openmpi3_16n = [96.58, 96.47, 97.71, 101.89, 100.69, 101.95, 91.32, 89.82, 85.48, 85.30, 87.49, 2165.76, 2104.20, 2117.77, 2235.77, 2335.53, 2457.74, 2815.92, 3668.79, 5121.64, 8052.14, 14105.71, 26151.91]
openmpi4_16n = [100.20, 97.71, 98.38, 99.62, 99.58, 102.52, 87.29, 87.79, 88.07, 88.06, 88.60, 2055.91, 2045.37, 2082.41, 2112.00, 2196.62, 2359.23, 2846.61, 3540.46, 5255.45, 8054.62, 14109.33, 26065.65]
openmpi5_16n = [96.31, 96.85, 97.76, 100.92, 100.78, 101.45, 86.42, 85.56, 84.50, 86.33, 86.90, 2083.19, 2142.56, 2099.66, 2178.50, 2330.39, 2483.51, 2861.63, 3657.27, 5044.06, 8159.10, 14056.84, 26259.12]
    
##########################################################################################################################

# Number of nodes used
num_nodes = [2, 4, 8, 16]

# Message sizes
sizes = [
    '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
    '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB'
]

cray_mpich_2n_averages = []
cray_mpich_4n_averages = []
cray_mpich_8n_averages = []
cray_mpich_16n_averages = []

argonne_mpich_2n_averages = []
argonne_mpich_4n_averages = []
argonne_mpich_8n_averages = []
argonne_mpich_16n_averages = []

openmpi_2n_averages = []
openmpi_4n_averages = []
openmpi_8n_averages = []
openmpi_16n_averages = []

for i in range( len( sizes ) ):
    cray_mpich_2n_averages.append(( cray_mpich1_2n[i] + cray_mpich2_2n[i] + cray_mpich3_2n[i] + cray_mpich4_2n[i] + cray_mpich5_2n[i] ) / 5)
    cray_mpich_4n_averages.append(( cray_mpich1_4n[i] + cray_mpich2_4n[i] + cray_mpich3_4n[i] + cray_mpich4_4n[i] + cray_mpich5_4n[i] ) / 5)
    cray_mpich_8n_averages.append(( cray_mpich1_8n[i] + cray_mpich2_8n[i] + cray_mpich3_8n[i] + cray_mpich4_8n[i] + cray_mpich5_8n[i] ) / 5)
    cray_mpich_16n_averages.append(( cray_mpich1_16n[i] + cray_mpich2_16n[i] + cray_mpich3_16n[i] + cray_mpich4_16n[i] + cray_mpich5_16n[i]) / 5)

    argonne_mpich_2n_averages.append(( argonne_mpich1_2n[i] + argonne_mpich2_2n[i] + argonne_mpich3_2n[i] + argonne_mpich4_2n[i] + argonne_mpich5_2n[i] ) / 5)
    argonne_mpich_4n_averages.append(( argonne_mpich1_4n[i] + argonne_mpich2_4n[i] + argonne_mpich3_4n[i] + argonne_mpich4_4n[i] + argonne_mpich5_4n[i] ) / 5)
    argonne_mpich_8n_averages.append(( argonne_mpich1_8n[i] + argonne_mpich2_8n[i] + argonne_mpich3_8n[i] + argonne_mpich4_8n[i] + argonne_mpich5_8n[i] ) / 5)
    argonne_mpich_16n_averages.append(( argonne_mpich1_16n[i] + argonne_mpich2_16n[i] + argonne_mpich3_16n[i] + argonne_mpich4_16n[i] + argonne_mpich5_16n[i] ) / 5)

    openmpi_2n_averages.append(( openmpi1_2n[i] + openmpi2_2n[i] + openmpi3_2n[i] + openmpi4_2n[i] + openmpi5_2n[i] ) / 5)
    openmpi_4n_averages.append(( openmpi1_4n[i] + openmpi2_4n[i] + openmpi3_4n[i] + openmpi4_4n[i] + openmpi5_4n[i] ) / 5)
    openmpi_8n_averages.append(( openmpi1_8n[i] + openmpi2_8n[i] + openmpi3_8n[i] + openmpi4_8n[i] + openmpi5_8n[i] ) / 5)
    openmpi_16n_averages.append(( openmpi1_16n[i] + openmpi2_16n[i] + openmpi3_16n[i] + openmpi4_16n[i] + openmpi5_16n[i] ) / 5)

# Averages latencies for 16MB message size, scaling nodes
cray_mpich_results = [ cray_mpich_2n_averages[22], cray_mpich_4n_averages[22], cray_mpich_8n_averages[22], cray_mpich_16n_averages[22] ]
argonne_mpich_results = [ argonne_mpich_2n_averages[22], argonne_mpich_4n_averages[22], argonne_mpich_8n_averages[22], argonne_mpich_16n_averages[22] ]
openmpi_results = [ openmpi_2n_averages[22], openmpi_4n_averages[22], openmpi_8n_averages[22], openmpi_16n_averages[22] ]

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("husl", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(num_nodes, cray_mpich_results, marker='x', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(num_nodes, argonne_mpich_results, marker='o', markersize=10, linewidth=2.5, color=color_palette[0])
ax.plot(num_nodes, openmpi_results, marker="|", markersize=10, linewidth=2.5, color=color_palette[2])

# Set labels and title
ax.set_xlabel('Nodes')
ax.set_ylabel('Average Latency (us)')
ax.set_title('D2D OSU MPI-CUDA Non-Blocking Gather Latency (16 MB Message Size)')

# Set y ticks
ax.set_yticks(range(0, 120001, 20000))

# Rotate x-axis labels for better visibility
plt.xticks(num_nodes, num_nodes)

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save figure
plt.savefig("figures/non_blocking_collectives/gather_nodes_NB.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %%
sizes = [
    '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
    '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB'
]

# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("husl", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(sizes, cray_mpich_16n_averages, marker='x', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(sizes, argonne_mpich_16n_averages, marker='o', markersize=10, linewidth=2.5, color=color_palette[0])
ax.plot(sizes, openmpi_16n_averages, marker="|", markersize=10, linewidth=2.5, color=color_palette[2])

# Set labels and title
ax.set_xlabel('Message Size')
ax.set_ylabel('Average Latency (us)')
ax.set_title('D2D OSU MPI-CUDA Non-Blocking Gather Latency (16 MB Message Size)')

# Rotate x-axis labels for better visibility
plt.xticks(sizes, sizes, rotation=45)

# Set y ticks
ax.set_yticks(range(0, 120001, 20000))

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save figure
plt.savefig("figures/non_blocking_collectives/gather_messages_NB.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %% [markdown]
# ### osu_allgather

# %%
##################################
# 2 nodes
##################################
cray_mpich1_2n = [110.38, 110.05, 112.40, 110.82, 91.68, 91.49, 91.54, 83.01, 73.64, 74.94, 76.96, 83.40, 87.70, 95.70, 111.11, 145.65, 215.70, 352.82, 645.27, 1216.76, 2340.36, 4765.32, 9410.71]
cray_mpich2_2n = [109.36, 109.19, 109.26, 108.26, 89.91, 89.50, 90.15, 82.98, 73.65, 76.01, 77.60, 83.26, 86.59, 95.21, 109.93, 144.96, 216.32, 355.14, 644.71, 1219.82, 2339.61, 4768.91, 9405.81]
cray_mpich3_2n = [109.40, 109.37, 109.40, 110.43, 94.53, 94.41, 94.62, 87.44, 76.71, 78.66, 80.93, 95.16, 99.70, 107.69, 125.60, 156.57, 228.16, 367.63, 664.61, 1216.15, 2356.31, 4924.62, 9667.20]
cray_mpich4_2n = [110.29, 109.35, 110.74, 108.77, 92.84, 93.16, 93.23, 87.31, 75.59, 76.68, 79.56, 93.82, 98.51, 106.60, 122.00, 154.33, 226.90, 366.87, 665.49, 1225.50, 2331.20, 4918.92, 9633.93]
izes = [
    '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
    '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB'
]

cray_mpich_2n_averages = []
cray_mpich_4n_averages = []
cray_mpich_8n_averages = []
cray_mpich_16n_averages = []

argonne_mpich_2n_averages = []
argonne_mpich_4n_averages = []
argonne_mpich_8n_averages = []
argonne_mpich_16n_averages = []

openmpi_2n_averages = []
openmpi_4n_averages = []
openmpi_8n_averages = []
openmpi_16n_averages = []

for i in range( len( sizes ) ):
    cray_mpich_2n_averages.append(( cray_mpich1_2n[i] + cray_mpich2_2n[i] + cray_mpich3_2n[i] + cray_mpich4_2n[i] + cray_mpich5_2n[i] ) / 5)
    cray_mpich_4n_averages.append(( cray_mpich1_4n[i] + cray_mpich2_4n[i] + cray_mpich3_4n[i] + cray_mpich4_4n[i] + cray_mpich5_4n[i] ) / 5)
    cray_mpich_8n_averages.append(( cray_mpich1_8n[i] + cray_mpich2_8n[i] + cray_mpich3_8n[i] + cray_mpich4_8n[i] + cray_mpich5_8n[i] ) / 5)
    cray_mpich_16n_averages.append(( cray_mpich1_16n[i] + cray_mpich2_16n[i] + cray_mpich3_16n[i] + cray_mpich4_16n[i] + cray_mpich5_16n[i]) / 5)

    argonne_mpich_2n_averages.append(( argonne_mpich1_2n[i] + argonne_mpich2_2n[i] + argonne_mpich3_2n[i] + argonne_mpich4_2n[i] + argonne_mpich5_2n[i] ) / 5)
    argonne_mpich_4n_averages.append(( argonne_mpich1_4n[i] + argonne_mpich2_4n[i] + argonne_mpich3_4n[i] + argonne_mpich4_4n[i] + argonne_mpich5_4n[i] ) / 5)
    argonne_mpich_8n_averages.append(( argonne_mpich1_8n[i] + argonne_mpich2_8n[i] + argonne_mpich3_8n[i] + argonne_mpich4_8n[i] + argonne_mpich5_8n[i] ) / 5)
    argonne_mpich_16n_averages.append(( argonne_mpich1_16n[i] + argonne_mpich2_16n[i] + argonne_mpich3_16n[i] + argonne_mpich4_16n[i] + argonne_mpich5_16n[i] ) / 5)

    openmpi_2n_averages.append(( openmpi1_2n[i] + openmpi2_2n[i] + openmpi3_2n[i] + openmpi4_2n[i] + openmpi5_2n[i] ) / 5)
    openmpi_4n_averages.append(( openmpi1_4n[i] + openmpi2_4n[i] + openmpi3_4n[i] + openmpi4_4n[i] + openmpi5_4n[i] ) / 5)
    openmpi_8n_averages.append(( openmpi1_8n[i] + openmpi2_8n[i] + openmpi3_8n[i] + openmpi4_8n[i] + openmpi5_8n[i] ) / 5)
    openmpi_16n_averages.append(( openmpi1_16n[i] + openmpi2_16n[i] + openmpi3_16n[i] + openmpi4_16n[i] + openmpi5_16n[i] ) / 5)

# Averages latencies for 16MB message size, scaling nodes
cray_mpich_results = [ cray_mpich_2n_averages[22], cray_mpich_4n_averages[22], cray_mpich_8n_averages[22], cray_mpich_16n_averages[22] ]
argonne_mpich_results = [ argonne_mpich_2n_averages[22], argonne_mpich_4n_averages[22], argonne_mpich_8n_averages[22], argonne_mpich_16n_averages[22] ]
openmpi_results = [ openmpi_2n_averages[22], openmpi_4n_averages[22], openmpi_8n_averages[22], openmpi_16n_averages[22] ]

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("husl", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(num_nodes, cray_mpich_results, marker='x', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(num_nodes, argonne_mpich_results, marker='o', markersize=10, linewidth=2.5, color=color_palette[0])
ax.plot(num_nodes, openmpi_results, marker="|", markersize=10, linewidth=2.5, color=color_palette[2])

# Set labels and title
ax.set_xlabel('Nodes')
ax.set_ylabel('Average Latency (us)')
ax.set_title('D2D OSU MPI-CUDA Non-Blocking AllGather Latency (16 MB Message Size)')

# Rotate x-axis labels for better visibility
plt.xticks(num_nodes, num_nodes)

# Set y ticks
ax.set_yticks(range(0, 1600001, 200000))

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save figure
plt.savefig("figures/non_blocking_collectives/allgather_nodes_NB.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %%
sizes = [
    '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
    '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB'
]

# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("husl", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(sizes, cray_mpich_16n_averages, marker='x', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(sizes, argonne_mpich_16n_averages, marker='o', markersize=10, linewidth=2.5, color=color_palette[0])
ax.plot(sizes, openmpi_16n_averages, marker="|", markersize=10, linewidth=2.5, color=color_palette[2])

# Set labels and title
ax.set_xlabel('Message Size')
ax.set_ylabel('Average Latency (us)')
ax.set_title('D2D OSU MPI-CUDA Non-Blocking AllGather Latency (16 Nodes)')

# Rotate x-axis labels for better visibility
plt.xticks(sizes, sizes, rotation=45)

# Set y ticks
ax.set_yticks(range(0, 1600001, 200000))

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save figure
plt.savefig("figures/non_blocking_collectives/allgather_messages_NB.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %% [markdown]
# ### osu_reduce

# %%
# ##################################
# # 2 nodes
# ##################################
# cray_mpich1_2n = [128.49, 129.75, 128.54, 129.52, 130.33, 128.76, 130.64, 147.42, 330.19, 392.61, 577.37, 649.66, 738.35, 807.36, 1087.97, 1143.60, 1317.75, 1657.42, 3430.60, 9131.35, 15628.72, 28163.03, 57727.89]
# cray_mpich2_2n = [126.98, 128.42, 125.57, 126.01, 128.28, 129.31, 126.95, 137.54, 317.02, 334.17, 590.23, 620.83, 712.94, 729.00, 1032.66, 1144.92, 1315.52, 1651.79, 3484.31, 8910.27, 16291.93, 28987.73, 59242.83]
# cray_mpich3_2n = [130.86, 131.04, 128.71, 128.17, 134.17, 130.62, 133.24, 154.90, 330.49, 345.92, 617.62, 652.20, 749.27, 819.38, 1116.38, 1189.97, 1336.97, 1609.84, 3479.41, 9111.86, 15958.03, 28507.87, 57830.40]
# cray_mpich4_2n = [131.52, 129.22, 129.94, 129.54, 127.35, 125.87, 128.32, 139.64, 385.41, 441.00, 479.53, 586.07, 716.72, 743.08, 1010.57, 1061.66, 1222.83, 1724.67, 3512.41, 8678.10, 15390.14, 28694.83, 59462.62]
# cray_mpich5_2n = [131.39, 129.16, 132.27, 130.03, 132.42, 132.85, 134.72, 135.76, 329.92, 346.80, 531.22, 666.61, 792.44, 873.57, 1122.39, 1189.98, 1383.92, 1722.86, 3580.23, 9121.21, 15451.23, 28602.61, 59437.32]

# argonne_mpich1_2n = [40.91, 40.88, 40.91, 40.89, 41.06, 41.34, 42.09, 42.26, 42.53, 44.30, 127.27, 149.40, 187.40, 215.94, 253.12, 326.90, 445.50, 667.85, 2589.03, 8977.41, 12443.68, 17895.47, 34868.85]
# argonne_mpich5_16n = [34.63, 34.45, 34.44, 34.46, 34.56, 34.77, 36.77, 36.97, 37.20, 38.25, 119.51, 149.87, 179.53, 212.13, 257.44, 339.32, 465.75, 698.71, 2643.48, 7510.85, 12342.91, 17077.61, 35238.21]

# openmpi1_16n = 
# openmpi2_16n = 
# openmpi3_16n = 
# openmpi4_16n = 
# openmpi5_16n = 
    
# ##########################################################################################################################

# # Number of nodes used
# num_nodes = [2, 4, 8, 16]

# # Message sizes
# sizes = [
#     '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
#     '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB'
# ]

# cray_mpich_2n_averages = []
# cray_mpich_4n_averages = []
# cray_mpich_8n_averages = []
# cray_mpich_16n_averages = []

# argonne_mpich_2n_averages = []
# argonne_mpich_4n_averages = []
# argonne_mpich_8n_averages = []
# argonne_mpich_16n_averages = []

# openmpi_2n_averages = []
# openmpi_4n_averages = []
# openmpi_8n_averages = []
# openmpi_16n_averages = []

# for i in range( len( sizes ) ):
#     cray_mpich_2n_averages.append(( cray_mpich1_2n[i] + cray_mpich2_2n[i] + cray_mpich3_2n[i] + cray_mpich4_2n[i] + cray_mpich5_2n[i] ) / 5)
#     cray_mpich_4n_averages.append(( cray_mpich1_4n[i] + cray_mpich2_4n[i] + cray_mpich3_4n[i] + cray_mpich4_4n[i] + cray_mpich5_4n[i] ) / 5)
#     cray_mpich_8n_averages.append(( cray_mpich1_8n[i] + cray_mpich2_8n[i] + cray_mpich3_8n[i] + cray_mpich4_8n[i] + cray_mpich5_8n[i] ) / 5)
#     cray_mpich_16n_averages.append(( cray_mpich1_16n[i] + cray_mpich2_16n[i] + cray_mpich3_16n[i] + cray_mpich4_16n[i] + cray_mpich5_16n[i]) / 5)

#     argonne_mpich_2n_averages.append(( argonne_mpich1_2n[i] + argonne_mpich2_2n[i] + argonne_mpich3_2n[i] + argonne_mpich4_2n[i] + argonne_mpich5_2n[i] ) / 5)
#     argonne_mpich_4n_averages.append(( argonne_mpich1_4n[i] + argonne_mpich2_4n[i] + argonne_mpich3_4n[i] + argonne_mpich4_4n[i] + argonne_mpich5_4n[i] ) / 5)
#     argonne_mpich_8n_averages.append(( argonne_mpich1_8n[i] + argonne_mpich2_8n[i] + argonne_mpich3_8n[i] + argonne_mpich4_8n[i] + argonne_mpich5_8n[i] ) / 5)
#     argonne_mpich_16n_averages.append(( argonne_mpich1_16n[i] + argonne_mpich2_16n[i] + argonne_mpich3_16n[i] + argonne_mpich4_16n[i] + argonne_mpich5_16n[i] ) / 5)

#     openmpi_2n_averages.append(( openmpi1_2n[i] + openmpi2_2n[i] + openmpi3_2n[i] + openmpi4_2n[i] + openmpi5_2n[i] ) / 5)
#     openmpi_4n_averages.append(( openmpi1_4n[i] + openmpi2_4n[i] + openmpi3_4n[i] + openmpi4_4n[i] + openmpi5_4n[i] ) / 5)
#     openmpi_8n_averages.append(( openmpi1_8n[i] + openmpi2_8n[i] + openmpi3_8n[i] + openmpi4_8n[i] + openmpi5_8n[i] ) / 5)
#     openmpi_16n_averages.append(( openmpi1_16n[i] + openmpi2_16n[i] + openmpi3_16n[i] + openmpi4_16n[i] + openmpi5_16n[i] ) / 5)

# # Averages latencies for 16MB message size, scaling nodes
# cray_mpich_results = [ cray_mpich_2n_averages[22], cray_mpich_4n_averages[22], cray_mpich_8n_averages[22], cray_mpich_16n_averages[22] ]
# argonne_mpich_results = [ argonne_mpich_2n_averages[22], argonne_mpich_4n_averages[22], argonne_mpich_8n_averages[22], argonne_mpich_16n_averages[22] ]
# openmpi_results = [ openmpi_2n_averages[22], openmpi_4n_averages[22], openmpi_8n_averages[22], openmpi_16n_averages[22] ]

# #----------------------------------------------------------------------------------------
# # Set plot style and create a color palette
# sns.set(style="whitegrid")
# color_palette = sns.color_palette("husl", 3)

# # Set the plot size
# plt.figure(dpi=300)
# fig, ax = plt.subplots(figsize=(16, 12))

# # Increase font sizes
# plt.rc('font', size=320)         # controls default text sizes

# # Plotting the line plot with larger linewidth and markersize
# ax.plot(num_nodes, cray_mpich_results, marker='x', markersize=10, linewidth=2.5, color=color_palette[1])
# ax.plot(num_nodes, argonne_mpich_results, marker='o', markersize=10, linewidth=2.5, color=color_palette[0])
# ax.plot(num_nodes, openmpi_results, marker="|", markersize=10, linewidth=2.5, color=color_palette[2])

# # Set labels and title
# ax.set_xlabel('Nodes')
# ax.set_ylabel('Average Latency (us)')
# ax.set_title('D2D OSU MPI-CUDA Non-Blocking Reduce Latency (16 MB Message Size)')

# # Rotate x-axis labels for better visibility
# plt.xticks(num_nodes, num_nodes)#, rotation=45)

# # Set y ticks
# # # # ax.set_yticks(range(20000, 80001, 5000))
# # ax.set_yticks(range(0, 80001, 10000))

# # Add a legend and place it outside the plot area
# legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper right') #, fontsize='large')

# # Add grid for easier value estimation
# ax.grid(True)

# # Adjust the layout to prevent labels from being cut off
# fig.tight_layout()

# # Save figure
# plt.savefig("figures/non_blocking_collectives/reduce_nodes_NB.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# # Display the plot
# plt.show()

# %%
# sizes = [
#     '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
#     '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB'
# ]

# # Set plot style and create a color palette
# sns.set(style="whitegrid")
# color_palette = sns.color_palette("husl", 3)

# # Set the plot size
# plt.figure(dpi=300)
# fig, ax = plt.subplots(figsize=(16, 12))

# # Increase font sizes
# plt.rc('font', size=320)         # controls default text sizes

# # Plotting the line plot with larger linewidth and markersize
# ax.plot(sizes, cray_mpich_16n_averages, marker='x', markersize=10, linewidth=2.5, color=color_palette[1])
# ax.plot(sizes, argonne_mpich_16n_averages, marker='o', markersize=10, linewidth=2.5, color=color_palette[0])
# ax.plot(sizes, openmpi_16n_averages, marker="|", markersize=10, linewidth=2.5, color=color_palette[2])

# # Set labels and title
# ax.set_xlabel('Message Size')
# ax.set_ylabel('Average Latency (us)')
# ax.set_title('D2D OSU MPI-CUDA Non-Blocking Reduce Latency (16 Nodes)')

# # Rotate x-axis labels for better visibility
# plt.xticks(sizes, sizes, rotation=45)

# # Set y ticks
# # ax.set_yticks(range(0, 60001, 10000))

# # Add a legend and place it outside the plot area
# legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# # Add grid for easier value estimation
# ax.grid(True)

# # Adjust the layout to prevent labels from being cut off
# fig.tight_layout()

# # Save figure
# plt.savefig("figures/non_blocking_collectives/reduce_messages_NB.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB'
# ]

# cray_mpich_2n_averages = []
# cray_mpich_4n_averages = []
# cray_mpich_8n_averages = []
# cray_mpich_16n_averages = []

# argonne_mpich_2n_averages = []
# argonne_mpich_4n_averages = []
# argonne_mpich_8n_averages = []
# argonne_mpich_16n_averages = []

# openmpi_2n_averages = []
# openmpi_4n_averages = []
# openmpi_8n_averages = []
# openmpi_16n_averages = []

# for i in range( len( sizes ) ):
#     cray_mpich_2n_averages.append(( cray_mpich1_2n[i] + cray_mpich2_2n[i] + cray_mpich3_2n[i] + cray_mpich4_2n[i] + cray_mpich5_2n[i] ) / 5)
#     cray_mpich_4n_averages.append(( cray_mpich1_4n[i] + cray_mpich2_4n[i] + cray_mpich3_4n[i] + cray_mpich4_4n[i] + cray_mpich5_4n[i] ) / 5)
#     cray_mpich_8n_averages.append(( cray_mpich1_8n[i] + cray_mpich2_8n[i] + cray_mpich3_8n[i] + cray_mpich4_8n[i] + cray_mpich5_8n[i] ) / 5)
#     cray_mpich_16n_averages.append(( cray_mpich1_16n[i] + cray_mpich2_16n[i] + cray_mpich3_16n[i] + cray_mpich4_16n[i] + cray_mpich5_16n[i]) / 5)

#     argonne_mpich_2n_averages.append(( argonne_mpich1_2n[i] + argonne_mpich2_2n[i] + argonne_mpich3_2n[i] + argonne_mpich4_2n[i] + argonne_mpich5_2n[i] ) / 5)
#     argonne_mpich_4n_averages.append(( argonne_mpich1_4n[i] + argonne_mpich2_4n[i] + argonne_mpich3_4n[i] + argonne_mpich4_4n[i] + argonne_mpich5_4n[i] ) / 5)
#     argonne_mpich_8n_averages.append(( argonne_mpich1_8n[i] + argonne_mpich2_8n[i] + argonne_mpich3_8n[i] + argonne_mpich4_8n[i] + argonne_mpich5_8n[i] ) / 5)
#     argonne_mpich_16n_averages.append(( argonne_mpich1_16n[i] + argonne_mpich2_16n[i] + argonne_mpich3_16n[i] + argonne_mpich4_16n[i] + argonne_mpich5_16n[i] ) / 5)

#     openmpi_2n_averages.append(( openmpi1_2n[i] + openmpi2_2n[i] + openmpi3_2n[i] + openmpi4_2n[i] + openmpi5_2n[i] ) / 5)
#     openmpi_4n_averages.append(( openmpi1_4n[i] + openmpi2_4n[i] + openmpi3_4n[i] + openmpi4_4n[i] + openmpi5_4n[i] ) / 5)
#     openmpi_8n_averages.append(( openmpi1_8n[i] + openmpi2_8n[i] + openmpi3_8n[i] + openmpi4_8n[i] + openmpi5_8n[i] ) / 5)
#     openmpi_16n_averages.append(( openmpi1_16n[i] + openmpi2_16n[i] + openmpi3_16n[i] + openmpi4_16n[i] + openmpi5_16n[i] ) / 5)

# # Averages latencies for 16MB message size, scaling nodes
# cray_mpich_results = [ cray_mpich_2n_averages[22], cray_mpich_4n_averages[22], cray_mpich_8n_averages[22], cray_mpich_16n_averages[22] ]
# argonne_mpich_results = [ argonne_mpich_2n_averages[22], argonne_mpich_4n_averages[22], argonne_mpich_8n_averages[22], argonne_mpich_16n_averages[22] ]
# openmpi_results = [ openmpi_2n_averages[22], openmpi_4n_averages[22], openmpi_8n_averages[22], openmpi_16n_averages[22] ]

# #----------------------------------------------------------------------------------------
# # Set plot style and create a color palette
# sns.set(style="whitegrid")
# color_palette = sns.color_palette("husl", 3)

# # Set the plot size
# plt.figure(dpi=300)
# fig, ax = plt.subplots(figsize=(16, 12))

# # Increase font sizes
# plt.rc('font', size=320)         # controls default text sizes

# # Plotting the line plot with larger linewidth and markersize
# ax.plot(num_nodes, cray_mpich_results, marker='x', markersize=10, linewidth=2.5, color=color_palette[1])
# ax.plot(num_nodes, argonne_mpich_results, marker='o', markersize=10, linewidth=2.5, color=color_palette[0])
# ax.plot(num_nodes, openmpi_results, marker="|", markersize=10, linewidth=2.5, color=color_palette[2])

# # Set labels and title
# ax.set_xlabel('Nodes')
# ax.set_ylabel('Average Latency (us)')
# ax.set_title('D2D OSU MPI-CUDA Non-Blocking AllReduce Latency (16 MB Message Size)')

# # Rotate x-axis labels for better visibility
# plt.xticks(num_nodes, num_nodes)

# # Set y ticks
# # # # ax.set_yticks(range(0, 140001, 10000))
# # ax.set_yticks(range(0, 140001, 20000))

# # Add a legend and place it outside the plot area
# legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='center left') #, fontsize='large')

# # Add grid for easier value estimation
# ax.grid(True)

# # Adjust the layout to prevent labels from being cut off
# fig.tight_layout()

# # Save figure
# plt.savefig("figures/non_blocking_collectives/allreduce_nodes_NB.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# # Display the plot
# plt.show()

# %%
# sizes = [
#     '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
#     '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB'
# ]

# # Set plot style and create a color palette
# sns.set(style="whitegrid")
# color_palette = sns.color_palette("husl", 3)

# # Set the plot size
# plt.figure(dpi=300)
# fig, ax = plt.subplots(figsize=(16, 12))

# # Increase font sizes
# plt.rc('font', size=320)         # controls default text sizes

# # Plotting the line plot with larger linewidth and markersize
# ax.plot(sizes, cray_mpich_16n_averages, marker='x', markersize=10, linewidth=2.5, color=color_palette[1])
# ax.plot(sizes, argonne_mpich_16n_averages, marker='o', markersize=10, linewidth=2.5, color=color_palette[0])
# ax.plot(sizes, openmpi_16n_averages, marker="|", markersize=10, linewidth=2.5, color=color_palette[2])

# # Set labels and title
# ax.set_xlabel('Message Size')
# ax.set_ylabel('Average Latency (us)')
# ax.set_title('D2D OSU MPI-CUDA Non-Blocking AllReduce Latency (16 Nodes)')

# # Rotate x-axis labels for better visibility
# plt.xticks(sizes, sizes, rotation=45)

# # Set y ticks
# # ax.set_yticks(range(0, 140001, 20000))

# # Add a legend and place it outside the plot area
# legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# # Add grid for easier value estimation
# ax.grid(True)

# # Adjust the layout to prevent labels from being cut off
# fig.tight_layout()

# # Save figure
# plt.savefig("figures/non_blocking_collectives/allreduce_messages_NB.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# # Display the plot
# plt.show()

# %% [markdown]
# ### osu_bcast

# %%
##################################
# 2 nodes
##################################
cray_mpich1_2n = [47.31, 47.35, 47.83, 47.95, 48.07, 48.88, 38.77, 39.74, 34.21, 34.27, 34.49, 35.11, 36.28, 37.77, 41.72, 44.46, 51.68, 65.70, 95.63, 155.70, 275.48, 516.50, 998.67]
cray_mpich2_2n = [48.24, 48.37, 48.36, 48.40, 49.04, 49.26, 40.12, 40.39, 33.84, 33.94, 34.46, 35.30, 35.86, 38.42, 41.17, 44.81, 51.71, 66.03, 96.04, 155.44, 275.84, 517.53, 1000.26]
cray_mpich3_2n = [48.27, 48.53, 48.19, 48.25, 48.43, 49.12, 39.30, 40.80, 34.84, 34.92, 35.03, 35.22, 36.50, 41.16, 43.51, 47.35, 54.41, 68.58, 102.09, 159.28, 279.53, 525.38, 1015.31]
argonne_mpich1_16n = [107.45, 107.41, 108.81, 108.97, 109.15, 110.31, 63.22, 63.58, 63.47, 64.25, 64.80, 77.66, 214.13, 142.22, 159.05, 181.41, 216.12, 514.22, 656.41, 1161.16, 2000.29, 3267.92, 7808.80]
argonne_mpich2_16n = [108.01, 107.88, 109.79, 109.68, 109.88, 111.10, 63.05, 63.40, 63.64, 64.38, 65.16, 80.39, 199.26, 162.22, 171.69, 196.45, 231.88, 626.59, 753.29, 1213.27, 1889.03, 3279.57, 7780.57]
argonne_mpich3_16n = [107.70, 107.51, 109.76, 109.56, 109.92, 111.01, 64.35, 64.34, 65.35, 65.11, 65.70, 84.36, 217.69, 177.37, 201.79, 226.74, 266.79, 649.06, 794.58, 1252.40, 1933.97, 3303.27, 7813.89]
argonne_mpich4_16n = [107.70, 107.51, 109.76, 109.56, 109.92, 111.01, 64.35, 64.34, 65.35, 65.11, 65.70, 84.36, 217.69, 177.37, 201.79, 226.74, 266.79, 649.06, 794.58, 1252.40, 1933.97, 3303.27, 7813.89]
argonne_mpich5_16n = [107.17, 107.05, 108.74, 108.40, 108.36, 109.38, 62.66, 62.79, 63.00, 63.86, 64.61, 80.19, 205.23, 160.68, 174.62, 199.63, 240.06, 654.01, 801.44, 1217.39, 1861.39, 3289.24, 7827.79]

openmpi1_16n = [98.96, 99.07, 102.25, 102.28, 102.22, 105.19, 28.68, 29.23, 29.73, 30.69, 31.01, 52.70, 55.39, 61.68, 78.96, 116.42, 216.31, 413.28, 806.30, 1576.16, 3139.53, 6272.01, 12496.26]
openmpi2_16n = [98.47, 98.56, 100.64, 100.67, 101.05, 104.73, 28.91, 29.20, 29.46, 30.32, 30.61, 52.74, 55.42, 62.28, 81.11, 124.00, 222.64, 417.09, 814.11, 1590.75, 3166.32, 6294.99, 12503.19]
openmpi3_16n = [98.57, 98.14, 100.16, 100.51, 100.32, 103.95, 28.88, 29.10, 29.45, 30.10, 30.32, 51.70, 55.23, 62.11, 81.76, 124.58, 223.55, 420.52, 814.75, 1591.81, 3177.20, 6291.01, 12522.00]
openmpi4_16n = [100.32, 100.24, 101.90, 101.91, 101.93, 105.87, 30.73, 30.98, 31.18, 32.29, 32.68, 57.16, 60.41, 68.08, 82.90, 121.55, 219.05, 417.57, 815.85, 1585.50, 3162.92, 6291.83, 12638.64]
openmpi5_16n = [100.16, 100.42, 103.41, 103.01, 103.14, 105.86, 29.61, 29.97, 30.41, 31.25, 31.55, 53.01, 56.70, 64.21, 84.02, 128.93, 225.47, 418.94, 813.79, 1594.95, 3175.99, 6274.16, 12503.06]
    
##########################################################################################################################

# Number of nodes used
num_nodes = [2, 4, 8, 16]

# Message sizes
sizes = [
    '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
    '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB'
]

cray_mpich_2n_averages = []
cray_mpich_4n_averages = []
cray_mpich_8n_averages = []
cray_mpich_16n_averages = []

argonne_mpich_2n_averages = []
argonne_mpich_4n_averages = []
argonne_mpich_8n_averages = []
argonne_mpich_16n_averages = []

openmpi_2n_averages = []
openmpi_4n_averages = []
openmpi_8n_averages = []
openmpi_16n_averages = []

for i in range( len( sizes ) ):
    cray_mpich_2n_averages.append(( cray_mpich1_2n[i] + cray_mpich2_2n[i] + cray_mpich3_2n[i] + cray_mpich4_2n[i] + cray_mpich5_2n[i] ) / 5)
    cray_mpich_4n_averages.append(( cray_mpich1_4n[i] + cray_mpich2_4n[i] + cray_mpich3_4n[i] + cray_mpich4_4n[i] + cray_mpich5_4n[i] ) / 5)
    cray_mpich_8n_averages.append(( cray_mpich1_8n[i] + cray_mpich2_8n[i] + cray_mpich3_8n[i] + cray_mpich4_8n[i] + cray_mpich5_8n[i] ) / 5)
    cray_mpich_16n_averages.append(( cray_mpich1_16n[i] + cray_mpich2_16n[i] + cray_mpich3_16n[i] + cray_mpich4_16n[i] + cray_mpich5_16n[i]) / 5)

    argonne_mpich_2n_averages.append(( argonne_mpich1_2n[i] + argonne_mpich2_2n[i] + argonne_mpich3_2n[i] + argonne_mpich4_2n[i] + argonne_mpich5_2n[i] ) / 5)
    argonne_mpich_4n_averages.append(( argonne_mpich1_4n[i] + argonne_mpich2_4n[i] + argonne_mpich3_4n[i] + argonne_mpich4_4n[i] + argonne_mpich5_4n[i] ) / 5)
    argonne_mpich_8n_averages.append(( argonne_mpich1_8n[i] + argonne_mpich2_8n[i] + argonne_mpich3_8n[i] + argonne_mpich4_8n[i] + argonne_mpich5_8n[i] ) / 5)
    argonne_mpich_16n_averages.append(( argonne_mpich1_16n[i] + argonne_mpich2_16n[i] + argonne_mpich3_16n[i] + argonne_mpich4_16n[i] + argonne_mpich5_16n[i] ) / 5)

    openmpi_2n_averages.append(( openmpi1_2n[i] + openmpi2_2n[i] + openmpi3_2n[i] + openmpi4_2n[i] + openmpi5_2n[i] ) / 5)
    openmpi_4n_averages.append(( openmpi1_4n[i] + openmpi2_4n[i] + openmpi3_4n[i] + openmpi4_4n[i] + openmpi5_4n[i] ) / 5)
    openmpi_8n_averages.append(( openmpi1_8n[i] + openmpi2_8n[i] + openmpi3_8n[i] + openmpi4_8n[i] + openmpi5_8n[i] ) / 5)
    openmpi_16n_averages.append(( openmpi1_16n[i] + openmpi2_16n[i] + openmpi3_16n[i] + openmpi4_16n[i] + openmpi5_16n[i] ) / 5)

# Averages latencies for 16MB message size, scaling nodes
cray_mpich_results = [ cray_mpich_2n_averages[22], cray_mpich_4n_averages[22], cray_mpich_8n_averages[22], cray_mpich_16n_averages[22] ]
argonne_mpich_results = [ argonne_mpich_2n_averages[22], argonne_mpich_4n_averages[22], argonne_mpich_8n_averages[22], argonne_mpich_16n_averages[22] ]
openmpi_results = [ openmpi_2n_averages[22], openmpi_4n_averages[22], openmpi_8n_averages[22], openmpi_16n_averages[22] ]

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("husl", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(num_nodes, cray_mpich_results, marker='x', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(num_nodes, argonne_mpich_results, marker='o', markersize=10, linewidth=2.5, color=color_palette[0])
ax.plot(num_nodes, openmpi_results, marker="|", markersize=10, linewidth=2.5, color=color_palette[2])

# Set labels and title
ax.set_xlabel('Nodes')
ax.set_ylabel('Average Latency (us)')
ax.set_title('D2D OSU MPI-CUDA Non-Blocking Broadcast Latency (16 MB Message Size)')

# Rotate x-axis labels for better visibility
plt.xticks(num_nodes, num_nodes)

# Set y-ticks
ax.set_yticks(range(0, 14001, 2000))

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save figure
plt.savefig("figures/non_blocking_collectives/broadcast_nodes_NB.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %%
sizes = [
    '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
    '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB'
]

# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("husl", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(sizes, cray_mpich_16n_averages, marker='x', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(sizes, argonne_mpich_16n_averages, marker='o', markersize=10, linewidth=2.5, color=color_palette[0])
ax.plot(sizes, openmpi_16n_averages, marker="|", markersize=10, linewidth=2.5, color=color_palette[2])

# Set labels and title
ax.set_xlabel('Message Size')
ax.set_ylabel('Average Latency (us)')
ax.set_title('D2D OSU MPI-CUDA Non-Blocking Broadcast Latency (16 Nodes)')

# Rotate x-axis labels for better visibility
plt.xticks(sizes, sizes, rotation=45)

# Set y-ticks
ax.set_yticks(range(0, 14001, 2000))

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save figure
plt.savefig("figures/non_blocking_collectives/broadcast_messages_NB.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %% [markdown]
# ### osu_alltoall

# %%
##################################
# 2 nodes
##################################
cray_mpich1_2n = [442.37, 443.62, 445.77, 446.44, 446.94, 449.19, 463.92, 183.64, 151.57, 157.97, 158.41, 164.09, 173.23, 169.72, 183.35, 217.84, 281.33, 417.42, 685.59, 1246.77, 2368.71, 4770.21, 8966.70]
cray_mpich2_2n = [451.52, 451.24, 453.50, 454.98, 455.36, 456.28, 470.37, 186.48, 149.71, 158.57, 158.57, 165.84, 172.43, 169.77, 184.40, 216.82, 283.39, 412.08, 685.44, 1239.39, 2383.48, 4782.07, 8944.20]
cray_mpich3_2n = [440.07, 440.96, 442.30, 444.38, 446.23, 447.48, 461.25, 184.81, 154.80, 156.57, 158.91, 166.76, 172.57, 206.79, 227.01, 254.86, 322.13, 444.97, 729.01, 1271.61, 2458.63, 4846.51, 9040.43]
cray_mpich4_2n = [452.13, 452.66, 454.46, 456.15, 456.85, 459.90, 471.53, 186.20, 157.00, 156.74, 159.33, 166.07, 173.34, 207.96, 225.77, 256.85, 326.65, 448.29, 736.70, 1288.91, 2454.66, 4823.96, 8999.81]
cray_mpich5_2n = [450.26, 450.77, 453.56, 454.68, 455.52, 457.59, 471.18, 184.72, 155.91, 157.80, 158.64, 165.17, 172.86, 204.80, 223.72, 253.33, 317.20, 438.27, 716.85, 1263.88, 2439.47, 4792.59, 8940.87]

argonne_mpich1_2n = [213.78, 213.61, 215.95, 215.56, 216.12, 217.77, 151.95, 152.39, 153.18, 154.81, 157.64, 163.29, 316.33, 205.55, 212.85, 263.61, 380.18, 589.08, 2121.29, 3505.89, 6384.53, 11626.94, 22190.46]
argonne_mpich2_2n = [215.35, 215.23, 215.35, 214.56, 215.44, 217.17, 150.38, 150.84, 151.41, 152.64, 155.63, 161.33, 312.14, 204.01, 210.35, 264.44, 374.15, 584.33, 2090.08, 3478.91, 6281.50, 11560.56, 22065.20]
argonne_mpich3_2n = [213.94, 214.04, 215.99, 215.49, 216.53, 217.97, 151.10, 151.98, 153.72, 155.76, 158.52, 164.09, 316.51, 205.58, 212.25, 266.24, 383.42, 586.42, 2121.03, 3489.76, 6313.43, 11502.65, 22099.76]
argonne_mpich4_2n = [210.71, 210.26, 212.63, 212.09, 212.96, 213.84, 148.06, 148.40, 149.43, 150.94, 153.59, 159.22, 309.26, 200.16, 207.84, 257.32, 369.72, 587.40, 2105.86, 3472.16, 6393.36, 11509.63, 22136.47]
    cray_mpich_4n_averages.append(( cray_mpich1_4n[i] + cray_mpich2_4n[i] + cray_mpich3_4n[i] + cray_mpich4_4n[i] + cray_mpich5_4n[i] ) / 5)
    cray_mpich_8n_averages.append(( cray_mpich1_8n[i] + cray_mpich2_8n[i] + cray_mpich3_8n[i] + cray_mpich4_8n[i] + cray_mpich5_8n[i] ) / 5)
    cray_mpich_16n_averages.append(( cray_mpich1_16n[i] + cray_mpich2_16n[i] + cray_mpich3_16n[i] + cray_mpich4_16n[i] + cray_mpich5_16n[i]) / 5)

    argonne_mpich_2n_averages.append(( argonne_mpich1_2n[i] + argonne_mpich2_2n[i] + argonne_mpich3_2n[i] + argonne_mpich4_2n[i] + argonne_mpich5_2n[i] ) / 5)
    argonne_mpich_4n_averages.append(( argonne_mpich1_4n[i] + argonne_mpich2_4n[i] + argonne_mpich3_4n[i] + argonne_mpich4_4n[i] + argonne_mpich5_4n[i] ) / 5)
    argonne_mpich_8n_averages.append(( argonne_mpich1_8n[i] + argonne_mpich2_8n[i] + argonne_mpich3_8n[i] + argonne_mpich4_8n[i] + argonne_mpich5_8n[i] ) / 5)
    argonne_mpich_16n_averages.append(( argonne_mpich1_16n[i] + argonne_mpich2_16n[i] + argonne_mpich3_16n[i] + argonne_mpich4_16n[i] + argonne_mpich5_16n[i] ) / 5)

    openmpi_2n_averages.append(( openmpi1_2n[i] + openmpi2_2n[i] + openmpi3_2n[i] + openmpi4_2n[i] + openmpi5_2n[i] ) / 5)
    openmpi_4n_averages.append(( openmpi1_4n[i] + openmpi2_4n[i] + openmpi3_4n[i] + openmpi4_4n[i] + openmpi5_4n[i] ) / 5)
    openmpi_8n_averages.append(( openmpi1_8n[i] + openmpi2_8n[i] + openmpi3_8n[i] + openmpi4_8n[i] + openmpi5_8n[i] ) / 5)
    openmpi_16n_averages.append(( openmpi1_16n[i] + openmpi2_16n[i] + openmpi3_16n[i] + openmpi4_16n[i] + openmpi5_16n[i] ) / 5)

# Averages latencies for 16MB message size, scaling nodes
cray_mpich_results = [ cray_mpich_2n_averages[22], cray_mpich_4n_averages[22], cray_mpich_8n_averages[22], cray_mpich_16n_averages[22] ]
argonne_mpich_results = [ argonne_mpich_2n_averages[22], argonne_mpich_4n_averages[22], argonne_mpich_8n_averages[22], argonne_mpich_16n_averages[22] ]
openmpi_results = [ openmpi_2n_averages[22], openmpi_4n_averages[22], openmpi_8n_averages[22], openmpi_16n_averages[22] ]

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("husl", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(num_nodes, cray_mpich_results, marker='x', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(num_nodes, argonne_mpich_results, marker='o', markersize=10, linewidth=2.5, color=color_palette[0])
ax.plot(num_nodes, openmpi_results, marker="|", markersize=10, linewidth=2.5, color=color_palette[2])

# Set labels and title
ax.set_xlabel('Nodes')
ax.set_ylabel('Average Latency (us)')
ax.set_title('D2D OSU MPI-CUDA All-to-All Personalized Exchange Latency (16 MB Message Size)')

# Rotate x-axis labels for better visibility
plt.xticks(num_nodes, num_nodes)

# Set y-ticks
ax.set_yticks(range(0, 2500001, 500000))

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save figure
plt.savefig("figures/non_blocking_collectives/alltoall_nodes_NB.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %%
sizes = [
    '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
    '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB'
]

# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("husl", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(sizes, cray_mpich_16n_averages, marker='x', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(sizes, argonne_mpich_16n_averages, marker='o', markersize=10, linewidth=2.5, color=color_palette[0])
ax.plot(sizes, openmpi_16n_averages, marker="|", markersize=10, linewidth=2.5, color=color_palette[2])

# Set labels and title
ax.set_xlabel('Message Size')
ax.set_ylabel('Average Latency (us)')
ax.set_title('D2D OSU MPI-CUDA All-to-All Personalized Exchange Latency (16 Nodes)')

# Rotate x-axis labels for better visibility
plt.xticks(sizes, sizes, rotation=45)

# Set y-ticks
ax.set_yticks(range(0, 2500001, 500000))

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save figure
plt.savefig("figures/non_blocking_collectives/alltoall_messages_NB.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %% [markdown]
# ## TEMPLATE:

# %%
# ##################################
# # 2 nodes
# ##################################
# cray_mpich1_2n = []
# cray_mpich2_2n = []
# cray_mpich3_2n = []
# cray_mpich4_2n = []
# cray_mpich5_2n = []

# argonne_mpich1_2n = []
# argonne_mpich2_2n = []
# argonne_mpich3_2n = []
# argonne_mpich4_2n = []
# argonne_mpich5_2n = []

# openmpi1_2n = []
# openmpi2_2n = []
# openmpi3_2n = []
# openmpi4_2n = []
# openmpi5_2n = []

# ##################################
# # 4 nodes
# ##################################
# cray_mpich1_4n = []
# cray_mpich2_4n = []
# cray_mpich3_4n = []
# cray_mpich4_4n = []
# cray_mpich5_4n = []

# argonne_mpich1_4n = []
# argonne_mpich2_4n = []
# argonne_mpich3_4n = []
# argonne_mpich4_4n = []
# argonne_mpich5_4n = []

# openmpi1_4n = []
# openmpi2_4n = []
# openmpi3_4n = []
# openmpi4_4n = []
# openmpi5_4n = []
    
# ##################################
# # 8 nodes
# ##################################
# cray_mpich1_8n = []
# cray_mpich2_8n = []
# cray_mpich3_8n = []
# cray_mpich4_8n = []
# cray_mpich5_8n = []

# argonne_mpich1_8n = []
# argonne_mpich2_8n = []
# argonne_mpich3_8n = []
# argonne_mpich4_8n = []
# argonne_mpich5_8n = []

# openmpi1_8n = []
# openmpi2_8n = []
# openmpi3_8n = []
# openmpi4_8n = []
# openmpi5_8n = []
    
    
# ##################################
# # 16 nodes
# ##################################
# cray_mpich1_16n = []
# cray_mpich2_16n = []
# cray_mpich3_16n = []
# cray_mpich4_16n = []
# cray_mpich5_16n = []

# argonne_mpich1_16n = []
# argonne_mpich2_16n = []
# argonne_mpich3_16n = []
# argonne_mpich4_16n = []
# argonne_mpich5_16n = []

# openmpi1_16n = []
# openmpi2_16n = []
# openmpi3_16n = []
# openmpi4_16n = []
# openmpi5_16n = []
    
# ##########################################################################################################################

# # Number of nodes used
# num_nodes = [2, 4, 8, 16, 32]
# message_sizes = [
#     '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
#     '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB', '32MB'
# ]

# %% [markdown]
# ## TEST

# %%
# ##################################
# # 2 nodes
# ##################################
# cray_mpich1_2n = [
#     13.38, 13.51, 13.37, 13.77, 14.13, 14.26, 14.30, 16.02, 17.43, 17.69,
#     18.82, 21.46, 24.09, 30.19, 41.73, 64.64, 109.87, 199.93, 365.81,
#     665.28, 1263.89, 3141.49, 13318.15 #, 38798.90
# ]
# argonne_mpich1_2n = [
#     15.75, 15.73, 15.78, 15.85, 16.36, 16.47, 16.43, 16.47, 17.31, 18.37,
#     18.86, 25.83, 43.87, 43.66, 71.35, 115.56, 215.29, 388.37, 596.26, 1196.24,
#     2396.99, 5613.51, 14658.02 #, 0
# ]
# openmpi1_2n = [
#     13.71, 13.65, 13.88, 13.86, 14.58, 16.10, 12.15, 12.58, 9.63, 10.87, 11.42, 23.39,
#     26.29, 32.60, 41.87, 61.80, 84.76, 136.24, 237.59, 440.79, 843.22, 3100.02, 6559.36
# ]

# ##################################
# # 4 nodes
# ##################################
# cray_mpich1_4n = [
#     12.88, 12.88, 12.83, 13.65, 14.16, 14.33, 14.47, 15.43, 16.47, 16.82,
#     19.37, 21.87, 24.81, 31.19, 43.77, 68.50, 118.21, 217.02, 407.58, 761.67,
#     1882.81, 4304.93, 15313.57 #, 43271.52
# ]
# argonne_mpich1_4n = [
#     15.71, 15.66, 15.64, 15.85, 16.34, 16.42, 16.50, 16.51,
#     19.70, 20.78, 21.98, 29.44, 50.79, 47.23, 96.39, 172.09,
#     314.94, 465.97, 657.57, 1268.03, 2924.46, 7826.73, 19641.06 #, 0
# ]
# openmpi1_4n = [
#     13.47, 13.43, 13.76, 14.01, 14.58, 16.20, 12.56, 12.78, 10.09, 11.54, 11.92, 26.15,
#     29.26, 37.40, 45.85, 66.26, 94.17, 154.68, 274.40, 512.30, 988.78, 3720.40, 7437.22
# ]
    
# ##################################
# # 8 nodes
# ##################################
# cray_mpich1_8n = [
#     12.98, 12.90, 12.90, 13.78, 14.40, 14.48, 14.65, 15.31, 16.17, 17.34,
#     19.33, 22.05, 25.59, 32.78, 46.58, 74.85, 129.81, 240.91, 453.24,
#     1103.68, 2407.65, 5243.80, 17088.56 #, 47497.69
# ]
# argonne_mpich1_8n = [
#     184.65, 185.16, 186.42, 190.94, 192.31, 191.82, 192.76, 367.34,
#     475.61, 527.51, 527.67, 544.51, 575.98, 571.71, 705.35, 1213.76,
#     1898.35, 2053.15, 2274.18, 2860.57, 4612.78, 10537.40, 24069.26 #, 0
# ]
# openmpi1_8n = [
#     13.26, 13.23, 13.69, 14.06, 14.75, 16.38, 12.50, 13.26, 11.19, 12.21, 12.92, 25.51,
#     31.59, 44.50, 64.84, 105.09, 173.35, 192.45, 749.05, 1717.97, 3637.13, 9314.25, 18685.30
# ]
    
# ##################################
# # 16 nodes
# ##################################
# cray_mpich1_16n = [
#     12.48, 12.65, 12.68, 13.50, 13.99, 14.10, 14.25, 14.77, 16.05, 16.87,
#     18.87, 21.93, 25.51, 33.22, 47.89, 77.75, 137.68, 257.24, 634.54,
#     1397.51, 2949.17, 6277.91, 19212.84 #, 51606.87
# ]
# argonne_mpich1_16n = [
#     235.90, 238.07, 244.19, 241.59, 237.48, 241.57, 469.14, 631.04,
#     741.22, 810.64, 811.74, 801.23, 819.99, 926.35, 1525.82, 2259.14,
#     3233.22, 3404.72, 3679.86, 4233.94, 6152.53, 12941.89, 28552.10 #, 0
# ]
# openmpi1_16n = [
#     132.81, 127.81, 128.60, 130.53, 135.06, 136.93, 257.27, 338.12, 389.36, 426.34, 476.18,
#     465.89, 467.56, 490.88, 523.00, 550.02, 611.92, 982.98, 1714.65, 3539.51, 7044.12,
#     16045.08, 32135.26
# ]
    
# ##################################
# # 32 nodes
# ##################################
# cray_mpich1_32n = [
#     12.47, 12.65, 12.56, 13.38, 13.89, 14.00, 14.17, 15.03, 15.98, 16.85,
#     18.96, 22.03, 26.18, 34.44, 50.59, 82.91, 146.90, 353.05, 778.20,
#     1670.41, 3514.22, 7426.73, 21469.74 #, 55827.81
# ]
# argonne_mpich1_32n =  [
#     287.81, 288.88, 292.16, 292.63, 291.23, 562.80, 776.28, 945.37,
#     1069.96, 1124.36, 1118.83, 1126.59, 1171.23, 1736.67, 2517.23,
#     3303.85, 4458.06, 4709.07, 4848.24, 6129.24, 8247.47, 15489.43, 32858.05 #, 0
# ]
# openmpi1_32n = [
#     152.06, 157.11, 153.50, 157.32, 156.73, 297.92, 412.66, 485.65, 558.17, 574.94, 581.62,
#     603.90, 600.31, 623.94, 642.63, 693.37, 1095.84, 1878.14, 3561.16, 6801.15, 13449.19,
#     28902.76, 57911.09
# ]
    
# ##########################################################################################################################

# # Number of nodes used
# num_nodes = [2, 4, 8, 16]

# # Message sizes
# sizes = [
#     '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
#     '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB'
# ]

# # Averages latencies for 16MB message size, scaling nodes
# cray_mpich_results = [ cray_mpich_2n_averages[22], cray_mpich_4n_averages[22], cray_mpich_8n_averages[22], cray_mpich_16n_averages[22] ]
# argonne_mpich_results = [ argonne_mpich_2n_averages[22], argonne_mpich_4n_averages[22], argonne_mpich_8n_averages[22], argonne_mpich_16n_averages[22] ]
# openmpi_results = [ openmpi_2n_averages[22], openmpi_4n_averages[22], openmpi_8n_averages[22], openmpi_16n_averages[22] ]

# #----------------------------------------------------------------------------------------
# # Set plot style and create a color palette
# sns.set(style="whitegrid")
# color_palette = sns.color_palette("husl", 3)

# # Set the plot size
# fig, ax = plt.subplots(figsize=(16, 12))

# # Increase font sizes
# plt.rc('font', size=320)         # controls default text sizes

# # Plotting the line plot with larger linewidth and markersize
# ax.plot(num_nodes, cray_mpich_results, marker='x', markersize=10, linewidth=2.5, color=color_palette[1])
# ax.plot(num_nodes, argonne_mpich_results, marker='o', markersize=10, linewidth=2.5, color=color_palette[0])
# ax.plot(num_nodes, openmpi_results, marker="|", markersize=10, linewidth=2.5, color=color_palette[2])

# # Set labels and title
# ax.set_xlabel('Nodes')
# ax.set_ylabel('Average Latency (us)')
# ax.set_title('D2D OSU MPI-CUDA Gather Latency (16 MB Message Size)')

# # Set y ticks
# # # # ax.set_yticks(range(0, 35001, 5000))
# # # ax.set_yticks(range(6000, 35001, 4000))

# # Rotate x-axis labels for better visibility
# plt.xticks(num_nodes, num_nodes)

# # Add a legend and place it outside the plot area
# legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# # Add grid for easier value estimation
# ax.grid(True)

# # Adjust the layout to prevent labels from being cut off
# fig.tight_layout()

# # Display the plot
# plt.show()
