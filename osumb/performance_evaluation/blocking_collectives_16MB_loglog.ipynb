openmpi3_16n = [128.56, 133.67, 135.50, 136.29, 132.90, 133.59, 249.44, 347.21, 406.66, 437.77, 425.54, 452.32, 452.50, 470.67, 496.41, 555.51, 634.18, 1002.97, 1734.87, 3560.07, 7110.29, 16056.86, 32026.04]
openmpi4_16n = [133.82, 132.03, 131.47, 135.02, 139.59, 140.47, 256.07, 339.04, 397.47, 439.14, 441.10, 470.16, 461.42, 481.65, 510.00, 543.92, 614.84, 984.38, 1689.66, 3539.87, 7137.49, 15971.16, 31969.95]
openmpi5_16n = [126.47, 127.15, 131.89, 132.65, 133.25, 130.94, 239.97, 331.56, 396.42, 426.13, 426.67, 438.78, 440.55, 464.80, 487.62, 531.27, 606.84, 961.06, 1715.94, 3512.13, 7238.90, 15949.24, 31989.41]
    
##########################################################################################################################

# Number of nodes used
# num_nodes = [2, 4, 8, 16]
num_nodes = ["2", "4", "8", "16"]
num_nodes_values = [2, 4, 8, 16]

# Message sizes
sizes = ['4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB']


cray_mpich_2n_averages = []
cray_mpich_4n_averages = []
cray_mpich_8n_averages = []
cray_mpich_16n_averages = []

argonne_mpich_2n_averages = []
argonne_mpich_4n_averages = []
argonne_mpich_8n_averages = []
argonne_mpich_16n_averages = []

openmpi_2n_averages = []
openmpi_4n_averages = []
openmpi_8n_averages = []
openmpi_16n_averages = []

for i in range( len( sizes ) ):
    cray_mpich_2n_averages.append(( cray_mpich1_2n[i] + cray_mpich2_2n[i] + cray_mpich3_2n[i] + cray_mpich4_2n[i] + cray_mpich5_2n[i] ) / 5)
    cray_mpich_4n_averages.append(( cray_mpich1_4n[i] + cray_mpich2_4n[i] + cray_mpich3_4n[i] + cray_mpich4_4n[i] + cray_mpich5_4n[i] ) / 5)
    cray_mpich_8n_averages.append(( cray_mpich1_8n[i] + cray_mpich2_8n[i] + cray_mpich3_8n[i] + cray_mpich4_8n[i] + cray_mpich5_8n[i] ) / 5)
    cray_mpich_16n_averages.append(( cray_mpich1_16n[i] + cray_mpich2_16n[i] + cray_mpich3_16n[i] + cray_mpich4_16n[i] + cray_mpich5_16n[i]) / 5)

    argonne_mpich_2n_averages.append(( argonne_mpich1_2n[i] + argonne_mpich2_2n[i] + argonne_mpich3_2n[i] + argonne_mpich4_2n[i] + argonne_mpich5_2n[i] ) / 5)
    argonne_mpich_4n_averages.append(( argonne_mpich1_4n[i] + argonne_mpich2_4n[i] + argonne_mpich3_4n[i] + argonne_mpich4_4n[i] + argonne_mpich5_4n[i] ) / 5)
    argonne_mpich_8n_averages.append(( argonne_mpich1_8n[i] + argonne_mpich2_8n[i] + argonne_mpich3_8n[i] + argonne_mpich4_8n[i] + argonne_mpich5_8n[i] ) / 5)
    argonne_mpich_16n_averages.append(( argonne_mpich1_16n[i] + argonne_mpich2_16n[i] + argonne_mpich3_16n[i] + argonne_mpich4_16n[i] + argonne_mpich5_16n[i] ) / 5)

    openmpi_2n_averages.append(( openmpi1_2n[i] + openmpi2_2n[i] + openmpi3_2n[i] + openmpi4_2n[i] + openmpi5_2n[i] ) / 5)
    openmpi_4n_averages.append(( openmpi1_4n[i] + openmpi2_4n[i] + openmpi3_4n[i] + openmpi4_4n[i] + openmpi5_4n[i] ) / 5)
    openmpi_8n_averages.append(( openmpi1_8n[i] + openmpi2_8n[i] + openmpi3_8n[i] + openmpi4_8n[i] + openmpi5_8n[i] ) / 5)
    openmpi_16n_averages.append(( openmpi1_16n[i] + openmpi2_16n[i] + openmpi3_16n[i] + openmpi4_16n[i] + openmpi5_16n[i] ) / 5)

# Averages latencies for 16MB message size, scaling nodes
cray_mpich_results = [ cray_mpich_2n_averages[22], cray_mpich_4n_averages[22], cray_mpich_8n_averages[22], cray_mpich_16n_averages[22] ]
argonne_mpich_results = [ argonne_mpich_2n_averages[22], argonne_mpich_4n_averages[22], argonne_mpich_8n_averages[22], argonne_mpich_16n_averages[22] ]
openmpi_results = [ openmpi_2n_averages[22], openmpi_4n_averages[22], openmpi_8n_averages[22], openmpi_16n_averages[22] ]

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("colorblind", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(num_nodes, cray_mpich_results, marker='x', markersize=10, linewidth=2.5, color=color_palette[2])
ax.plot(num_nodes, argonne_mpich_results, marker='o', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(num_nodes, openmpi_results, marker="|", markersize=10, linewidth=2.5, color=color_palette[0])

# Set labels and title
ax.set_xlabel('Nodes')
ax.set_ylabel('Average Latency (us)')
# ax.set_title(' OSU MPI-CUDA Gather Latency (16 MB Message Size)')

# plt.xscale('log')
plt.yscale('log')

# Rotate x-axis labels for better visibility
ax.set_xticks(num_nodes)
ax.set_xticklabels(num_nodes)

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='lower right') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save figure
plt.savefig("figures/loglog_blocking_collectives/gather_nodes_BC.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %%
sizes = ['4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB']
size_values = [4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304, 8388608, 16777216]

# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("colorblind", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(size_values, cray_mpich_16n_averages, marker='x', markersize=10, linewidth=2.5, color=color_palette[2])
ax.plot(size_values, argonne_mpich_16n_averages, marker='o', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(size_values, openmpi_16n_averages, marker="|", markersize=10, linewidth=2.5, color=color_palette[0])

# Set labels and title
ax.set_xlabel('Message Size')
ax.set_ylabel('Average Latency (us)')
# ax.set_title(' OSU MPI-CUDA Gather Latency (16 Nodes)')

plt.xscale('log')
plt.yscale('log')

# Rotate x-axis labels for better visibility
ax.set_xticks(size_values)
ax.set_xticklabels(sizes, rotation=45)

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save figure
plt.savefig("figures/loglog_blocking_collectives/gather_messages_BC.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %%
sizes = ['4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K']
size_values = [4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192]
num_elements = len(sizes)

cray_mpich_small = []
argonne_mpich_small = []
openmpi_small = []

for i in range(num_elements):
    cray_mpich_small.append( cray_mpich_16n_averages[i] )
    argonne_mpich_small.append( argonne_mpich_16n_averages[i] )
    openmpi_small.append( openmpi_16n_averages[i] )

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("colorblind", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(size_values, cray_mpich_small, marker='x', markersize=10, linewidth=2.5, color=color_palette[2])
ax.plot(size_values, argonne_mpich_small, marker='o', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(size_values, openmpi_small, marker="|", markersize=10, linewidth=2.5, color=color_palette[0])

# Set labels and title
ax.set_xlabel('Size')
ax.set_ylabel('Latency (us)')
# ax.set_title(' OSU MPI-CUDA Gather Latency (16 Nodes) - Small Messages')

plt.xscale('log')
plt.yscale('log')

# Rotate x-axis labels for better visibility
ax.set_xticks(size_values)
ax.set_xticklabels(sizes, rotation=45)

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='center right') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save plot
plt.savefig("figures/loglog_blocking_collectives/gather_messages_small_BC.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %%
sizes = ['16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB']
size_values = [16384, 32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304, 8388608, 16777216]
num_elements = len(sizes)

cray_mpich_large = []
argonne_mpich_large = []
openmpi_large = []

for i in range(num_elements):
    cray_mpich_large.append( cray_mpich_16n_averages[i+12] )
    argonne_mpich_large.append( argonne_mpich_16n_averages[i+12] )
    openmpi_large.append( openmpi_16n_averages[i+12] )

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("colorblind", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(size_values, cray_mpich_large, marker='x', markersize=10, linewidth=2.5, color=color_palette[2])
ax.plot(size_values, argonne_mpich_large, marker='o', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(size_values, openmpi_large, marker="|", markersize=10, linewidth=2.5, color=color_palette[0])

# Set labels and title
ax.set_xlabel('Size')
ax.set_ylabel('Latency (us)')
# ax.set_title(' OSU MPI-CUDA Gather Latency (16 Nodes) - Large Messages')

plt.xscale('log')
plt.yscale('log')

# Rotate x-axis labels for better visibility
ax.set_xticks(size_values)
ax.set_xticklabels(sizes, rotation=45)


# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='lower right') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save plot
plt.savefig("figures/loglog_blocking_collectives/gather_messages_large_BC.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %% [markdown]
# ### osu_allgather

# %%
##################################
# 2 nodes
##################################
cray_mpich1_2n = [51.95, 51.95, 51.94, 52.70, 46.51, 46.71, 46.62, 43.99, 38.89, 39.38, 40.62, 48.13, 50.87, 53.94, 62.75, 78.84, 116.06, 188.06, 338.48, 626.64, 1198.17, 2513.55, 4903.06]
cray_mpich2_2n = [49.36, 49.30, 49.35, 49.98, 43.01, 42.82, 43.35, 41.60, 36.87, 37.47, 38.81, 42.28, 42.86, 48.51, 55.87, 71.22, 108.38, 174.07, 315.92, 588.16, 1146.62, 2438.18, 4781.67]
cray_mpich3_2n = [50.15, 49.90, 49.87, 50.57, 43.62, 43.45, 48.23, 42.06, 37.14, 37.78, 38.85, 42.74, 42.57, 48.53, 56.91, 72.65, 107.69, 173.28, 310.26, 581.25, 1133.82, 2428.31, 4796.35]
cray_mpich4_2n = [49.89, 49.70, 49.86, 50.38, 43.37, 43.29, 43.72, 42.18, 37.14, 37.76, 39.56, 42.76, 42.55, 49.20, 56.24, 72.14, 107.54, 174.04, 316.04, 588.16, 1139.87, 2435.83, 4800.95]
cray_mpich5_2n = [49.42, 49.46, 49.36, 50.12, 43.12, 42.65, 43.35, 41.59, 36.79, 37.31, 37.99, 42.06, 42.33, 48.29, 55.55, 71.20, 105.73, 172.61, 311.79, 584.19, 1133.52, 2433.19, 4793.21]

argonne_mpich1_2n = [56.29, 56.02, 56.07, 56.69, 48.39, 48.54, 48.76, 49.02, 49.70, 53.70, 55.36, 75.49, 72.08, 54.60, 101.72, 166.29, 216.64, 305.81, 882.27, 1215.81, 1956.19, 3344.96, 6251.40]
argonne_mpich2_2n = [58.10, 57.88, 57.84, 58.42, 50.09, 50.27, 50.41, 50.69, 51.50, 55.07, 56.88, 77.88, 75.32, 55.10, 108.47, 165.49, 218.02, 309.37, 888.76, 1219.37, 1964.39, 3344.01, 6376.56]
argonne_mpich3_2n = [57.13, 57.01, 57.13, 57.61, 49.34, 49.32, 49.56, 49.83, 50.14, 54.43, 56.11, 76.72, 77.08, 54.76, 116.72, 164.23, 216.88, 308.49, 878.21, 1243.12, 1975.90, 3949.67, 7610.04]
argonne_mpich4_2n = [57.18, 56.79, 56.99, 57.21, 49.21, 49.10, 49.36, 49.56, 50.11, 54.04, 55.78, 76.92, 73.23, 58.35, 106.87, 161.22, 216.43, 307.31, 882.81, 1210.47, 1960.99, 3358.90, 6342.86]
argonne_mpich5_16n = [16278.24, 16200.94, 16237.80, 16295.42, 16253.95, 16349.97, 16269.80, 16195.03, 16018.77, 16330.74, 16383.14, 163931.91, 165804.87, 167823.05, 167743.87, 167156.30, 168498.64, 171687.83, 715832.88, 720251.75, 716366.02, 724536.13, 735931.24]

openmpi1_16n = [14895.16, 14880.49, 15073.77, 14916.74, 14963.13, 14104.59, 15125.24, 15241.51, 15260.58, 15412.88, 15489.98, 15093.08, 17434.92, 18621.87, 18203.45, 18683.33, 22555.40, 25496.32, 32174.43, 45165.59, 71801.68, 126027.42, 233648.26]
openmpi2_16n = [14895.16, 14880.49, 15073.77, 14916.74, 14963.13, 14104.59, 15125.24, 15241.51, 15260.58, 15412.88, 15489.98, 15093.08, 17434.92, 18621.87, 18203.45, 18683.33, 22555.40, 25496.32, 32174.43, 45165.59, 71801.68, 126027.42, 233648.26]
openmpi3_16n = [14539.40, 14532.16, 14539.84, 14436.47, 14576.96, 13622.31, 14580.38, 14751.65, 14912.37, 14723.28, 14879.35, 14664.86, 16478.04, 17120.12, 17343.67, 17953.96, 21647.24, 24679.71, 32149.49, 44775.44, 71226.94, 125666.75, 233175.91]
openmpi4_16n = [14702.49, 14887.04, 14944.59, 14881.56, 14872.33, 13837.23, 15228.93, 14847.12, 15187.67, 15359.36, 15270.47, 15091.66, 17765.34, 18148.34, 17910.75, 18722.10, 22484.18, 25326.47, 32485.26, 45215.23, 71395.53, 126336.97, 233345.33]
openmpi5_16n = [14874.20, 14978.48, 14885.39, 15042.86, 14925.59, 14020.37, 15132.03, 15126.96, 15400.18, 15551.56, 15732.18, 15251.97, 17466.53, 17757.84, 18244.50, 19157.91, 22469.13, 25167.96, 32065.33, 45426.00, 72207.41, 126656.48, 235893.18]
    
##########################################################################################################################

# Number of nodes used
num_nodes = ["2", "4", "8", "16"]
num_nodes_values = [2, 4, 8, 16]

# Message sizes
sizes = ['4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB']

cray_mpich_2n_averages = []
cray_mpich_4n_averages = []
cray_mpich_8n_averages = []
cray_mpich_16n_averages = []

argonne_mpich_2n_averages = []
argonne_mpich_4n_averages = []
argonne_mpich_8n_averages = []
argonne_mpich_16n_averages = []

openmpi_2n_averages = []
openmpi_4n_averages = []
openmpi_8n_averages = []
openmpi_16n_averages = []

for i in range( len( sizes ) ):
    cray_mpich_2n_averages.append(( cray_mpich1_2n[i] + cray_mpich2_2n[i] + cray_mpich3_2n[i] + cray_mpich4_2n[i] + cray_mpich5_2n[i] ) / 5)
    cray_mpich_4n_averages.append(( cray_mpich1_4n[i] + cray_mpich2_4n[i] + cray_mpich3_4n[i] + cray_mpich4_4n[i] + cray_mpich5_4n[i] ) / 5)
    cray_mpich_8n_averages.append(( cray_mpich1_8n[i] + cray_mpich2_8n[i] + cray_mpich3_8n[i] + cray_mpich4_8n[i] + cray_mpich5_8n[i] ) / 5)
    cray_mpich_16n_averages.append(( cray_mpich1_16n[i] + cray_mpich2_16n[i] + cray_mpich3_16n[i] + cray_mpich4_16n[i] + cray_mpich5_16n[i]) / 5)

    argonne_mpich_2n_averages.append(( argonne_mpich1_2n[i] + argonne_mpich2_2n[i] + argonne_mpich3_2n[i] + argonne_mpich4_2n[i] + argonne_mpich5_2n[i] ) / 5)
    argonne_mpich_4n_averages.append(( argonne_mpich1_4n[i] + argonne_mpich2_4n[i] + argonne_mpich3_4n[i] + argonne_mpich4_4n[i] + argonne_mpich5_4n[i] ) / 5)
    argonne_mpich_8n_averages.append(( argonne_mpich1_8n[i] + argonne_mpich2_8n[i] + argonne_mpich3_8n[i] + argonne_mpich4_8n[i] + argonne_mpich5_8n[i] ) / 5)
    argonne_mpich_16n_averages.append(( argonne_mpich1_16n[i] + argonne_mpich2_16n[i] + argonne_mpich3_16n[i] + argonne_mpich4_16n[i] + argonne_mpich5_16n[i] ) / 5)

    openmpi_2n_averages.append(( openmpi1_2n[i] + openmpi2_2n[i] + openmpi3_2n[i] + openmpi4_2n[i] + openmpi5_2n[i] ) / 5)
    openmpi_4n_averages.append(( openmpi1_4n[i] + openmpi2_4n[i] + openmpi3_4n[i] + openmpi4_4n[i] + openmpi5_4n[i] ) / 5)
    openmpi_8n_averages.append(( openmpi1_8n[i] + openmpi2_8n[i] + openmpi3_8n[i] + openmpi4_8n[i] + openmpi5_8n[i] ) / 5)
    openmpi_16n_averages.append(( openmpi1_16n[i] + openmpi2_16n[i] + openmpi3_16n[i] + openmpi4_16n[i] + openmpi5_16n[i] ) / 5)

# Averages latencies for 16MB message size, scaling nodes
cray_mpich_results = [ cray_mpich_2n_averages[22], cray_mpich_4n_averages[22], cray_mpich_8n_averages[22], cray_mpich_16n_averages[22] ]
argonne_mpich_results = [ argonne_mpich_2n_averages[22], argonne_mpich_4n_averages[22], argonne_mpich_8n_averages[22], argonne_mpich_16n_averages[22] ]
openmpi_results = [ openmpi_2n_averages[22], openmpi_4n_averages[22], openmpi_8n_averages[22], openmpi_16n_averages[22] ]

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("colorblind", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(num_nodes, cray_mpich_results, marker='x', markersize=10, linewidth=2.5, color=color_palette[2])
ax.plot(num_nodes, argonne_mpich_results, marker='o', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(num_nodes, openmpi_results, marker="|", markersize=10, linewidth=2.5, color=color_palette[0])

# Set labels and title
ax.set_xlabel('Nodes')
ax.set_ylabel('Average Latency (us)')
# ax.set_title(' OSU MPI-CUDA AllGather Latency (16 MB Message Size)')

# plt.xscale('log')
plt.yscale('log')

# Rotate x-axis labels for better visibility
ax.set_xticks(num_nodes)
ax.set_xticklabels(num_nodes)


# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save figure
plt.savefig("figures/loglog_blocking_collectives/allgather_nodes_BC.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %%
sizes = ['4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB']
size_values = [4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304, 8388608, 16777216]

# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("colorblind", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(size_values, cray_mpich_16n_averages, marker='x', markersize=10, linewidth=2.5, color=color_palette[2])
ax.plot(size_values, argonne_mpich_16n_averages, marker='o', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(size_values, openmpi_16n_averages, marker="|", markersize=10, linewidth=2.5, color=color_palette[0])

# Set labels and title
ax.set_xlabel('Message Size')
ax.set_ylabel('Average Latency (us)')
# ax.set_title(' OSU MPI-CUDA AllGather Latency (16 Nodes)')


plt.xscale('log')
plt.yscale('log')

# Rotate x-axis labels for better visibility
ax.set_xticks(size_values)
ax.set_xticklabels(sizes, rotation=45)


# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='lower right') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save figure
plt.savefig("figures/loglog_blocking_collectives/allgather_messages_BC.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %%
sizes = ['4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K']
size_values = [4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192]
num_elements = len(sizes)

cray_mpich_small = []
argonne_mpich_small = []
openmpi_small = []

for i in range(num_elements):
    cray_mpich_small.append( cray_mpich_16n_averages[i] )
    argonne_mpich_small.append( argonne_mpich_16n_averages[i] )
    openmpi_small.append( openmpi_16n_averages[i] )

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("colorblind", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(size_values, cray_mpich_small, marker='x', markersize=10, linewidth=2.5, color=color_palette[2])
ax.plot(size_values, argonne_mpich_small, marker='o', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(size_values, openmpi_small, marker="|", markersize=10, linewidth=2.5, color=color_palette[0])

# Set labels and title
ax.set_xlabel('Size')
ax.set_ylabel('Latency (us)')
# ax.set_title(' OSU MPI-CUDA AllGather Latency (16 Nodes) - Small Messages')


plt.xscale('log')
plt.yscale('log')

# Rotate x-axis labels for better visibility
ax.set_xticks(size_values)
ax.set_xticklabels(sizes, rotation=45)

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='lower left', bbox_to_anchor=(0, 0.1)) #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save plot
plt.savefig("figures/loglog_blocking_collectives/allgather_messages_small_BC.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %%
sizes = ['16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB']
size_values = [16384, 32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304, 8388608, 16777216]

num_elements = len(sizes)

cray_mpich_large = []
argonne_mpich_large = []
openmpi_large = []

for i in range(num_elements):
    cray_mpich_large.append( cray_mpich_16n_averages[i+12] )
    argonne_mpich_large.append( argonne_mpich_16n_averages[i+12] )
    openmpi_large.append( openmpi_16n_averages[i+12] )

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("colorblind", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(size_values, cray_mpich_large, marker='x', markersize=10, linewidth=2.5, color=color_palette[2])
ax.plot(size_values, argonne_mpich_large, marker='o', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(size_values, openmpi_large, marker="|", markersize=10, linewidth=2.5, color=color_palette[0])

# Set labels and title
ax.set_xlabel('Size')
ax.set_ylabel('Latency (us)')
# ax.set_title(' OSU MPI-CUDA AllGather Latency (16 Nodes) - Large Messages')

plt.xscale('log')
plt.yscale('log')

# Rotate x-axis labels for better visibility
ax.set_xticks(size_values)
ax.set_xticklabels(sizes, rotation=45)

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='lower right') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save plot
plt.savefig("figures/loglog_blocking_collectives/allgather_messages_large_BC.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %% [markdown]
# ### osu_reduce

# %%
##################################
# 2 nodes
##################################
cray_mpich1_2n = [14.65, 14.67, 14.94, 15.00, 15.01, 15.30, 16.02, 16.35, 23.62, 24.80, 185.48, 235.36, 236.96, 249.26, 267.89, 302.08, 346.01, 539.44, 872.47, 5531.18, 9305.06, 17663.20, 35396.42]
cray_mpich2_2n = [14.78, 14.59, 14.83, 14.89, 14.90, 15.17, 15.61, 15.69, 22.34, 23.59, 193.47, 244.17, 242.05, 245.05, 268.90, 318.91, 355.84, 593.80, 899.73, 5647.76, 9542.21, 18175.91, 35885.15]
cray_mpich3_2n = [14.50, 14.47, 14.70, 14.78, 14.79, 15.05, 15.62, 15.75, 22.27, 23.31, 189.10, 241.97, 239.85, 247.34, 259.62, 293.53, 386.34, 530.96, 879.28, 5512.18, 9513.41, 18007.61, 35800.60]
cray_mpich4_2n = [14.44, 14.42, 14.69, 14.80, 14.74, 14.96, 15.40, 15.76, 22.25, 23.53, 186.40, 234.06, 236.46, 245.30, 269.29, 294.70, 381.14, 530.00, 878.01, 5511.63, 9584.04, 17592.88, 35169.17]
cray_mpich5_2n = [14.62, 14.54, 14.88, 14.84, 14.83, 15.11, 15.53, 15.86, 22.44, 23.89, 171.38, 217.05, 215.97, 228.49, 249.16, 280.38, 352.26, 523.88, 841.26, 5583.86, 9447.49, 18012.42, 34791.21]

argonne_mpich1_2n = [18.52, 18.44, 18.45, 18.50, 18.45, 18.57, 19.09, 19.15, 19.45, 19.87, 27.07, 28.17, 53.24, 97.01, 235.59, 537.07, 1151.13, 2387.16, 4845.54, 9844.20, 19737.67, 39564.76, 78552.95]
argonne_mpich3_16n = [13.73, 13.70, 13.69, 13.69, 13.70, 13.81, 14.62, 14.98, 15.03, 15.46, 31.72, 33.13, 57.60, 103.34, 200.26, 404.24, 834.68, 1689.32, 3399.52, 6858.88, 13784.91, 27608.65, 54975.17]
argonne_mpich4_16n = [13.68, 13.68, 13.66, 13.73, 13.71, 13.78, 14.82, 14.85, 15.16, 15.57, 32.75, 34.21, 59.26, 106.42, 204.05, 408.88, 839.02, 1693.41, 3403.73, 6844.23, 13646.03, 27286.24, 54974.33]
argonne_mpich5_16n = [13.70, 13.68, 13.70, 13.72, 13.71, 13.78, 14.64, 14.79, 15.11, 15.48, 31.84, 33.30, 57.75, 103.65, 201.33, 405.05, 833.29, 1689.42, 3416.86, 6893.99, 13963.44, 27816.74, 55765.54]

openmpi1_16n = [12.13, 12.08, 12.35, 12.34, 16.43, 17.13, 19.43, 20.10, 21.04, 22.69, 27.30, 34.90, 39.79, 48.37, 54.67, 116.66, 308.05, 751.31, 1661.54, 4516.89, 7062.48, 14310.10, 32429.51]
openmpi2_16n = [12.25, 12.23, 12.48, 12.48, 16.50, 17.17, 19.52, 20.15, 21.14, 22.66, 27.34, 34.95, 39.85, 48.29, 54.77, 116.69, 310.02, 759.33, 1693.21, 4505.57, 7245.44, 14601.62, 32617.46]
openmpi3_16n = [12.46, 12.42, 12.70, 12.70, 16.63, 17.54, 19.70, 20.75, 21.56, 23.25, 27.92, 35.60, 41.00, 49.48, 55.79, 119.61, 325.44, 808.66, 1808.89, 4762.95, 7694.64, 14280.19, 32170.85]
openmpi4_16n = [12.33, 12.30, 12.56, 12.56, 16.62, 17.37, 19.70, 20.46, 21.51, 23.23, 27.38, 35.07, 40.58, 49.16, 55.96, 117.53, 323.63, 819.75, 1825.52, 4858.57, 7771.34, 15611.25, 34777.12]
openmpi5_16n = [12.40, 12.36, 12.64, 12.63, 16.58, 17.39, 19.75, 20.50, 21.44, 23.10, 27.45, 35.08, 40.36, 48.90, 55.44, 124.28, 326.67, 814.11, 1821.53, 4798.28, 7855.98, 15839.47, 34965.91]
    
##########################################################################################################################

# Number of nodes used
num_nodes = ["2", "4", "8", "16"]
num_nodes_values = [2, 4 ,8, 16]

# Message sizes
sizes = ['4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB']
size_values = [4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304, 8388608, 16777216]

cray_mpich_2n_averages = []
cray_mpich_4n_averages = []
cray_mpich_8n_averages = []
cray_mpich_16n_averages = []

argonne_mpich_2n_averages = []
argonne_mpich_4n_averages = []
argonne_mpich_8n_averages = []
argonne_mpich_16n_averages = []

openmpi_2n_averages = []
openmpi_4n_averages = []
openmpi_8n_averages = []
openmpi_16n_averages = []

for i in range( len( sizes ) ):
    cray_mpich_2n_averages.append(( cray_mpich1_2n[i] + cray_mpich2_2n[i] + cray_mpich3_2n[i] + cray_mpich4_2n[i] + cray_mpich5_2n[i] ) / 5)
    cray_mpich_4n_averages.append(( cray_mpich1_4n[i] + cray_mpich2_4n[i] + cray_mpich3_4n[i] + cray_mpich4_4n[i] + cray_mpich5_4n[i] ) / 5)
    cray_mpich_8n_averages.append(( cray_mpich1_8n[i] + cray_mpich2_8n[i] + cray_mpich3_8n[i] + cray_mpich4_8n[i] + cray_mpich5_8n[i] ) / 5)
    cray_mpich_16n_averages.append(( cray_mpich1_16n[i] + cray_mpich2_16n[i] + cray_mpich3_16n[i] + cray_mpich4_16n[i] + cray_mpich5_16n[i]) / 5)

    argonne_mpich_2n_averages.append(( argonne_mpich1_2n[i] + argonne_mpich2_2n[i] + argonne_mpich3_2n[i] + argonne_mpich4_2n[i] + argonne_mpich5_2n[i] ) / 5)
    argonne_mpich_4n_averages.append(( argonne_mpich1_4n[i] + argonne_mpich2_4n[i] + argonne_mpich3_4n[i] + argonne_mpich4_4n[i] + argonne_mpich5_4n[i] ) / 5)
    argonne_mpich_8n_averages.append(( argonne_mpich1_8n[i] + argonne_mpich2_8n[i] + argonne_mpich3_8n[i] + argonne_mpich4_8n[i] + argonne_mpich5_8n[i] ) / 5)
    argonne_mpich_16n_averages.append(( argonne_mpich1_16n[i] + argonne_mpich2_16n[i] + argonne_mpich3_16n[i] + argonne_mpich4_16n[i] + argonne_mpich5_16n[i] ) / 5)

    openmpi_2n_averages.append(( openmpi1_2n[i] + openmpi2_2n[i] + openmpi3_2n[i] + openmpi4_2n[i] + openmpi5_2n[i] ) / 5)
    openmpi_4n_averages.append(( openmpi1_4n[i] + openmpi2_4n[i] + openmpi3_4n[i] + openmpi4_4n[i] + openmpi5_4n[i] ) / 5)
    openmpi_8n_averages.append(( openmpi1_8n[i] + openmpi2_8n[i] + openmpi3_8n[i] + openmpi4_8n[i] + openmpi5_8n[i] ) / 5)
    openmpi_16n_averages.append(( openmpi1_16n[i] + openmpi2_16n[i] + openmpi3_16n[i] + openmpi4_16n[i] + openmpi5_16n[i] ) / 5)

# Averages latencies for 16MB message size, scaling nodes
cray_mpich_results = [ cray_mpich_2n_averages[22], cray_mpich_4n_averages[22], cray_mpich_8n_averages[22], cray_mpich_16n_averages[22] ]
argonne_mpich_results = [ argonne_mpich_2n_averages[22], argonne_mpich_4n_averages[22], argonne_mpich_8n_averages[22], argonne_mpich_16n_averages[22] ]
openmpi_results = [ openmpi_2n_averages[22], openmpi_4n_averages[22], openmpi_8n_averages[22], openmpi_16n_averages[22] ]

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("colorblind", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(num_nodes, cray_mpich_results, marker='x', markersize=10, linewidth=2.5, color=color_palette[2])
ax.plot(num_nodes, argonne_mpich_results, marker='o', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(num_nodes, openmpi_results, marker="|", markersize=10, linewidth=2.5, color=color_palette[0])

# Set labels and title
ax.set_xlabel('Nodes')
ax.set_ylabel('Average Latency (us)')
# ax.set_title(' OSU MPI-CUDA Reduce Latency (16 MB Message Size)')

# plt.xscale('log')
plt.yscale('log')

# Rotate x-axis labels for better visibility
ax.set_xticks(num_nodes)
ax.set_xticklabels(num_nodes, rotation=45)

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='center left', bbox_to_anchor=(0, 0.6)) #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save figure
plt.savefig("figures/loglog_blocking_collectives/reduce_nodes_BC.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %%
sizes = ['4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB']
size_values = [4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304, 8388608, 16777216]

# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("colorblind", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(size_values, cray_mpich_16n_averages, marker='x', markersize=10, linewidth=2.5, color=color_palette[2])
ax.plot(size_values, argonne_mpich_16n_averages, marker='o', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(size_values, openmpi_16n_averages, marker="|", markersize=10, linewidth=2.5, color=color_palette[0])

# Set labels and title
ax.set_xlabel('Message Size')
ax.set_ylabel('Average Latency (us)')
# ax.set_title(' OSU MPI-CUDA Reduce Latency (16 Nodes)')

plt.xscale('log')
plt.yscale('log')

# Rotate x-axis labels for better visibility
ax.set_xticks(size_values)
ax.set_xticklabels(sizes, rotation=45)


# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save figure
plt.savefig("figures/loglog_blocking_collectives/reduce_messages_BC.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %%
sizes = ['4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K']
size_values = [4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192]
num_elements = len(sizes)

cray_mpich_small = []
argonne_mpich_small = []
openmpi_small = []

for i in range(num_elements):
    cray_mpich_small.append( cray_mpich_16n_averages[i] )
    argonne_mpich_small.append( argonne_mpich_16n_averages[i] )
    openmpi_small.append( openmpi_16n_averages[i] )

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("colorblind", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(size_values, cray_mpich_small, marker='x', markersize=10, linewidth=2.5, color=color_palette[2])
ax.plot(size_values, argonne_mpich_small, marker='o', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(size_values, openmpi_small, marker="|", markersize=10, linewidth=2.5, color=color_palette[0])

# Set labels and title
ax.set_xlabel('Size')
ax.set_ylabel('Latency (us)')
# ax.set_title(' OSU MPI-CUDA Reduce Latency (16 Nodes) - Small Messages')

plt.xscale('log')
plt.yscale('log')

# Rotate x-axis labels for better visibility
ax.set_xticks(size_values)
ax.set_xticklabels(sizes, rotation=45)

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save plot
plt.savefig("figures/loglog_blocking_collectives/reduce_messages_small_BC.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %%
sizes = ['16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB']
size_values = [16384, 32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304, 8388608, 16777216]

num_elements = len(sizes)

cray_mpich_large = []
argonne_mpich_large = []
openmpi_large = []

for i in range(num_elements):
    cray_mpich_large.append( cray_mpich_16n_averages[i+12] )
    argonne_mpich_large.append( argonne_mpich_16n_averages[i+12] )
    openmpi_large.append( openmpi_16n_averages[i+12] )

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("colorblind", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(size_values, cray_mpich_large, marker='x', markersize=10, linewidth=2.5, color=color_palette[2])
ax.plot(size_values, argonne_mpich_large, marker='o', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(size_values, openmpi_large, marker="|", markersize=10, linewidth=2.5, color=color_palette[0])

# Set labels and title
ax.set_xlabel('Size')
ax.set_ylabel('Latency (us)')
# ax.set_title(' OSU MPI-CUDA Reduce Latency (16 Nodes) - Large Messages')

plt.xscale('log')
plt.yscale('log')

# Rotate x-axis labels for better visibility
ax.set_xticks(size_values)
ax.set_xticklabels(sizes, rotation=45)

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save plot
plt.savefig("figures/loglog_blocking_collectives/reduce_messages_large_BC.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %% [markdown]
# ### osu_allreduce

# %%
##################################
# 2 nodes
##################################
cray_mpich1_2n = [34.93, 34.74, 35.02, 34.98, 34.94, 35.73, 31.49, 32.41, 31.63, 31.91, 45.72, 48.66, 53.53, 63.56, 82.71, 114.41, 132.00, 142.55, 158.54, 196.40, 271.70, 424.54, 854.81]
cray_mpich2_2n = [33.30, 32.86, 33.12, 33.12, 33.12, 33.95, 29.12, 29.81, 29.22, 29.19, 40.42, 42.84, 47.60, 57.91, 77.86, 105.14, 114.31, 124.45, 141.92, 178.33, 248.85, 398.19, 794.68]
cray_mpich3_2n = [33.14, 33.15, 33.15, 33.09, 32.86, 33.87, 29.17, 29.69, 29.00, 29.26, 40.46, 43.59, 47.32, 57.19, 78.21, 104.35, 115.25, 123.64, 143.64, 178.93, 248.36, 395.51, 787.70]
cray_mpich4_2n = [32.86, 32.78, 32.90, 32.98, 32.96, 33.80, 29.07, 29.74, 29.07, 29.37, 39.85, 42.71, 46.98, 57.61, 79.04, 104.14, 113.48, 124.72, 142.17, 180.74, 250.24, 396.19, 795.41]
', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB']

cray_mpich_2n_averages = []
cray_mpich_4n_averages = []
cray_mpich_8n_averages = []
cray_mpich_16n_averages = []

argonne_mpich_2n_averages = []
argonne_mpich_4n_averages = []
argonne_mpich_8n_averages = []
argonne_mpich_16n_averages = []

openmpi_2n_averages = []
openmpi_4n_averages = []
openmpi_8n_averages = []
openmpi_16n_averages = []

for i in range( len( sizes ) ):
    cray_mpich_2n_averages.append(( cray_mpich1_2n[i] + cray_mpich2_2n[i] + cray_mpich3_2n[i] + cray_mpich4_2n[i] + cray_mpich5_2n[i] ) / 5)
    cray_mpich_4n_averages.append(( cray_mpich1_4n[i] + cray_mpich2_4n[i] + cray_mpich3_4n[i] + cray_mpich4_4n[i] + cray_mpich5_4n[i] ) / 5)
    cray_mpich_8n_averages.append(( cray_mpich1_8n[i] + cray_mpich2_8n[i] + cray_mpich3_8n[i] + cray_mpich4_8n[i] + cray_mpich5_8n[i] ) / 5)
    cray_mpich_16n_averages.append(( cray_mpich1_16n[i] + cray_mpich2_16n[i] + cray_mpich3_16n[i] + cray_mpich4_16n[i] + cray_mpich5_16n[i]) / 5)

    argonne_mpich_2n_averages.append(( argonne_mpich1_2n[i] + argonne_mpich2_2n[i] + argonne_mpich3_2n[i] + argonne_mpich4_2n[i] + argonne_mpich5_2n[i] ) / 5)
    argonne_mpich_4n_averages.append(( argonne_mpich1_4n[i] + argonne_mpich2_4n[i] + argonne_mpich3_4n[i] + argonne_mpich4_4n[i] + argonne_mpich5_4n[i] ) / 5)
    argonne_mpich_8n_averages.append(( argonne_mpich1_8n[i] + argonne_mpich2_8n[i] + argonne_mpich3_8n[i] + argonne_mpich4_8n[i] + argonne_mpich5_8n[i] ) / 5)
    argonne_mpich_16n_averages.append(( argonne_mpich1_16n[i] + argonne_mpich2_16n[i] + argonne_mpich3_16n[i] + argonne_mpich4_16n[i] + argonne_mpich5_16n[i] ) / 5)

    openmpi_2n_averages.append(( openmpi1_2n[i] + openmpi2_2n[i] + openmpi3_2n[i] + openmpi4_2n[i] + openmpi5_2n[i] ) / 5)
    openmpi_4n_averages.append(( openmpi1_4n[i] + openmpi2_4n[i] + openmpi3_4n[i] + openmpi4_4n[i] + openmpi5_4n[i] ) / 5)
    openmpi_8n_averages.append(( openmpi1_8n[i] + openmpi2_8n[i] + openmpi3_8n[i] + openmpi4_8n[i] + openmpi5_8n[i] ) / 5)
    openmpi_16n_averages.append(( openmpi1_16n[i] + openmpi2_16n[i] + openmpi3_16n[i] + openmpi4_16n[i] + openmpi5_16n[i] ) / 5)

# Averages latencies for 16MB message size, scaling nodes
cray_mpich_results = [ cray_mpich_2n_averages[22], cray_mpich_4n_averages[22], cray_mpich_8n_averages[22], cray_mpich_16n_averages[22] ]
argonne_mpich_results = [ argonne_mpich_2n_averages[22], argonne_mpich_4n_averages[22], argonne_mpich_8n_averages[22], argonne_mpich_16n_averages[22] ]
openmpi_results = [ openmpi_2n_averages[22], openmpi_4n_averages[22], openmpi_8n_averages[22], openmpi_16n_averages[22] ]

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("colorblind", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(num_nodes, cray_mpich_results, marker='x', markersize=10, linewidth=2.5, color=color_palette[2])
ax.plot(num_nodes, argonne_mpich_results, marker='o', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(num_nodes, openmpi_results, marker="|", markersize=10, linewidth=2.5, color=color_palette[0])

# Set labels and title
ax.set_xlabel('Nodes')
ax.set_ylabel('Average Latency (us)')
# ax.set_title(' OSU MPI-CUDA AllReduce Latency (16 MB Message Size)')

# plt.xscale('log')
plt.yscale('log')

# Rotate x-axis labels for better visibility
ax.set_xticks(num_nodes)
ax.set_xticklabels(num_nodes)

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='center left', bbox_to_anchor=(0, 0.4)) #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save figure
plt.savefig("figures/loglog_blocking_collectives/allreduce_nodes_BC.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %%
sizes = ['4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB']
size_values = [4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304, 8388608, 16777216]

# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("colorblind", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(size_values, cray_mpich_16n_averages, marker='x', markersize=10, linewidth=2.5, color=color_palette[2])
ax.plot(size_values, argonne_mpich_16n_averages, marker='o', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(size_values, openmpi_16n_averages, marker="|", markersize=10, linewidth=2.5, color=color_palette[0])

# Set labels and title
ax.set_xlabel('Message Size')
ax.set_ylabel('Average Latency (us)')
# ax.set_title(' OSU MPI-CUDA AllReduce Latency (16 Nodes)')

plt.xscale('log')
plt.yscale('log')

# Rotate x-axis labels for better visibility
ax.set_xticks(size_values)
ax.set_xticklabels(sizes, rotation=45)


# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save figure
plt.savefig("figures/loglog_blocking_collectives/allreduce_messages_BC.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %%
sizes = ['4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K']
size_values = [4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192]

num_elements = len(sizes)

cray_mpich_small = []
argonne_mpich_small = []
openmpi_small = []

for i in range(num_elements):
    cray_mpich_small.append( cray_mpich_16n_averages[i] )
    argonne_mpich_small.append( argonne_mpich_16n_averages[i] )
    openmpi_small.append( openmpi_16n_averages[i] )

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("colorblind", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(size_values, cray_mpich_small, marker='x', markersize=10, linewidth=2.5, color=color_palette[2])
ax.plot(size_values, argonne_mpich_small, marker='o', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(size_values, openmpi_small, marker="|", markersize=10, linewidth=2.5, color=color_palette[0])

# Set labels and title
ax.set_xlabel('Size')
ax.set_ylabel('Latency (us)')
# ax.set_title(' OSU MPI-CUDA AllReduce Latency (16 Nodes) - Small Messages')

plt.xscale('log')
plt.yscale('log')

# Rotate x-axis labels for better visibility
ax.set_xticks(size_values)
ax.set_xticklabels(sizes, rotation=45)

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='center left') #, fontsize='large')


# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save plot
plt.savefig("figures/loglog_blocking_collectives/allreduce_messages_small_BC.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %%
sizes = ['16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB']
size_values = [16384, 32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304, 8388608, 16777216]
num_elements = len(sizes)

cray_mpich_large = []
argonne_mpich_large = []
openmpi_large = []

for i in range(num_elements):
    cray_mpich_large.append( cray_mpich_16n_averages[i+12] )
    argonne_mpich_large.append( argonne_mpich_16n_averages[i+12] )
    openmpi_large.append( openmpi_16n_averages[i+12] )

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("colorblind", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(size_values, cray_mpich_large, marker='x', markersize=10, linewidth=2.5, color=color_palette[2])
ax.plot(size_values, argonne_mpich_large, marker='o', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(size_values, openmpi_large, marker="|", markersize=10, linewidth=2.5, color=color_palette[0])

# Set labels and title
ax.set_xlabel('Size')
ax.set_ylabel('Latency (us)')
# ax.set_title(' OSU MPI-CUDA AllReduce Latency (16 Nodes) - Large Messages')

plt.xscale('log')
plt.yscale('log')

# Rotate x-axis labels for better visibility
ax.set_xticks(size_values)
ax.set_xticklabels(sizes, rotation=45)

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save plot
plt.savefig("figures/loglog_blocking_collectives/allreduce_messages_large_BC.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %% [markdown]
# ### osu_bcast

# %%
##################################
# 2 nodes
##################################
cray_mpich1_2n = [23.69, 23.72, 23.92, 23.93, 23.96, 24.47, 18.08, 27.47, 18.80, 19.04, 19.31, 15.40, 16.19, 23.63, 26.68, 29.85, 36.60, 50.04, 77.93, 132.65, 241.78, 469.54, 912.36]
cray_mpich2_2n = [22.07, 21.87, 22.13, 22.12, 22.13, 22.68, 15.97, 24.71, 17.27, 17.44, 17.67, 13.96, 14.50, 18.55, 20.79, 24.19, 30.95, 44.34, 73.62, 127.35, 236.77, 456.80, 897.91]
cray_mpich3_2n = [22.21, 22.09, 22.32, 22.33, 22.40, 22.93, 16.20, 25.03, 17.46, 17.73, 17.80, 14.17, 14.72, 18.69, 20.93, 24.32, 30.89, 44.44, 73.52, 127.57, 236.60, 456.56, 897.50]
', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB']

cray_mpich_2n_averages = []
cray_mpich_4n_averages = []
cray_mpich_8n_averages = []
cray_mpich_16n_averages = []

argonne_mpich_2n_averages = []
argonne_mpich_4n_averages = []
argonne_mpich_8n_averages = []
argonne_mpich_16n_averages = []

openmpi_2n_averages = []
openmpi_4n_averages = []
openmpi_8n_averages = []
openmpi_16n_averages = []

for i in range( len( sizes ) ):
    cray_mpich_2n_averages.append(( cray_mpich1_2n[i] + cray_mpich2_2n[i] + cray_mpich3_2n[i] + cray_mpich4_2n[i] + cray_mpich5_2n[i] ) / 5)
    cray_mpich_4n_averages.append(( cray_mpich1_4n[i] + cray_mpich2_4n[i] + cray_mpich3_4n[i] + cray_mpich4_4n[i] + cray_mpich5_4n[i] ) / 5)
    cray_mpich_8n_averages.append(( cray_mpich1_8n[i] + cray_mpich2_8n[i] + cray_mpich3_8n[i] + cray_mpich4_8n[i] + cray_mpich5_8n[i] ) / 5)
    cray_mpich_16n_averages.append(( cray_mpich1_16n[i] + cray_mpich2_16n[i] + cray_mpich3_16n[i] + cray_mpich4_16n[i] + cray_mpich5_16n[i]) / 5)

    argonne_mpich_2n_averages.append(( argonne_mpich1_2n[i] + argonne_mpich2_2n[i] + argonne_mpich3_2n[i] + argonne_mpich4_2n[i] + argonne_mpich5_2n[i] ) / 5)
    argonne_mpich_4n_averages.append(( argonne_mpich1_4n[i] + argonne_mpich2_4n[i] + argonne_mpich3_4n[i] + argonne_mpich4_4n[i] + argonne_mpich5_4n[i] ) / 5)
    argonne_mpich_8n_averages.append(( argonne_mpich1_8n[i] + argonne_mpich2_8n[i] + argonne_mpich3_8n[i] + argonne_mpich4_8n[i] + argonne_mpich5_8n[i] ) / 5)
    argonne_mpich_16n_averages.append(( argonne_mpich1_16n[i] + argonne_mpich2_16n[i] + argonne_mpich3_16n[i] + argonne_mpich4_16n[i] + argonne_mpich5_16n[i] ) / 5)

    openmpi_2n_averages.append(( openmpi1_2n[i] + openmpi2_2n[i] + openmpi3_2n[i] + openmpi4_2n[i] + openmpi5_2n[i] ) / 5)
    openmpi_4n_averages.append(( openmpi1_4n[i] + openmpi2_4n[i] + openmpi3_4n[i] + openmpi4_4n[i] + openmpi5_4n[i] ) / 5)
    openmpi_8n_averages.append(( openmpi1_8n[i] + openmpi2_8n[i] + openmpi3_8n[i] + openmpi4_8n[i] + openmpi5_8n[i] ) / 5)
    openmpi_16n_averages.append(( openmpi1_16n[i] + openmpi2_16n[i] + openmpi3_16n[i] + openmpi4_16n[i] + openmpi5_16n[i] ) / 5)

# Averages latencies for 16MB message size, scaling nodes
cray_mpich_results = [ cray_mpich_2n_averages[22], cray_mpich_4n_averages[22], cray_mpich_8n_averages[22], cray_mpich_16n_averages[22] ]
argonne_mpich_results = [ argonne_mpich_2n_averages[22], argonne_mpich_4n_averages[22], argonne_mpich_8n_averages[22], argonne_mpich_16n_averages[22] ]
openmpi_results = [ openmpi_2n_averages[22], openmpi_4n_averages[22], openmpi_8n_averages[22], openmpi_16n_averages[22] ]

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("colorblind", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(num_nodes, cray_mpich_results, marker='x', markersize=10, linewidth=2.5, color=color_palette[2])
ax.plot(num_nodes, argonne_mpich_results, marker='o', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(num_nodes, openmpi_results, marker="|", markersize=10, linewidth=2.5, color=color_palette[0])

# Set labels and title
ax.set_xlabel('Nodes')
ax.set_ylabel('Average Latency (us)')
# ax.set_title(' OSU MPI-CUDA Broadcast Latency (16 MB Message Size)')

# plt.xscale('log')
plt.yscale('log')

# Rotate x-axis labels for better visibility
ax.set_xticks(num_nodes)
ax.set_xticklabels(num_nodes)

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='lower right') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save figure
plt.savefig("figures/loglog_blocking_collectives/broadcast_nodes_BC.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %%
sizes = ['4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB']
size_values = [4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304, 8388608, 16777216]


# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("colorblind", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(size_values, cray_mpich_16n_averages, marker='x', markersize=10, linewidth=2.5, color=color_palette[2])
ax.plot(size_values, argonne_mpich_16n_averages, marker='o', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(size_values, openmpi_16n_averages, marker="|", markersize=10, linewidth=2.5, color=color_palette[0])

# Set labels and title
ax.set_xlabel('Message Size')
ax.set_ylabel('Average Latency (us)')
# ax.set_title(' OSU MPI-CUDA Broadcast Latency (16 Nodes)')


plt.xscale('log')
plt.yscale('log')

# Rotate x-axis labels for better visibility
ax.set_xticks(size_values)
ax.set_xticklabels(sizes, rotation=45)


# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save figure
plt.savefig("figures/loglog_blocking_collectives/broadcast_messages_BC.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %%
sizes = ['4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K']
size_values = [4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192]

num_elements = len(sizes)

cray_mpich_small = []
argonne_mpich_small = []
openmpi_small = []

for i in range(num_elements):
    cray_mpich_small.append( cray_mpich_16n_averages[i] )
    argonne_mpich_small.append( argonne_mpich_16n_averages[i] )
    openmpi_small.append( openmpi_16n_averages[i] )

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("colorblind", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(size_values, cray_mpich_small, marker='x', markersize=10, linewidth=2.5, color=color_palette[2])
ax.plot(size_values, argonne_mpich_small, marker='o', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(size_values, openmpi_small, marker="|", markersize=10, linewidth=2.5, color=color_palette[0])

# Set labels and title
ax.set_xlabel('Size')
ax.set_ylabel('Latency (us)')
# ax.set_title(' OSU MPI-CUDA Broadcast Latency (16 Nodes) - Small Messages')

plt.xscale('log')
plt.yscale('log')

# Rotate x-axis labels for better visibility
ax.set_xticks(size_values)
ax.set_xticklabels(sizes, rotation=45)

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='lower left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save plot
plt.savefig("figures/loglog_blocking_collectives/broadcast_messages_small_BC.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %%
sizes = ['16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB']
size_values = [16384, 32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304, 8388608, 16777216]

num_elements = len(sizes)

cray_mpich_large = []
argonne_mpich_large = []
openmpi_large = []

for i in range(num_elements):
    cray_mpich_large.append( cray_mpich_16n_averages[i+12] )
    argonne_mpich_large.append( argonne_mpich_16n_averages[i+12] )
    openmpi_large.append( openmpi_16n_averages[i+12] )

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("colorblind", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(size_values, cray_mpich_large, marker='x', markersize=10, linewidth=2.5, color=color_palette[2])
ax.plot(size_values, argonne_mpich_large, marker='o', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(size_values, openmpi_large, marker="|", markersize=10, linewidth=2.5, color=color_palette[0])

# Set labels and title
ax.set_xlabel('Size')
ax.set_ylabel('Latency (us)')
# ax.set_title(' OSU MPI-CUDA Broadcast Latency (16 Nodes) - Large Messages')

plt.xscale('log')
plt.yscale('log')

# Rotate x-axis labels for better visibility
ax.set_xticks(size_values)
ax.set_xticklabels(sizes, rotation=45)

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save plot
plt.savefig("figures/loglog_blocking_collectives/broadcast_messages_large_BC.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %% [markdown]
# ### osu_alltoall

# %%
##################################
# 2 nodes
##################################
cray_mpich1_2n = [41.45, 41.15, 41.09, 41.83, 46.72, 46.91, 48.12, 49.06, 50.99, 50.25, 51.59, 53.51, 56.66, 59.79, 65.31, 70.18, 105.29, 253.83, 442.10, 829.44, 1644.86, 3286.63, 6542.99]
cray_mpich2_2n = [37.63, 37.53, 37.58, 38.31, 39.47, 40.10, 41.28, 42.83, 50.67, 49.25, 52.81, 52.23, 56.75, 58.69, 61.75, 66.25, 96.07, 228.92, 407.31, 787.83, 1572.41, 3113.85, 6289.02]
openmpi3_16n = [13933.81, 14073.63, 13636.26, 14126.69, 14282.60, 13806.35, 13768.96, 14116.50, 90021.95, 90187.24, 89827.79, 90164.57, 90782.90, 90712.60, 90969.74, 90197.59, 553741.55, 553086.99, 564116.70, 561608.65, 566839.54, 571613.30, 589891.63]
openmpi4_16n = [14733.04, 14532.37, 14872.44, 14274.07, 15245.48, 14272.42, 14826.92, 14170.48, 91389.43, 91210.33, 91389.74, 91336.71, 92482.11, 91766.41, 92272.49, 93205.94, 556961.23, 567718.78, 563438.84, 571864.15, 581267.59, 583572.54, 597752.60]
openmpi5_16n = [15350.27, 15242.17, 14932.82, 14887.48, 15152.56, 15983.90, 15116.55, 15915.93, 90753.06, 90839.96, 91184.56, 91404.79, 92868.12, 91489.10, 92112.70, 92190.70, 566334.42, 575351.11, 574987.92, 577858.26, 581112.48, 589042.80, 612412.64]
    
##########################################################################################################################

# Number of nodes used
num_nodes = ["2", "4", "8", "16"]
num_nodes_values = [2, 4 ,8, 16]

# Message sizes
sizes = ['4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB']
size_values = [4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304, 8388608, 16777216]

cray_mpich_2n_averages = []
cray_mpich_4n_averages = []
cray_mpich_8n_averages = []
cray_mpich_16n_averages = []

argonne_mpich_2n_averages = []
argonne_mpich_4n_averages = []
argonne_mpich_8n_averages = []
argonne_mpich_16n_averages = []

openmpi_2n_averages = []
openmpi_4n_averages = []
openmpi_8n_averages = []
openmpi_16n_averages = []

for i in range( len( sizes ) ):
    cray_mpich_2n_averages.append(( cray_mpich1_2n[i] + cray_mpich2_2n[i] + cray_mpich3_2n[i] + cray_mpich4_2n[i] + cray_mpich5_2n[i] ) / 5)
    cray_mpich_4n_averages.append(( cray_mpich1_4n[i] + cray_mpich2_4n[i] + cray_mpich3_4n[i] + cray_mpich4_4n[i] + cray_mpich5_4n[i] ) / 5)
    cray_mpich_8n_averages.append(( cray_mpich1_8n[i] + cray_mpich2_8n[i] + cray_mpich3_8n[i] + cray_mpich4_8n[i] + cray_mpich5_8n[i] ) / 5)
    cray_mpich_16n_averages.append(( cray_mpich1_16n[i] + cray_mpich2_16n[i] + cray_mpich3_16n[i] + cray_mpich4_16n[i] + cray_mpich5_16n[i]) / 5)

    argonne_mpich_2n_averages.append(( argonne_mpich1_2n[i] + argonne_mpich2_2n[i] + argonne_mpich3_2n[i] + argonne_mpich4_2n[i] + argonne_mpich5_2n[i] ) / 5)
    argonne_mpich_4n_averages.append(( argonne_mpich1_4n[i] + argonne_mpich2_4n[i] + argonne_mpich3_4n[i] + argonne_mpich4_4n[i] + argonne_mpich5_4n[i] ) / 5)
    argonne_mpich_8n_averages.append(( argonne_mpich1_8n[i] + argonne_mpich2_8n[i] + argonne_mpich3_8n[i] + argonne_mpich4_8n[i] + argonne_mpich5_8n[i] ) / 5)
    argonne_mpich_16n_averages.append(( argonne_mpich1_16n[i] + argonne_mpich2_16n[i] + argonne_mpich3_16n[i] + argonne_mpich4_16n[i] + argonne_mpich5_16n[i] ) / 5)

    openmpi_2n_averages.append(( openmpi1_2n[i] + openmpi2_2n[i] + openmpi3_2n[i] + openmpi4_2n[i] + openmpi5_2n[i] ) / 5)
    openmpi_4n_averages.append(( openmpi1_4n[i] + openmpi2_4n[i] + openmpi3_4n[i] + openmpi4_4n[i] + openmpi5_4n[i] ) / 5)
    openmpi_8n_averages.append(( openmpi1_8n[i] + openmpi2_8n[i] + openmpi3_8n[i] + openmpi4_8n[i] + openmpi5_8n[i] ) / 5)
    openmpi_16n_averages.append(( openmpi1_16n[i] + openmpi2_16n[i] + openmpi3_16n[i] + openmpi4_16n[i] + openmpi5_16n[i] ) / 5)

# Averages latencies for 16MB message size, scaling nodes
cray_mpich_results = [ cray_mpich_2n_averages[22], cray_mpich_4n_averages[22], cray_mpich_8n_averages[22], cray_mpich_16n_averages[22] ]
argonne_mpich_results = [ argonne_mpich_2n_averages[22], argonne_mpich_4n_averages[22], argonne_mpich_8n_averages[22], argonne_mpich_16n_averages[22] ]
openmpi_results = [ openmpi_2n_averages[22], openmpi_4n_averages[22], openmpi_8n_averages[22], openmpi_16n_averages[22] ]

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("colorblind", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(num_nodes, cray_mpich_results, marker='x', markersize=10, linewidth=2.5, color=color_palette[2])
ax.plot(num_nodes, argonne_mpich_results, marker='o', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(num_nodes, openmpi_results, marker="|", markersize=10, linewidth=2.5, color=color_palette[0])

# Set labels and title
ax.set_xlabel('Nodes')
ax.set_ylabel('Average Latency (us)')
# ax.set_title(' OSU MPI-CUDA All-to-All Personalized Exchange Latency (16 MB Message Size)')

# plt.xscale('log')
plt.yscale('log')

# Rotate x-axis labels for better visibility
ax.set_xticks(num_nodes)
ax.set_xticklabels(num_nodes)

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save figure
plt.savefig("figures/loglog_blocking_collectives/alltoall_nodes_BC.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %%
sizes = ['4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB']
size_values = [4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304, 8388608, 16777216]

# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("colorblind", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(size_values, cray_mpich_16n_averages, marker='x', markersize=10, linewidth=2.5, color=color_palette[2])
ax.plot(size_values, argonne_mpich_16n_averages, marker='o', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(size_values, openmpi_16n_averages, marker="|", markersize=10, linewidth=2.5, color=color_palette[0])

# Set labels and title
ax.set_xlabel('Message Size')
ax.set_ylabel('Average Latency (us)')
# ax.set_title(' OSU MPI-CUDA All-to-All Personalized Exchange Latency (16 Nodes)')

plt.xscale('log')
plt.yscale('log')

# Rotate x-axis labels for better visibility
ax.set_xticks(size_values)
ax.set_xticklabels(sizes, rotation=45)


# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save figure
plt.savefig("figures/loglog_blocking_collectives/alltoall_messages_BC.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %%
sizes = ['4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K']
size_values = [4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192]

num_elements = len(sizes)

cray_mpich_small = []
argonne_mpich_small = []
openmpi_small = []

for i in range(num_elements):
    cray_mpich_small.append( cray_mpich_16n_averages[i] )
    argonne_mpich_small.append( argonne_mpich_16n_averages[i] )
    openmpi_small.append( openmpi_16n_averages[i] )

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("colorblind", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(size_values, cray_mpich_small, marker='x', markersize=10, linewidth=2.5, color=color_palette[2])
ax.plot(size_values, argonne_mpich_small, marker='o', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(size_values, openmpi_small, marker="|", markersize=10, linewidth=2.5, color=color_palette[0])

# Set labels and title
ax.set_xlabel('Size')
ax.set_ylabel('Latency (us)')
# ax.set_title(' OSU MPI-CUDA All-to-All Personalized Exchange Latency (16 Nodes) - Small Messages')

plt.xscale('log')
plt.yscale('log')

# Rotate x-axis labels for better visibility
ax.set_xticks(size_values)
ax.set_xticklabels(sizes, rotation=45)

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='center right', bbox_to_anchor=(1, 0.4)) #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save plot
plt.savefig("figures/loglog_blocking_collectives/alltoall_messages_small_BC.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %%
sizes = ['16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB']
size_values = [16384, 32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304, 8388608, 16777216]

num_elements = len(sizes)

cray_mpich_large = []
argonne_mpich_large = []
openmpi_large = []

for i in range(num_elements):
    cray_mpich_large.append( cray_mpich_16n_averages[i+12] )
    argonne_mpich_large.append( argonne_mpich_16n_averages[i+12] )
    openmpi_large.append( openmpi_16n_averages[i+12] )

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("colorblind", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(size_values, cray_mpich_large, marker='x', markersize=10, linewidth=2.5, color=color_palette[2])
ax.plot(size_values, argonne_mpich_large, marker='o', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(size_values, openmpi_large, marker="|", markersize=10, linewidth=2.5, color=color_palette[0])

# Set labels and title
ax.set_xlabel('Size')
ax.set_ylabel('Latency (us)')
# ax.set_title(' OSU MPI-CUDA All-to-All Personalized Exchange Latency (16 Nodes) - Large Messages')

plt.xscale('log')
plt.yscale('log')

# Rotate x-axis labels for better visibility
ax.set_xticks(size_values)
ax.set_xticklabels(sizes, rotation=45)

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='lower right') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save plot
plt.savefig("figures/loglog_blocking_collectives/alltoall_messages_large_BC.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %% [markdown]
# ## TEMPLATE:

# %%
# ##################################
# # 2 nodes
# ##################################
# cray_mpich1_2n = []
# cray_mpich2_2n = []
# cray_mpich3_2n = []
# cray_mpich4_2n = []
# cray_mpich5_2n = []

# argonne_mpich1_2n = []
# argonne_mpich2_2n = []
# argonne_mpich3_2n = []
# argonne_mpich4_2n = []
# argonne_mpich5_2n = []

# openmpi1_2n = []
# openmpi2_2n = []
# openmpi3_2n = []
# openmpi4_2n = []
# openmpi5_2n = []

# ##################################
# # 4 nodes
# ##################################
# cray_mpich1_4n = []
# cray_mpich2_4n = []
# cray_mpich3_4n = []
# cray_mpich4_4n = []
# cray_mpich5_4n = []

# argonne_mpich1_4n = []
# argonne_mpich2_4n = []
# argonne_mpich3_4n = []
# argonne_mpich4_4n = []
# argonne_mpich5_4n = []

# openmpi1_4n = []
# openmpi2_4n = []
# openmpi3_4n = []
# openmpi4_4n = []
# openmpi5_4n = []
    
# ##################################
# # 8 nodes
# ##################################
# cray_mpich1_8n = []
# cray_mpich2_8n = []
# cray_mpich3_8n = []
# cray_mpich4_8n = []
# cray_mpich5_8n = []

# argonne_mpich1_8n = []
# argonne_mpich2_8n = []
# argonne_mpich3_8n = []
# argonne_mpich4_8n = []
# argonne_mpich5_8n = []

# openmpi1_8n = []
# openmpi2_8n = []
# openmpi3_8n = []
# openmpi4_8n = []
# openmpi5_8n = []
    
    
# ##################################
# # 16 nodes
# ##################################
# cray_mpich1_16n = []
# cray_mpich2_16n = []
# cray_mpich3_16n = []
# cray_mpich4_16n = []
# cray_mpich5_16n = []

# argonne_mpich1_16n = []
# argonne_mpich2_16n = []
# argonne_mpich3_16n = []
# argonne_mpich4_16n = []
# argonne_mpich5_16n = []

# openmpi1_16n = []
# openmpi2_16n = []
# openmpi3_16n = []
# openmpi4_16n = []
# openmpi5_16n = []
    
# ##########################################################################################################################

# # Number of nodes used
# num_nodes = [2, 4, 8, 16, 32]
# message_sizes = [
#     '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
#     '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB', '32MB'
# ]

# %% [markdown]
# ## TEST

# %%
# ##################################
# # 2 nodes
# ##################################
# cray_mpich1_2n = [
#     13.38, 13.51, 13.37, 13.77, 14.13, 14.26, 14.30, 16.02, 17.43, 17.69,
#     18.82, 21.46, 24.09, 30.19, 41.73, 64.64, 109.87, 199.93, 365.81,
#     665.28, 1263.89, 3141.49, 13318.15 #, 38798.90
# ]
# argonne_mpich1_2n = [
#     15.75, 15.73, 15.78, 15.85, 16.36, 16.47, 16.43, 16.47, 17.31, 18.37,
#     18.86, 25.83, 43.87, 43.66, 71.35, 115.56, 215.29, 388.37, 596.26, 1196.24,
#     2396.99, 5613.51, 14658.02 #, 0
# ]
# openmpi1_2n = [
#     13.71, 13.65, 13.88, 13.86, 14.58, 16.10, 12.15, 12.58, 9.63, 10.87, 11.42, 23.39,
#     26.29, 32.60, 41.87, 61.80, 84.76, 136.24, 237.59, 440.79, 843.22, 3100.02, 6559.36
# ]

# ##################################
# # 4 nodes
# ##################################
# cray_mpich1_4n = [
#     12.88, 12.88, 12.83, 13.65, 14.16, 14.33, 14.47, 15.43, 16.47, 16.82,
#     19.37, 21.87, 24.81, 31.19, 43.77, 68.50, 118.21, 217.02, 407.58, 761.67,
#     1882.81, 4304.93, 15313.57 #, 43271.52
# ]
# argonne_mpich1_4n = [
#     15.71, 15.66, 15.64, 15.85, 16.34, 16.42, 16.50, 16.51,
#     19.70, 20.78, 21.98, 29.44, 50.79, 47.23, 96.39, 172.09,
#     314.94, 465.97, 657.57, 1268.03, 2924.46, 7826.73, 19641.06 #, 0
# ]
# openmpi1_4n = [
#     13.47, 13.43, 13.76, 14.01, 14.58, 16.20, 12.56, 12.78, 10.09, 11.54, 11.92, 26.15,
#     29.26, 37.40, 45.85, 66.26, 94.17, 154.68, 274.40, 512.30, 988.78, 3720.40, 7437.22
# ]
    
# ##################################
# # 8 nodes
# ##################################
# cray_mpich1_8n = [
#     12.98, 12.90, 12.90, 13.78, 14.40, 14.48, 14.65, 15.31, 16.17, 17.34,
#     19.33, 22.05, 25.59, 32.78, 46.58, 74.85, 129.81, 240.91, 453.24,
#     1103.68, 2407.65, 5243.80, 17088.56 #, 47497.69
# ]
# argonne_mpich1_8n = [
#     184.65, 185.16, 186.42, 190.94, 192.31, 191.82, 192.76, 367.34,
#     475.61, 527.51, 527.67, 544.51, 575.98, 571.71, 705.35, 1213.76,
#     1898.35, 2053.15, 2274.18, 2860.57, 4612.78, 10537.40, 24069.26 #, 0
# ]
# openmpi1_8n = [
#     13.26, 13.23, 13.69, 14.06, 14.75, 16.38, 12.50, 13.26, 11.19, 12.21, 12.92, 25.51,
#     31.59, 44.50, 64.84, 105.09, 173.35, 192.45, 749.05, 1717.97, 3637.13, 9314.25, 18685.30
# ]
    
# ##################################
# # 16 nodes
# ##################################
# cray_mpich1_16n = [
#     12.48, 12.65, 12.68, 13.50, 13.99, 14.10, 14.25, 14.77, 16.05, 16.87,
#     18.87, 21.93, 25.51, 33.22, 47.89, 77.75, 137.68, 257.24, 634.54,
#     1397.51, 2949.17, 6277.91, 19212.84 #, 51606.87
# ]
# argonne_mpich1_16n = [
#     235.90, 238.07, 244.19, 241.59, 237.48, 241.57, 469.14, 631.04,
#     741.22, 810.64, 811.74, 801.23, 819.99, 926.35, 1525.82, 2259.14,
#     3233.22, 3404.72, 3679.86, 4233.94, 6152.53, 12941.89, 28552.10 #, 0
# ]
# openmpi1_16n = [
#     132.81, 127.81, 128.60, 130.53, 135.06, 136.93, 257.27, 338.12, 389.36, 426.34, 476.18,
#     465.89, 467.56, 490.88, 523.00, 550.02, 611.92, 982.98, 1714.65, 3539.51, 7044.12,
#     16045.08, 32135.26
# ]
    
# ##################################
# # 32 nodes
# ##################################
# cray_mpich1_32n = [
#     12.47, 12.65, 12.56, 13.38, 13.89, 14.00, 14.17, 15.03, 15.98, 16.85,
#     18.96, 22.03, 26.18, 34.44, 50.59, 82.91, 146.90, 353.05, 778.20,
#     1670.41, 3514.22, 7426.73, 21469.74 #, 55827.81
# ]
# argonne_mpich1_32n =  [
#     287.81, 288.88, 292.16, 292.63, 291.23, 562.80, 776.28, 945.37,
#     1069.96, 1124.36, 1118.83, 1126.59, 1171.23, 1736.67, 2517.23,
#     3303.85, 4458.06, 4709.07, 4848.24, 6129.24, 8247.47, 15489.43, 32858.05 #, 0
# ]
# openmpi1_32n = [
#     152.06, 157.11, 153.50, 157.32, 156.73, 297.92, 412.66, 485.65, 558.17, 574.94, 581.62,
#     603.90, 600.31, 623.94, 642.63, 693.37, 1095.84, 1878.14, 3561.16, 6801.15, 13449.19,
#     28902.76, 57911.09
# ]
    
# ##########################################################################################################################

# # Number of nodes used
# num_nodes = ["2", "4", "8", "16"]

# # Message sizes
# sizes = [
#     '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
#     '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB'
# ]

# # Averages latencies for 16MB message size, scaling nodes
# cray_mpich_results = [ cray_mpich_2n_averages[22], cray_mpich_4n_averages[22], cray_mpich_8n_averages[22], cray_mpich_16n_averages[22] ]
# argonne_mpich_results = [ argonne_mpich_2n_averages[22], argonne_mpich_4n_averages[22], argonne_mpich_8n_averages[22], argonne_mpich_16n_averages[22] ]
# openmpi_results = [ openmpi_2n_averages[22], openmpi_4n_averages[22], openmpi_8n_averages[22], openmpi_16n_averages[22] ]

# #----------------------------------------------------------------------------------------
# # Set plot style and create a color palette
# sns.set(style="whitegrid")
# color_palette = sns.color_palette("colorblind", 3)

# # Set the plot size
# fig, ax = plt.subplots(figsize=(16, 12))

# # Increase font sizes
# plt.rc('font', size=320)         # controls default text sizes

# # Plotting the line plot with larger linewidth and markersize
# ax.plot(num_nodes, cray_mpich_results, marker='x', markersize=10, linewidth=2.5, color=color_palette[2])
# ax.plot(num_nodes, argonne_mpich_results, marker='o', markersize=10, linewidth=2.5, color=color_palette[1])
# ax.plot(num_nodes, openmpi_results, marker="|", markersize=10, linewidth=2.5, color=color_palette[0])

# # Set labels and title
# ax.set_xlabel('Nodes')
# ax.set_ylabel('Average Latency (us)')
# # ax.set_title(' OSU MPI-CUDA Gather Latency (16 MB Message Size)')

# # Set y ticks
# # # ax.set_yticks(range(0, 35001, 5000))
# # ax.set_yticks(range(6000, 35001, 4000))

# # Rotate x-axis labels for better visibility
# plt.xticks(num_nodes, num_nodes)

# # Add a legend and place it outside the plot area
# legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# # Add grid for easier value estimation
# ax.grid(True)

# # Adjust the layout to prevent labels from being cut off
# fig.tight_layout()

# # Display the plot
# plt.show()
