# %% [markdown]
# # Point-to-Point OSU Microbenchmarks

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## TODO
# - Add more y tiks to figures

# %% [markdown]
# ------------------------------

# %% [markdown]
# ## GNU

# %% [markdown]
# ### osu_latency - Latency Test
#     * The latency tests are carried out in a ping-pong fashion. The sender
#     * sends a message with a certain data size to the receiver and waits for a
#     * reply from the receiver. The receiver receives the message from the sender
#     * and sends back a reply with the same data size. Many iterations of this
#     * ping-pong test are carried out and average one-way latency numbers are
#     * obtained. Blocking version of MPI functions (MPI_Send and MPI_Recv) are
#     * used in the tests. This test is available here.
#
# - nodes=2
# - ntasks-per-node=1
# - cpus-per-task=128
# - gpus-per-task=1

# %%
sizes = ['1', '2', '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', '16K', '32K', '64K', '128K', '256K', '512K', '1024K', '2048K', '4096K']
num_elements = len(sizes)

cray_mpich1 = [2.63, 2.65, 2.64, 2.64, 2.64, 2.68, 2.65, 3.19, 2.98, 3.02, 3.09, 3.23, 3.35, 3.72, 4.37, 7.66, 9.03, 11.76, 17.14, 27.95, 49.80, 93.32, 180.84]
cray_mpich2 = [2.65, 2.65, 2.62, 2.61, 2.63, 2.61, 2.61, 3.15, 2.97, 3.02, 3.08, 3.25, 3.37, 3.72, 4.39, 7.65, 9.02, 11.83, 17.18, 27.92, 49.78, 93.36, 180.30]
cray_mpich3 = [2.63, 2.64, 2.65, 2.64, 2.64, 2.65, 2.63, 3.19, 2.99, 3.04, 3.08, 3.21, 3.34, 3.71, 4.36, 7.62, 9.03, 11.78, 17.13, 27.98, 49.80, 93.21, 180.18]
cray_mpich4 = [2.65, 2.64, 2.63, 2.63, 2.64, 2.62, 2.61, 3.14, 2.94, 2.99, 3.07, 3.21, 3.36, 3.72, 4.35, 7.61, 8.98, 11.72, 17.15, 27.98, 49.72, 93.19, 180.78]
cray_mpich5 = [2.66, 2.65, 2.62, 2.63, 2.62, 2.62, 2.64, 3.17, 2.94, 3.00, 3.10, 3.22, 3.37, 3.75, 4.36, 7.59, 8.95, 11.72, 17.12, 27.95, 49.77, 93.28, 180.90]
cray_mpich_averages = []
for i in range(num_elements):
    avg = (cray_mpich1[i] + cray_mpich2[i] + cray_mpich3[i] + cray_mpich4[i] + cray_mpich5[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages.append(avg)


argonne_mpich1 = [2.64, 2.64, 2.62, 2.65, 2.63, 2.63, 2.65, 3.16, 2.96, 3.01, 3.12, 3.25, 3.36, 3.74, 4.36, 7.61, 8.97, 11.71, 17.10, 27.91, 49.72, 93.16, 181.04]
argonne_mpich2 = [2.63, 2.63, 2.63, 2.63, 2.64, 2.63, 2.63, 3.18, 2.97, 3.01, 3.09, 3.23, 3.36, 3.74, 4.35, 7.61, 8.97, 11.74, 17.18, 28.07, 49.92, 93.48, 181.51]
argonne_mpich3 = [2.66, 2.62, 2.63, 2.63, 2.64, 2.64, 2.63, 3.17, 2.97, 3.02, 3.10, 3.25, 3.38, 3.76, 4.40, 7.65, 9.01, 11.75, 17.23, 28.01, 49.81, 93.32, 180.25]
argonne_mpich4 = [2.68, 2.66, 2.63, 2.63, 2.65, 2.64, 2.64, 3.18, 3.04, 3.04, 3.09, 3.25, 3.36, 3.74, 4.37, 7.63, 8.98, 11.75, 17.17, 28.03, 49.93, 94.19, 180.64]
argonne_mpich5 = [2.67, 2.64, 2.63, 2.63, 2.64, 2.65, 2.63, 3.18, 2.98, 3.03, 3.11, 3.26, 3.40, 3.76, 4.38, 7.63, 8.99, 11.72, 17.13, 28.04, 49.93, 93.43, 180.60]
argonne_mpich_averages = []
for i in range(num_elements):
    avg = (argonne_mpich1[i] + argonne_mpich2[i] + argonne_mpich3[i] + argonne_mpich4[i] + argonne_mpich5[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages.append(avg)

openmpi1 = [2.59, 2.59, 2.59, 2.58, 2.58, 2.58, 2.60, 3.11, 2.91, 2.97, 3.05, 3.19, 3.32, 3.71, 4.36, 7.56, 8.93, 11.66, 17.07, 27.88, 49.65, 93.12, 180.06]
openmpi2 = [2.72, 2.68, 2.67, 2.67, 2.68, 2.68, 2.68, 3.22, 2.97, 3.02, 3.09, 3.24, 3.36, 3.77, 4.40, 7.60, 8.96, 11.69, 17.09, 27.95, 49.73, 93.16, 180.27]
openmpi3 = [2.66, 2.64, 2.64, 2.65, 2.65, 2.64, 2.64, 3.18, 2.97, 3.01, 3.08, 3.24, 3.37, 3.76, 4.39, 7.60, 8.96, 11.71, 17.14, 27.99, 49.74, 93.23, 180.81]
openmpi4 = [2.69, 2.67, 2.67, 2.65, 2.66, 2.64, 2.65, 3.18, 3.02, 3.06, 3.12, 3.25, 3.39, 3.79, 4.40, 7.63, 8.99, 11.75, 17.16, 27.99, 49.74, 93.20, 181.46]
openmpi5 = [2.66, 2.65, 2.65, 2.65, 2.63, 2.62, 2.62, 3.17, 2.94, 2.97, 3.06, 3.20, 3.33, 3.71, 4.35, 7.59, 8.96, 11.71, 17.14, 27.96, 49.71, 93.16, 180.71]
openmpi_averages = []
for i in range(num_elements):
    avg = (openmpi1[i] + openmpi2[i] + openmpi3[i] + openmpi4[i] + openmpi5[i]) / 5
    avg = round(avg, 2)
    openmpi_averages.append(avg)

sns.set(style="whitegrid")  # Set the plot style
plt.figure(figsize=(10, 6))  # Set the plot size

# Plotting the line plot
plt.plot(sizes, cray_mpich_averages, marker='x', linewidth=4)
plt.plot(sizes, argonne_mpich_averages, marker='o', linewidth=2)
plt.plot(sizes, openmpi_averages, marker="|", linewidth=1)

# Set labels and title
plt.xlabel('Size')
plt.ylabel('Latency (us)')
plt.title('OSU MPI Latency Test v7.1')

plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility

# Add a legend
plt.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left')

plt.tight_layout()  # Adjust the layout to prevent labels from being cut off
plt.show()  # Display the plot

# %%
sizes = ['1', '2', '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K']

cray_mpich1 = [2.63, 2.65, 2.64, 2.64, 2.64, 2.68, 2.65, 3.19, 2.98, 3.02, 3.09, 3.23, 3.35]
cray_mpich2 = [2.65, 2.65, 2.62, 2.61, 2.63, 2.61, 2.61, 3.15, 2.97, 3.02, 3.08, 3.25, 3.37]
cray_mpich3 = [2.63, 2.64, 2.65, 2.64, 2.64, 2.65, 2.63, 3.19, 2.99, 3.04, 3.08, 3.21, 3.34]
cray_mpich4 = [2.65, 2.64, 2.63, 2.63, 2.64, 2.62, 2.61, 3.14, 2.94, 2.99, 3.07, 3.21, 3.36]
cray_mpich5 = [2.66, 2.65, 2.62, 2.63, 2.62, 2.62, 2.64, 3.17, 2.94, 3.00, 3.10, 3.22, 3.37]
num_elements = len(cray_mpich1)
cray_mpich_averages = []
for i in range(num_elements):
    avg = (cray_mpich1[i] + cray_mpich2[i] + cray_mpich3[i] + cray_mpich4[i] + cray_mpich5[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages.append(avg)

argonne_mpich1 = [2.64, 2.64, 2.62, 2.65, 2.63, 2.63, 2.65, 3.16, 2.96, 3.01, 3.12, 3.25, 3.36]
argonne_mpich2 = [2.63, 2.63, 2.63, 2.63, 2.64, 2.63, 2.63, 3.18, 2.97, 3.01, 3.09, 3.23, 3.36]
argonne_mpich3 = [2.66, 2.62, 2.63, 2.63, 2.64, 2.64, 2.63, 3.17, 2.97, 3.02, 3.10, 3.25, 3.38]
argonne_mpich4 = [2.68, 2.66, 2.63, 2.63, 2.65, 2.64, 2.64, 3.18, 3.04, 3.04, 3.09, 3.25, 3.36]
argonne_mpich5 = [2.67, 2.64, 2.63, 2.63, 2.64, 2.65, 2.63, 3.18, 2.98, 3.03, 3.11, 3.26, 3.40]
argonne_mpich_averages = []
for i in range(num_elements):
    avg = (argonne_mpich1[i] + argonne_mpich2[i] + argonne_mpich3[i] + argonne_mpich4[i] + argonne_mpich5[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages.append(avg)

openmpi1 = [2.59, 2.59, 2.59, 2.58, 2.58, 2.58, 2.60, 3.11, 2.91, 2.97, 3.05, 3.19, 3.32]
openmpi2 = [2.72, 2.68, 2.67, 2.67, 2.68, 2.68, 2.68, 3.22, 2.97, 3.02, 3.09, 3.24, 3.36]
openmpi3 = [2.66, 2.64, 2.64, 2.65, 2.65, 2.64, 2.64, 3.18, 2.97, 3.01, 3.08, 3.24, 3.37]
openmpi4 = [2.69, 2.67, 2.67, 2.65, 2.66, 2.64, 2.65, 3.18, 3.02, 3.06, 3.12, 3.25, 3.39]
openmpi5 = [2.66, 2.65, 2.65, 2.65, 2.63, 2.62, 2.62, 3.17, 2.94, 2.97, 3.06, 3.20, 3.33]
openmpi_averages = []
for i in range(num_elements):
    avg = (openmpi1[i] + openmpi2[i] + openmpi3[i] + openmpi4[i] + openmpi5[i]) / 5
    avg = round(avg, 2)
    openmpi_averages.append(avg)

sns.set(style="whitegrid")  # Set the plot style
plt.figure(figsize=(10, 6))  # Set the plot size

# Plotting the line plot
plt.plot(sizes, cray_mpich_averages, marker='x', linewidth=4)
plt.plot(sizes, argonne_mpich_averages, marker='o', linewidth=2)
plt.plot(sizes, openmpi_averages, marker="|", linewidth=1)


# Set labels and title
plt.xlabel('Size')
plt.ylabel('Latency (us)')
plt.title('OSU MPI Latency Test v7.1')

plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility

# Add a legend
plt.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left')

plt.tight_layout()  # Adjust the layout to prevent labels from being cut off
plt.show()  # Display the plot

# %%
sizes = ['8K', '16K', '32K', '64K', '128K', '256K', '512K', '1024K', '2048K', '4096K']

cray_mpich1 = [3.72, 4.37, 7.66, 9.03, 11.76, 17.14, 27.95, 49.80, 93.32, 180.84]
cray_mpich2 = [3.72, 4.39, 7.65, 9.02, 11.83, 17.18, 27.92, 49.78, 93.36, 180.30]
cray_mpich3 = [3.71, 4.36, 7.62, 9.03, 11.78, 17.13, 27.98, 49.80, 93.21, 180.18]
cray_mpich4 = [3.72, 4.35, 7.61, 8.98, 11.72, 17.15, 27.98, 49.72, 93.19, 180.78]
cray_mpich5 = [3.75, 4.36, 7.59, 8.95, 11.72, 17.12, 27.95, 49.77, 93.28, 180.90]
num_elements = len(cray_mpich1)
cray_mpich_averages = []
for i in range(num_elements):
    avg = (cray_mpich1[i] + cray_mpich2[i] + cray_mpich3[i] + cray_mpich4[i] + cray_mpich5[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages.append(avg)

argonne_mpich1 = [3.74, 4.36, 7.61, 8.97, 11.71, 17.10, 27.91, 49.72, 93.16, 181.04]
argonne_mpich2 = [3.74, 4.35, 7.61, 8.97, 11.74, 17.18, 28.07, 49.92, 93.48, 181.51]
argonne_mpich3 = [3.76, 4.40, 7.65, 9.01, 11.75, 17.23, 28.01, 49.81, 93.32, 180.25]
argonne_mpich4 = [3.74, 4.37, 7.63, 8.98, 11.75, 17.17, 28.03, 49.93, 94.19, 180.64]
argonne_mpich5 = [3.76, 4.38, 7.63, 8.99, 11.72, 17.13, 28.04, 49.93, 93.43, 180.60]
argonne_mpich_averages = []
for i in range(num_elements):
    avg = (argonne_mpich1[i] + argonne_mpich2[i] + argonne_mpich3[i] + argonne_mpich4[i] + argonne_mpich5[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages.append(avg)

openmpi1 = [3.71, 4.36, 7.56, 8.93, 11.66, 17.07, 27.88, 49.65, 93.12, 180.06]
openmpi2 = [3.77, 4.40, 7.60, 8.96, 11.69, 17.09, 27.95, 49.73, 93.16, 180.27]
openmpi3 = [3.76, 4.39, 7.60, 8.96, 11.71, 17.14, 27.99, 49.74, 93.23, 180.81]
openmpi4 = [3.79, 4.40, 7.63, 8.99, 11.75, 17.16, 27.99, 49.74, 93.20, 181.46]
openmpi5 = [3.71, 4.35, 7.59, 8.96, 11.71, 17.14, 27.96, 49.71, 93.16, 180.71]
openmpi_averages = []
for i in range(num_elements):
    avg = (openmpi1[i] + openmpi2[i] + openmpi3[i] + openmpi4[i] + openmpi5[i]) / 5
    avg = round(avg, 2)
    openmpi_averages.append(avg)

sns.set(style="whitegrid")  # Set the plot style
plt.figure(figsize=(10, 6))  # Set the plot size

# Plotting the line plot
plt.plot(sizes, cray_mpich_averages, marker='x', linewidth=4)
plt.plot(sizes, argonne_mpich_averages, marker='o', linewidth=2)
plt.plot(sizes, openmpi_averages, marker="|", linewidth=1)

# Set labels and title
plt.xlabel('Size')
plt.ylabel('Latency (us)')
plt.title('OSU MPI Latency Test v7.1')

plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility

# Add a legend
plt.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left')

plt.tight_layout()  # Adjust the layout to prevent labels from being cut off
plt.show()  # Display the plot

# %% [markdown]
# ### osu_bw - Bandwidth Test
#     * The bandwidth tests are carried out by having the sender sending out a
#     * fixed number (equal to the window size) of back-to-back messages to the
#     * receiver and then waiting for a reply from the receiver. The receiver
#     * sends the reply only after receiving all these messages. This process is
#     * repeated for several iterations and the bandwidth is calculated based on
#     * the elapsed time (from the time sender sends the first message until the
#     * time it receives the reply back from the receiver) and the number of bytes
#     * sent by the sender. The objective of this bandwidth test is to determine
#     * the maximum sustained date rate that can be achieved at the network level.
#     * Thus, non-blocking version of MPI functions (MPI_Isend and MPI_Irecv) are
#     * used in the test. This test is available here.
#
# - nodes=2
# - ntasks-per-node=1
# - cpus-per-task=128
# - gpus-per-task=1

# %%
sizes = ['1', '2', '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', '16K', '32K', '64K', '128K', '256K', '512K', '1024K', '2048K', '4096K']

cray_mpich1 = [0.93, 1.90, 3.81, 7.31, 15.42, 30.40, 61.76, 123.88, 345.49, 651.65, 1355.36, 2686.23, 5400.58, 10242.08, 20014.26, 21170.74, 22631.81, 23193.96, 23599.79, 23758.85, 23879.63, 23896.12, 23965.27]
cray_mpich2 = [0.95, 1.90, 3.81, 7.56, 15.05, 30.90, 59.99, 121.62, 337.52, 655.87, 1332.05, 2729.60, 5419.62, 10799.30, 20151.88, 21167.96, 22628.75, 23249.04, 23641.41, 23837.15, 23902.17, 23945.44, 23977.82]
cray_mpich3 = [0.96, 1.98, 3.89, 7.80, 15.79, 31.58, 62.61, 124.03, 339.75, 692.69, 1342.68, 2706.24, 5327.94, 10757.20, 20132.03, 21102.95, 22639.99, 23252.81, 23637.76, 23833.71, 23913.49, 23958.30, 23977.23]
cray_mpich4 = [0.99, 1.99, 4.05, 8.35, 16.47, 33.98, 66.93, 132.53, 370.50, 738.57, 1419.24, 2903.19, 5678.65, 11434.79, 20124.85, 21171.47, 22667.46, 23253.78, 23660.23, 23836.29, 23915.12, 23962.91, 23988.26]
cray_mpich5 = [0.97, 2.10, 4.14, 8.38, 16.85, 33.83, 65.80, 130.35, 351.01, 729.24, 1456.66, 2804.07, 5742.32, 11365.67, 20133.21, 21183.82, 22342.77, 23178.52, 23590.64, 23830.03, 23906.67, 23958.22, 23967.53]
num_elements = len(cray_mpich1)
cray_mpich_averages = []
for i in range(num_elements):
    avg = (cray_mpich1[i] + cray_mpich2[i] + cray_mpich3[i] + cray_mpich4[i] + cray_mpich5[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages.append(avg)

argonne_mpich1 = [0.94, 1.92, 3.77, 7.57, 15.10, 31.08, 62.05, 124.07, 353.12, 679.75, 1392.98, 2797.92, 5414.84, 10693.67, 19812.26, 21149.67, 22636.34, 23250.71, 23630.04, 23782.23, 23902.64, 23935.85, 23959.43]
argonne_mpich2 = [0.95, 1.97, 3.97, 7.96, 15.90, 31.26, 63.57, 127.77, 347.52, 686.13, 1410.53, 2694.99, 5607.48, 11187.47, 19842.52, 21117.11, 22645.95, 23267.95, 23650.49, 23831.26, 23902.07, 23911.36, 23964.63]
argonne_mpich3 = [0.96, 1.95, 3.97, 7.76, 15.69, 31.94, 62.47, 126.73, 355.53, 696.40, 1347.24, 2820.67, 5490.66, 10665.27, 20191.33, 21097.77, 22616.74, 23248.35, 23641.94, 23836.49, 23916.29, 23963.14, 23984.09]
argonne_mpich4 = [1.00, 2.00, 3.92, 8.03, 16.03, 32.03, 63.54, 127.06, 341.68, 708.36, 1409.26, 2756.28, 5571.52, 10637.13, 20133.00, 21145.10, 22657.42, 23180.63, 23609.91, 23806.60, 23878.67, 23922.63, 23979.08]
argonne_mpich5 = [0.96, 1.90, 3.81, 7.66, 14.87, 30.83, 61.85, 122.76, 335.61, 677.39, 1332.39, 2652.50, 5336.77, 10587.33, 19527.66, 21171.19, 22624.37, 23241.99, 23645.67, 23825.60, 23864.75, 23925.65, 23976.31]
argonne_mpich_averages = []
for i in range(num_elements):
    avg = (argonne_mpich1[i] + argonne_mpich2[i] + argonne_mpich3[i] + argonne_mpich4[i] + argonne_mpich5[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages.append(avg)

openmpi1 = [0.97, 2.01, 4.14, 8.19, 16.35, 31.82, 66.27, 126.31, 361.38, 701.95, 1447.83, 2762.23, 5657.49, 11047.97, 20118.84, 21182.17, 22660.38, 23272.15, 23656.73, 23820.97, 23919.93, 23965.21, 23979.43]
openmpi2 = [0.92, 1.94, 3.99, 7.88, 16.09, 32.61, 64.42, 128.60, 360.16, 693.13, 1439.74, 2843.20, 5460.27, 11024.18, 20232.62, 21170.91, 22689.13, 23270.60, 23665.47, 23833.69, 23906.05, 23957.18, 23969.27]
openmpi3 = [0.99, 1.99, 3.98, 7.81, 15.88, 31.87, 63.62, 126.54, 349.70, 662.96, 1418.72, 2901.98, 5762.47, 11198.36, 19894.96, 21206.01, 22610.11, 23262.76, 23650.72, 23837.31, 23916.72, 23963.67, 23972.18]
openmpi4 = [1.04, 2.08, 4.07, 8.46, 16.26, 34.31, 67.78, 135.41, 366.92, 738.03, 1424.79, 2873.42, 5723.08, 11541.85, 20199.26, 21153.71, 22683.89, 23274.67, 23661.93, 23825.94, 23922.34, 23955.45, 23972.21]
openmpi5 = [1.00, 2.14, 4.31, 8.57, 16.95, 34.32, 66.55, 134.75, 363.82, 716.29, 1442.78, 2884.05, 5512.27, 10983.43, 20009.98, 21173.49, 22665.85, 23288.05, 23666.36, 23837.11, 23923.21, 23966.43, 23981.97]
openmpi_averages = []
for i in range(num_elements):
    avg = (openmpi1[i] + openmpi2[i] + openmpi3[i] + openmpi4[i] + openmpi5[i]) / 5
    avg = round(avg, 2)
    openmpi_averages.append(avg)

sns.set(style="whitegrid")  # Set the plot style
plt.figure(figsize=(10, 6))  # Set the plot size

# Plotting the line plot
plt.plot(sizes, cray_mpich_averages, marker='x', linewidth=4)
plt.plot(sizes, argonne_mpich_averages, marker='o', linewidth=2)
plt.plot(sizes, openmpi_averages, marker="|", linewidth=1)

# Set labels and title
plt.xlabel('Size')
plt.ylabel('Bandwidth (MB/s)')
plt.title('OSU MPI Bandwidth Test v7.1')

plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility

# Add a legend
plt.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left')

plt.tight_layout()  # Adjust the layout to prevent labels from being cut off
plt.show()  # Display the plot

# %%
sizes = ['1', '2', '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K']

cray_mpich1 = [0.93, 1.90, 3.81, 7.31, 15.42, 30.40, 61.76, 123.88, 345.49, 651.65, 1355.36, 2686.23, 5400.58]
cray_mpich2 = [0.95, 1.90, 3.81, 7.56, 15.05, 30.90, 59.99, 121.62, 337.52, 655.87, 1332.05, 2729.60, 5419.62]
cray_mpich3 = [0.96, 1.98, 3.89, 7.80, 15.79, 31.58, 62.61, 124.03, 339.75, 692.69, 1342.68, 2706.24, 5327.94]
cray_mpich4 = [0.99, 1.99, 4.05, 8.35, 16.47, 33.98, 66.93, 132.53, 370.50, 738.57, 1419.24, 2903.19, 5678.65]
cray_mpich5 = [0.97, 2.10, 4.14, 8.38, 16.85, 33.83, 65.80, 130.35, 351.01, 729.24, 1456.66, 2804.07, 5742.32]
num_elements = len(cray_mpich1)
cray_mpich_averages = []
for i in range(num_elements):
    avg = (cray_mpich1[i] + cray_mpich2[i] + cray_mpich3[i] + cray_mpich4[i] + cray_mpich5[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages.append(avg)

argonne_mpich1 = [0.94, 1.92, 3.77, 7.57, 15.10, 31.08, 62.05, 124.07, 353.12, 679.75, 1392.98, 2797.92, 5414.84]
argonne_mpich2 = [0.95, 1.97, 3.97, 7.96, 15.90, 31.26, 63.57, 127.77, 347.52, 686.13, 1410.53, 2694.99, 5607.48]
argonne_mpich3 = [0.96, 1.95, 3.97, 7.76, 15.69, 31.94, 62.47, 126.73, 355.53, 696.40, 1347.24, 2820.67, 5490.66]
argonne_mpich4 = [1.00, 2.00, 3.92, 8.03, 16.03, 32.03, 63.54, 127.06, 341.68, 708.36, 1409.26, 2756.28, 5571.52]
argonne_mpich5 = [0.96, 1.90, 3.81, 7.66, 14.87, 30.83, 61.85, 122.76, 335.61, 677.39, 1332.39, 2652.50, 5336.77]
argonne_mpich_averages = []
for i in range(num_elements):
    avg = (argonne_mpich1[i] + argonne_mpich2[i] + argonne_mpich3[i] + argonne_mpich4[i] + argonne_mpich5[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages.append(avg)

openmpi1 = [0.97, 2.01, 4.14, 8.19, 16.35, 31.82, 66.27, 126.31, 361.38, 701.95, 1447.83, 2762.23, 5657.49]
openmpi2 = [0.92, 1.94, 3.99, 7.88, 16.09, 32.61, 64.42, 128.60, 360.16, 693.13, 1439.74, 2843.20, 5460.27]
openmpi3 = [0.99, 1.99, 3.98, 7.81, 15.88, 31.87, 63.62, 126.54, 349.70, 662.96, 1418.72, 2901.98, 5762.47]
openmpi4 = [1.04, 2.08, 4.07, 8.46, 16.26, 34.31, 67.78, 135.41, 366.92, 738.03, 1424.79, 2873.42, 5723.08]
openmpi5 = [1.00, 2.14, 4.31, 8.57, 16.95, 34.32, 66.55, 134.75, 363.82, 716.29, 1442.78, 2884.05, 5512.27]
openmpi_averages = []
for i in range(num_elements):
    avg = (openmpi1[i] + openmpi2[i] + openmpi3[i] + openmpi4[i] + openmpi5[i]) / 5
    avg = round(avg, 2)
    openmpi_averages.append(avg)

sns.set(style="whitegrid")  # Set the plot style
plt.figure(figsize=(10, 6))  # Set the plot size

# Plotting the line plot
plt.plot(sizes, cray_mpich_averages, marker='x', linewidth=4)
plt.plot(sizes, argonne_mpich_averages, marker='o', linewidth=2)
plt.plot(sizes, openmpi_averages, marker="|", linewidth=1)

# Set labels and title
plt.xlabel('Size')
plt.ylabel('Bandwidth (MB/s)')
plt.title('OSU MPI Bandwidth Test v7.1')

plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility

# Add a legend
plt.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left')

plt.tight_layout()  # Adjust the layout to prevent labels from being cut off
plt.show()  # Display the plot

# %%
sizes = ['8K', '16K', '32K', '64K', '128K', '256K', '512K', '1024K', '2048K', '4096K']

cray_mpich1 = [10242.08, 20014.26, 21170.74, 22631.81, 23193.96, 23599.79, 23758.85, 23879.63, 23896.12, 23965.27]
cray_mpich2 = [10799.30, 20151.88, 21167.96, 22628.75, 23249.04, 23641.41, 23837.15, 23902.17, 23945.44, 23977.82]
cray_mpich3 = [10757.20, 20132.03, 21102.95, 22639.99, 23252.81, 23637.76, 23833.71, 23913.49, 23958.30, 23977.23]
cray_mpich4 = [11434.79, 20124.85, 21171.47, 22667.46, 23253.78, 23660.23, 23836.29, 23915.12, 23962.91, 23988.26]
cray_mpich5 = [11365.67, 20133.21, 21183.82, 22342.77, 23178.52, 23590.64, 23830.03, 23906.67, 23958.22, 23967.53]
num_elements = len(cray_mpich1)
cray_mpich_averages = []
for i in range(num_elements):
    avg = (cray_mpich1[i] + cray_mpich2[i] + cray_mpich3[i] + cray_mpich4[i] + cray_mpich5[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages.append(avg)

argonne_mpich1 = [10693.67, 19812.26, 21149.67, 22636.34, 23250.71, 23630.04, 23782.23, 23902.64, 23935.85, 23959.43]
argonne_mpich2 = [11187.47, 19842.52, 21117.11, 22645.95, 23267.95, 23650.49, 23831.26, 23902.07, 23911.36, 23964.63]
argonne_mpich3 = [10665.27, 20191.33, 21097.77, 22616.74, 23248.35, 23641.94, 23836.49, 23916.29, 23963.14, 23984.09]
argonne_mpich4 = [10637.13, 20133.00, 21145.10, 22657.42, 23180.63, 23609.91, 23806.60, 23878.67, 23922.63, 23979.08]
argonne_mpich5 = [10587.33, 19527.66, 21171.19, 22624.37, 23241.99, 23645.67, 23825.60, 23864.75, 23925.65, 23976.31]
argonne_mpich_averages = []
for i in range(num_elements):
    avg = (argonne_mpich1[i] + argonne_mpich2[i] + argonne_mpich3[i] + argonne_mpich4[i] + argonne_mpich5[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages.append(avg)

openmpi1 = [11047.97, 20118.84, 21182.17, 22660.38, 23272.15, 23656.73, 23820.97, 23919.93, 23965.21, 23979.43]
openmpi2 = [11024.18, 20232.62, 21170.91, 22689.13, 23270.60, 23665.47, 23833.69, 23906.05, 23957.18, 23969.27]
openmpi3 = [11198.36, 19894.96, 21206.01, 22610.11, 23262.76, 23650.72, 23837.31, 23916.72, 23963.67, 23972.18]
openmpi4 = [11541.85, 20199.26, 21153.71, 22683.89, 23274.67, 23661.93, 23825.94, 23922.34, 23955.45, 23972.21]
openmpi5 = [10983.43, 20009.98, 21173.49, 22665.85, 23288.05, 23666.36, 23837.11, 23923.21, 23966.43, 23981.97]
openmpi_averages = []
for i in range(num_elements):
    avg = (openmpi1[i] + openmpi2[i] + openmpi3[i] + openmpi4[i] + openmpi5[i]) / 5
    avg = round(avg, 2)
    openmpi_averages.append(avg)

sns.set(style="whitegrid")  # Set the plot style
plt.figure(figsize=(10, 6))  # Set the plot size

# Plotting the line plot
plt.plot(sizes, cray_mpich_averages, marker='x', linewidth=4)
plt.plot(sizes, argonne_mpich_averages, marker='o', linewidth=2)
plt.plot(sizes, openmpi_averages, marker="|", linewidth=1)

# Set labels and title
plt.xlabel('Size')
plt.ylabel('Bandwidth (MB/s)')
plt.title('OSU MPI Bandwidth Test v7.1')

plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility

# Add a legend
plt.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left')

plt.tight_layout()  # Adjust the layout to prevent labels from being cut off
plt.show()  # Display the plot

# %% [markdown]
# ### osu_bibw - Bidirectional Bandwidth Test
#     * The bidirectional bandwidth test is similar to the bandwidth test, except
#     * that both the nodes involved send out a fixed number of back-to-back
#     * messages and wait for the reply. This test measures the maximum
#     * sustainable aggregate bandwidth by two nodes. This test is available here.
#
# - nodes=2
# - ntasks-per-node=1
# - cpus-per-task=128
# - gpus-per-task=1

# %%
sizes = ['1', '2', '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', '16K', '32K', '64K', '128K', '256K', '512K', '1024K', '2048K', '4096K']

cray_mpich1 = [1.17, 2.36, 4.72, 9.54, 19.18, 37.95, 77.74, 155.52, 379.89, 739.27, 1526.85, 3062.47, 6016.56, 11978.53, 22067.43, 27802.03, 30688.09, 35651.84, 37454.01, 42625.20, 42647.36, 42911.64, 42579.51]
cray_mpich2 = [1.21, 2.48, 4.94, 9.93, 19.81, 39.20, 77.97, 159.14, 388.13, 760.72, 1533.52, 3020.03, 5578.63, 12157.75, 22048.80, 27298.37, 33301.30, 38257.84, 40127.84, 41906.74, 42594.57, 43359.85, 42243.98]
cray_mpich3 = [1.19, 2.48, 4.96, 9.76, 20.10, 39.95, 79.27, 160.45, 387.09, 777.03, 1530.97, 3050.38, 6025.71, 12057.77, 22109.04, 26839.19, 34049.00, 39034.72, 42218.34, 43524.79, 44093.19, 43998.40, 42448.92]
cray_mpich4 = [1.15, 2.48, 4.98, 9.77, 19.65, 39.69, 78.00, 159.72, 383.05, 767.26, 1522.77, 3116.94, 6133.63, 12100.71, 21251.81, 27863.00, 33806.40, 37497.50, 40011.71, 41284.51, 41661.14, 41870.80, 42611.59]
cray_mpich5 = [1.15, 2.37, 4.71, 9.69, 19.74, 39.66, 77.58, 159.87, 389.20, 770.93, 1534.29, 3136.01, 6043.18, 12455.25, 19964.33, 25995.65, 32385.29, 37814.88, 40217.64, 41881.48, 42236.10, 42655.79, 42722.18]
num_elements = len(cray_mpich1)
cray_mpich_averages = []
for i in range(num_elements):
    avg = (cray_mpich1[i] + cray_mpich2[i] + cray_mpich3[i] + cray_mpich4[i] + cray_mpich5[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages.append(avg)

argonne_mpich1 = [1.18, 2.38, 4.73, 9.49, 19.26, 38.44, 76.87, 150.90, 372.46, 766.35, 1514.42, 3000.07, 5845.30, 11915.50, 21463.05, 26630.24, 32811.28, 37615.45, 39172.01, 39695.59, 39303.67, 40488.82, 39843.21]
argonne_mpich2 = [1.15, 2.35, 4.74, 9.36, 18.94, 38.45, 75.98, 150.37, 366.04, 738.95, 1499.91, 3002.22, 5863.56, 11990.81, 22087.39, 27872.62, 32556.57, 36673.30, 38610.16, 40562.36, 41142.53, 41372.68, 39499.15]
argonne_mpich3 = [1.13, 2.29, 4.71, 9.40, 18.47, 38.47, 76.83, 154.01, 374.99, 721.55, 1479.05, 3027.78, 6069.94, 12011.19, 20601.39, 27712.29, 33184.72, 37076.34, 39333.55, 40043.07, 40435.00, 40478.42, 41782.03]
argonne_mpich4 = [1.20, 2.37, 4.85, 9.57, 19.51, 37.91, 77.80, 152.07, 378.17, 760.89, 1520.67, 3006.06, 5891.13, 11838.78, 20392.15, 27062.08, 33768.25, 36330.55, 39573.75, 39631.75, 41137.28, 41472.01, 40515.28]
argonne_mpich5 = [1.16, 2.41, 4.86, 9.73, 19.66, 38.94, 78.55, 154.65, 372.73, 776.28, 1525.64, 3031.43, 6053.03, 12071.46, 21051.42, 27647.32, 33736.18, 37237.20, 39964.92, 41127.66, 41707.42, 42406.35, 41119.86]
argonne_mpich_averages = []
for i in range(num_elements):
    avg = (argonne_mpich1[i] + argonne_mpich2[i] + argonne_mpich3[i] + argonne_mpich4[i] + argonne_mpich5[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages.append(avg)
    
openmpi1 = [1.19, 2.39, 4.93, 10.13, 20.00, 40.41, 80.85, 159.49, 377.10, 770.81, 1530.00, 3015.45, 5953.72, 11856.61, 20771.44, 26646.89, 33355.01, 37554.52, 39628.46, 40442.88, 41459.42, 42669.32, 42828.28]
openmpi2 = [1.20, 2.48, 4.85, 9.69, 19.91, 39.70, 79.65, 157.19, 370.60, 769.35, 1529.86, 3039.53, 6009.75, 12238.44, 21567.21, 26837.96, 33491.83, 37212.19, 39308.57, 39919.31, 40671.56, 41675.25, 42409.18]
openmpi3 = [1.13, 2.34, 4.68, 9.27, 18.84, 37.96, 73.48, 151.24, 371.79, 741.82, 1449.87, 2948.19, 5899.16, 11577.33, 21781.98, 26485.32, 33458.87, 37502.99, 39476.84, 40096.21, 40720.40, 41195.62, 42154.50]
openmpi4 = [1.18, 2.36, 4.71, 9.75, 19.55, 38.52, 78.96, 155.70, 379.72, 752.32, 1543.94, 3034.05, 6015.83, 12175.13, 22182.84, 26637.39, 33169.14, 36987.32, 37776.82, 39104.09, 39318.88, 38681.20, 39688.18]
openmpi5 = [1.20, 2.45, 5.00, 10.00, 20.30, 40.50, 78.79, 157.07, 397.37, 784.37, 1527.90, 3111.68, 6137.36, 12482.73, 22165.13, 26941.79, 33307.18, 38901.57, 40550.21, 41700.39, 42903.93, 43634.62, 42585.31]
openmpi_averages = []
for i in range(num_elements):
    avg = (openmpi1[i] + openmpi2[i] + openmpi3[i] + openmpi4[i] + openmpi5[i]) / 5
    avg = round(avg, 2)
    openmpi_averages.append(avg)

sns.set(style="whitegrid")  # Set the plot style
plt.figure(figsize=(10, 6))  # Set the plot size

# Plotting the line plot
plt.plot(sizes, cray_mpich_averages, marker='x', linewidth=4)
plt.plot(sizes, argonne_mpich_averages, marker='o', linewidth=2)
plt.plot(sizes, openmpi_averages, marker="|", linewidth=1)

# Set labels and title
plt.xlabel('Size')
plt.ylabel('Bandwidth (MB/s)')
plt.title('OSU MPI Bi-Directional Bandwidth Test v7.1')

plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility

# Add a legend
plt.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left')

plt.tight_layout()  # Adjust the layout to prevent labels from being cut off
plt.show()  # Display the plot

# %%
sizes = ['1', '2', '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K']

cray_mpich1 = [1.17, 2.36, 4.72, 9.54, 19.18, 37.95, 77.74, 155.52, 379.89, 739.27, 1526.85, 3062.47, 6016.56]
cray_mpich2 = [1.21, 2.48, 4.94, 9.93, 19.81, 39.20, 77.97, 159.14, 388.13, 760.72, 1533.52, 3020.03, 5578.63]
cray_mpich3 = [1.19, 2.48, 4.96, 9.76, 20.10, 39.95, 79.27, 160.45, 387.09, 777.03, 1530.97, 3050.38, 6025.71]
cray_mpich4 = [1.15, 2.48, 4.98, 9.77, 19.65, 39.69, 78.00, 159.72, 383.05, 767.26, 1522.77, 3116.94, 6133.63]
cray_mpich5 = [1.15, 2.37, 4.71, 9.69, 19.74, 39.66, 77.58, 159.87, 389.20, 770.93, 1534.29, 3136.01, 6043.18]
num_elements = len(cray_mpich1)
cray_mpich_averages = []
for i in range(num_elements):
    avg = (cray_mpich1[i] + cray_mpich2[i] + cray_mpich3[i] + cray_mpich4[i] + cray_mpich5[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages.append(avg)

argonne_mpich1 = [1.18, 2.38, 4.73, 9.49, 19.26, 38.44, 76.87, 150.90, 372.46, 766.35, 1514.42, 3000.07, 5845.30]
argonne_mpich2 = [1.15, 2.35, 4.74, 9.36, 18.94, 38.45, 75.98, 150.37, 366.04, 738.95, 1499.91, 3002.22, 5863.56]
argonne_mpich3 = [1.13, 2.29, 4.71, 9.40, 18.47, 38.47, 76.83, 154.01, 374.99, 721.55, 1479.05, 3027.78, 6069.94]
argonne_mpich4 = [1.20, 2.37, 4.85, 9.57, 19.51, 37.91, 77.80, 152.07, 378.17, 760.89, 1520.67, 3006.06, 5891.13]
argonne_mpich5 = [1.16, 2.41, 4.86, 9.73, 19.66, 38.94, 78.55, 154.65, 372.73, 776.28, 1525.64, 3031.43, 6053.03]
argonne_mpich_averages = []
for i in range(num_elements):
    avg = (argonne_mpich1[i] + argonne_mpich2[i] + argonne_mpich3[i] + argonne_mpich4[i] + argonne_mpich5[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages.append(avg)

openmpi1 = [1.19, 2.39, 4.93, 10.13, 20.00, 40.41, 80.85, 159.49, 377.10, 770.81, 1530.00, 3015.45, 5953.72]
openmpi2 = [1.20, 2.48, 4.85, 9.69, 19.91, 39.70, 79.65, 157.19, 370.60, 769.35, 1529.86, 3039.53, 6009.75]
openmpi3 = [1.13, 2.34, 4.68, 9.27, 18.84, 37.96, 73.48, 151.24, 371.79, 741.82, 1449.87, 2948.19, 5899.16]
openmpi4 = [1.18, 2.36, 4.71, 9.75, 19.55, 38.52, 78.96, 155.70, 379.72, 752.32, 1543.94, 3034.05, 6015.83]
openmpi5 = [1.20, 2.45, 5.00, 10.00, 20.30, 40.50, 78.79, 157.07, 397.37, 784.37, 1527.90, 3111.68, 6137.36]
openmpi_averages = []
for i in range(num_elements):
    avg = (openmpi1[i] + openmpi2[i] + openmpi3[i] + openmpi4[i] + openmpi5[i]) / 5
    avg = round(avg, 2)
    openmpi_averages.append(avg)

sns.set(style="whitegrid")  # Set the plot style
plt.figure(figsize=(10, 6))  # Set the plot size

# Plotting the line plot
plt.plot(sizes, cray_mpich_averages, marker='x', linewidth=4)
plt.plot(sizes, argonne_mpich_averages, marker='o', linewidth=2)
plt.plot(sizes, openmpi_averages, marker="|", linewidth=1)

# Set labels and title
plt.xlabel('Size')
plt.ylabel('Bandwidth (MB/s)')
plt.title('OSU MPI Bi-Directional Bandwidth Test v7.1')

plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility

# Add a legend
plt.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left')

plt.tight_layout()  # Adjust the layout to prevent labels from being cut off
plt.show()  # Display the plot

# %%
sizes = ['8K', '16K', '32K', '64K', '128K', '256K', '512K', '1024K', '2048K', '4096K']

cray_mpich1 = [11978.53, 22067.43, 27802.03, 30688.09, 35651.84, 37454.01, 42625.20, 42647.36, 42911.64, 42579.51]
cray_mpich2 = [12157.75, 22048.80, 27298.37, 33301.30, 38257.84, 40127.84, 41906.74, 42594.57, 43359.85, 42243.98]
cray_mpich3 = [12057.77, 22109.04, 26839.19, 34049.00, 39034.72, 42218.34, 43524.79, 44093.19, 43998.40, 42448.92]
cray_mpich4 = [12100.71, 21251.81, 27863.00, 33806.40, 37497.50, 40011.71, 41284.51, 41661.14, 41870.80, 42611.59]
cray_mpich5 = [12455.25, 19964.33, 25995.65, 32385.29, 37814.88, 40217.64, 41881.48, 42236.10, 42655.79, 42722.18]
num_elements = len(cray_mpich1)
cray_mpich_averages = []
for i in range(num_elements):
    avg = (cray_mpich1[i] + cray_mpich2[i] + cray_mpich3[i] + cray_mpich4[i] + cray_mpich5[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages.append(avg)

argonne_mpich1 = [11915.50, 21463.05, 26630.24, 32811.28, 37615.45, 39172.01, 39695.59, 39303.67, 40488.82, 39843.21]
argonne_mpich2 = [11990.81, 22087.39, 27872.62, 32556.57, 36673.30, 38610.16, 40562.36, 41142.53, 41372.68, 39499.15]
argonne_mpich3 = [12011.19, 20601.39, 27712.29, 33184.72, 37076.34, 39333.55, 40043.07, 40435.00, 40478.42, 41782.03]
argonne_mpich4 = [11838.78, 20392.15, 27062.08, 33768.25, 36330.55, 39573.75, 39631.75, 41137.28, 41472.01, 40515.28]
argonne_mpich5 = [12071.46, 21051.42, 27647.32, 33736.18, 37237.20, 39964.92, 41127.66, 41707.42, 42406.35, 41119.86]
argonne_mpich_averages = []
for i in range(num_elements):
    avg = (argonne_mpich1[i] + argonne_mpich2[i] + argonne_mpich3[i] + argonne_mpich4[i] + argonne_mpich5[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages.append(avg)

openmpi1 = [11856.61, 20771.44, 26646.89, 33355.01, 37554.52, 39628.46, 40442.88, 41459.42, 42669.32, 42828.28]
openmpi2 = [12238.44, 21567.21, 26837.96, 33491.83, 37212.19, 39308.57, 39919.31, 40671.56, 41675.25, 42409.18]
openmpi3 = [11577.33, 21781.98, 26485.32, 33458.87, 37502.99, 39476.84, 40096.21, 40720.40, 41195.62, 42154.50]
openmpi4 = [12175.13, 22182.84, 26637.39, 33169.14, 36987.32, 37776.82, 39104.09, 39318.88, 38681.20, 39688.18]
openmpi5 = [12482.73, 22165.13, 26941.79, 33307.18, 38901.57, 40550.21, 41700.39, 42903.93, 43634.62, 42585.31]
openmpi_averages = []
for i in range(num_elements):
    avg = (openmpi1[i] + openmpi2[i] + openmpi3[i] + openmpi4[i] + openmpi5[i]) / 5
    avg = round(avg, 2)
    openmpi_averages.append(avg)

sns.set(style="whitegrid")  # Set the plot style
plt.figure(figsize=(10, 6))  # Set the plot size

# Plotting the line plot
plt.plot(sizes, cray_mpich_averages, marker='x', linewidth=4)
plt.plot(sizes, argonne_mpich_averages, marker='o', linewidth=2)
plt.plot(sizes, openmpi_averages, marker="|", linewidth=1)

# Set labels and title
plt.xlabel('Size')
plt.ylabel('Bandwidth (MB/s)')
plt.title('OSU MPI Bi-Directional Bandwidth Test v7.1')

plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility

# Add a legend
plt.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left')

plt.tight_layout()  # Adjust the layout to prevent labels from being cut off
plt.show()  # Display the plot

# %% [markdown]
# ### osu_mbw_mr - Multiple Bandwidth / Message Rate Test
#     * The multi-pair bandwidth and message rate test evaluates the aggregate
#     * uni-directional bandwidth and message rate between multiple pairs of
#     * processes. Each of the sending processes sends a fixed number of messages
#     * (the window size) back-to-back to the paired receiving process before
#     * waiting for a reply from the receiver. This process is repeated for
#     * several iterations. The objective of this benchmark is to determine the
#     * achieved bandwidth and message rate from one node to another node with a
#     * configurable number of processes running on each node. The test is
#     * available here.
#
# ### FIXME:
# - nodes=2
# - ntasks-per-node=136
# - cpus-per-task=128

# %% [markdown]
# ### osu_multi_lat - Multi-pair Latency Test
#     * This test is very similar to the latency test. However, at the same
#     * instant multiple pairs are performing the same test simultaneously.
#     * In order to perform the test across just two nodes the hostnames must
#     * be specified in block fashion.
#
# - nodes=2
# - ntasks-per-node=1
# - cpus-per-task=128
# - gpus-per-task=1

# %% [markdown]
# ## NVHPC

# %% [markdown]
# ### osu_latency - Latency Test
#     * The latency tests are carried out in a ping-pong fashion. The sender
#     * sends a message with a certain data size to the receiver and waits for a
#     * reply from the receiver. The receiver receives the message from the sender
#     * and sends back a reply with the same data size. Many iterations of this
#     * ping-pong test are carried out and average one-way latency numbers are
#     * obtained. Blocking version of MPI functions (MPI_Send and MPI_Recv) are
#     * used in the tests. This test is available here.

# %% [markdown]
# ### osu_bw - Bandwidth Test
#     * The bandwidth tests are carried out by having the sender sending out a
#     * fixed number (equal to the window size) of back-to-back messages to the
#     * receiver and then waiting for a reply from the receiver. The receiver
#     * sends the reply only after receiving all these messages. This process is
#     * repeated for several iterations and the bandwidth is calculated based on
#     * the elapsed time (from the time sender sends the first message until the
#     * time it receives the reply back from the receiver) and the number of bytes
#     * sent by the sender. The objective of this bandwidth test is to determine
#     * the maximum sustained date rate that can be achieved at the network level.
#     * Thus, non-blocking version of MPI functions (MPI_Isend and MPI_Irecv) are
#     * used in the test. This test is available here.

# %% [markdown]
# ### osu_bibw - Bidirectional Bandwidth Test
#     * The bidirectional bandwidth test is similar to the bandwidth test, except
#     * that both the nodes involved send out a fixed number of back-to-back
#     * messages and wait for the reply. This test measures the maximum
#     * sustainable aggregate bandwidth by two nodes. This test is available here.

# %% [markdown]
# ### osu_mbw_mr - Multiple Bandwidth / Message Rate Test
#     * The multi-pair bandwidth and message rate test evaluates the aggregate
#     * uni-directional bandwidth and message rate between multiple pairs of
#     * processes. Each of the sending processes sends a fixed number of messages
#     * (the window size) back-to-back to the paired receiving process before
#     * waiting for a reply from the receiver. This process is repeated for
#     * several iterations. The objective of this benchmark is to determine the
#     * achieved bandwidth and message rate from one node to another node with a
#     * configurable number of processes running on each node. The test is
#     * available here.

# %% [markdown]
# ### osu_multi_lat - Multi-pair Latency Test
#     * This test is very similar to the latency test. However, at the same
#     * instant multiple pairs are performing the same test simultaneously.
#     * In order to perform the test across just two nodes the hostnames must
#     * be specified in block fashion.

# %% [markdown]
# ## LLVM
# - nodes=2
# - ntasks-per-node=1
# - cpus-per-task=128
# - gpus-per-task=4

# %% [markdown]
# ### osu_latency - Latency Test
#     * The latency tests are carried out in a ping-pong fashion. The sender
#     * sends a message with a certain data size to the receiver and waits for a
#     * reply from the receiver. The receiver receives the message from the sender
#     * and sends back a reply with the same data size. Many iterations of this
#     * ping-pong test are carried out and average one-way latency numbers are
#     * obtained. Blocking version of MPI functions (MPI_Send and MPI_Recv) are
#     * used in the tests. This test is available here.

# %%
# argonne_mpich1 = 
# argonne_mpich2 =
# argonne_mpich3 =
# argonne_mpich4 =
# argonne_mpich5 =

# %% [markdown]
# ### osu_bw - Bandwidth Test
#     * The bandwidth tests are carried out by having the sender sending out a
#     * fixed number (equal to the window size) of back-to-back messages to the
#     * receiver and then waiting for a reply from the receiver. The receiver
#     * sends the reply only after receiving all these messages. This process is
#     * repeated for several iterations and the bandwidth is calculated based on
#     * the elapsed time (from the time sender sends the first message until the
#     * time it receives the reply back from the receiver) and the number of bytes
#     * sent by the sender. The objective of this bandwidth test is to determine
#     * the maximum sustained date rate that can be achieved at the network level.
#     * Thus, non-blocking version of MPI functions (MPI_Isend and MPI_Irecv) are
#     * used in the test. This test is available here.

# %% [markdown]
# ### osu_bibw - Bidirectional Bandwidth Test
#     * The bidirectional bandwidth test is similar to the bandwidth test, except
#     * that both the nodes involved send out a fixed number of back-to-back
#     * messages and wait for the reply. This test measures the maximum
#     * sustainable aggregate bandwidth by two nodes. This test is available here.

# %% [markdown]
# ### osu_mbw_mr - Multiple Bandwidth / Message Rate Test
#     * The multi-pair bandwidth and message rate test evaluates the aggregate
#     * uni-directional bandwidth and message rate between multiple pairs of
#     * processes. Each of the sending processes sends a fixed number of messages
#     * (the window size) back-to-back to the paired receiving process before
#     * waiting for a reply from the receiver. This process is repeated for
#     * several iterations. The objective of this benchmark is to determine the
#     * achieved bandwidth and message rate from one node to another node with a
#     * configurable number of processes running on each node. The test is
#     * available here.

# %% [markdown]
# ### osu_multi_lat - Multi-pair Latency Test
#     * This test is very similar to the latency test. However, at the same
#     * instant multiple pairs are performing the same test simultaneously.
#     * In order to perform the test across just two nodes the hostnames must
#     * be specified in block fashion.
