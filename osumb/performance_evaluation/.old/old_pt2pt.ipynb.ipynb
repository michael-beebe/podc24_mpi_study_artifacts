# %% [markdown]
# # Point-to-Point OSU Microbenchmarks

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## TODO
# - Add more y tiks to figures

# %% [markdown]
# ------------------------------

# %% [markdown]
# ## GNU

# %% [markdown]
# ### osu_latency - Latency Test
#     * The latency tests are carried out in a ping-pong fashion. The sender
#     * sends a message with a certain data size to the receiver and waits for a
#     * reply from the receiver. The receiver receives the message from the sender
#     * and sends back a reply with the same data size. Many iterations of this
#     * ping-pong test are carried out and average one-way latency numbers are
#     * obtained. Blocking version of MPI functions (MPI_Send and MPI_Recv) are
#     * used in the tests. This test is available here.

# %%
# sizes = [
#     '4', '8', '16', '32', '64', '128', '256', '512', '1024', '2048', '4096', '8192', 
#     '16384', '32768', '65536', '131072', '262144', '524288', '1048576', '2097152', 
#     '4194304', '8388608', '16777216', '33554432'
# ]
sizes = [
    '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
    '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB', '32MB'
]
num_elements = len(sizes)

cray_mpich1 = [
    10.40, 10.43, 10.69, 10.68, 10.69, 11.34, 3.55, 3.60, 3.67, 3.85, 3.97, 4.34, 
    4.89, 8.87, 10.22, 12.91, 18.38, 29.22, 51.00, 96.38, 181.95, 357.26, 710.88, 1427.49
]
cray_mpich2 = [
    10.32, 10.35, 10.66, 10.59, 10.61, 11.24, 3.55, 3.58, 3.67, 3.82, 3.96, 4.34,
    4.90, 8.86, 10.22, 12.91, 18.34, 29.28, 51.08, 94.75, 182.07, 357.90, 709.74, 1427.86
]
cray_mpich3 = [
    10.44, 10.43, 10.70, 10.68, 10.70, 11.32, 3.56, 3.61, 3.68, 3.85, 3.97, 4.35,
    4.91, 8.87, 10.23, 12.89, 18.42, 29.24, 51.01, 94.84, 182.25, 357.71, 710.20, 1427.90
]
cray_mpich4 = [
    10.38, 10.42, 10.66, 10.65, 10.66, 11.30, 3.57, 3.61, 3.69, 3.85, 3.98, 4.36,
    4.91, 8.86, 10.20, 12.91, 18.44, 29.21, 51.27, 95.48, 182.03, 357.97, 709.79, 1424.93
]
cray_mpich5 = [
    10.36, 10.38, 10.64, 10.62, 10.65, 11.25, 3.55, 3.59, 3.67, 3.83, 3.95, 4.33,
    4.89, 8.84, 10.21, 12.91, 18.40, 29.29, 51.03, 97.70, 182.02, 357.63, 711.35, 1426.07
]
cray_mpich_averages = []
for i in range(num_elements):
    avg = (cray_mpich1[i] + cray_mpich2[i] + cray_mpich3[i] + cray_mpich4[i] + cray_mpich5[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages.append(avg)


argonne_mpich1 = [
    11.23, 11.22, 11.50, 11.51, 11.53, 12.14, 5.22, 5.27, 5.35, 5.51, 5.58, 11.88,
    12.70, 14.22, 15.95, 18.74, 24.28, 35.36, 92.24, 130.49, 208.95, 364.79, 671.18, 1311.69
]
argonne_mpich2 = [
    11.33, 11.35, 11.58, 11.62, 11.63, 12.22, 5.27, 5.32, 5.39, 5.54, 5.60, 11.90,
    12.68, 14.24, 16.02, 18.78, 24.34, 35.38, 92.62, 130.74, 208.82, 365.02, 672.61, 1311.73
]
argonne_mpich3 = [
    11.31, 11.29, 11.58, 11.57, 11.58, 12.15, 5.26, 5.30, 5.37, 5.52, 5.59, 11.89,
    12.64, 14.22, 15.97, 18.74, 24.34, 35.58, 92.45, 130.58, 208.73, 364.92, 670.98, 1309.27
]
argonne_mpich4 = [
    11.25, 11.23, 11.50, 11.52, 11.52, 12.10, 5.20, 5.25, 5.32, 5.47, 5.54, 11.85,
    12.63, 14.18, 15.94, 18.67, 24.28, 35.39, 92.10, 130.17, 208.19, 364.65, 671.40, 1309.87
]
argonne_mpich5 = [
    11.24, 11.24, 11.51, 11.51, 11.54, 12.21, 5.22, 5.27, 5.35, 5.51, 5.58, 11.87,
    12.64, 14.22, 15.95, 18.73, 24.51, 35.43, 92.28, 130.56, 208.37, 364.70, 671.90, 1311.95
]
argonne_mpich_averages = []
for i in range(num_elements):
    avg = (argonne_mpich1[i] + argonne_mpich2[i] + argonne_mpich3[i] + argonne_mpich4[i] + argonne_mpich5[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages.append(avg)

openmpi1 = [
    11.23, 11.22, 11.49, 11.49, 11.48, 12.07, 5.18, 5.22, 5.28, 5.44, 5.50, 11.66,
    12.41, 14.00, 15.68, 18.44, 23.93, 35.03, 92.04, 130.21, 207.83, 364.00, 669.91, 1310.73
]
openmpi2 = [
    11.24, 11.24, 11.49, 11.53, 11.51, 12.11, 5.19, 5.23, 5.30, 5.45, 5.52, 11.67,
    12.45, 14.02, 15.68, 18.42, 23.96, 35.05, 91.80, 129.98, 207.55, 363.66, 671.00, 1310.17
]
openmpi3 = [
    11.29, 11.25, 11.52, 11.52, 11.55, 12.08, 5.16, 5.22, 5.29, 5.44, 5.51, 11.67,
    12.43, 14.00, 15.69, 18.41, 24.26, 35.08, 91.76, 130.00, 207.70, 363.73, 670.73, 1308.08
]
openmpi4 = [
    11.31, 11.25, 11.55, 11.55, 11.57, 12.21, 5.20, 5.23, 5.29, 5.45, 5.53, 11.67,
    12.44, 14.01, 15.71, 18.41, 24.00, 35.09, 92.15, 130.34, 207.87, 363.29, 669.46, 1309.30
]
openmpi5 = [
    9.97, 9.97, 10.24, 10.26, 10.27, 10.88, 3.85, 3.91, 3.99, 4.16, 4.23, 7.77,
    8.44, 9.12, 10.55, 13.26, 18.91, 29.95, 88.67, 126.02, 203.42, 359.19, 664.68, 1301.47
]
openmpi_averages = []
for i in range(num_elements):
    avg = (openmpi1[i] + openmpi2[i] + openmpi3[i] + openmpi4[i] + openmpi5[i]) / 5
    avg = round(avg, 2)
    openmpi_averages.append(avg)

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("husl", 3)

# Set the plot size
fig, ax = plt.subplots(figsize=(12, 8))

# Increase font sizes
plt.rc('font', size=150)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(sizes, cray_mpich_averages, marker='x', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(sizes, argonne_mpich_averages, marker='o', markersize=10, linewidth=2.5, color=color_palette[0])
ax.plot(sizes, openmpi_averages, marker="|", markersize=10, linewidth=2.5, color=color_palette[2])

# Set labels and title
plt.xlabel('Size')
plt.ylabel('Latency (us)')
plt.title('OSU MPI Latency Test v7.1')

plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility

# Add a legend
plt.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left')

plt.tight_layout()  # Adjust the layout to prevent labels from being cut off
plt.show()  # Display the plot

# %%
sizes = ['4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K']
num_elements = len(sizes)

cray_mpich1 = [10.40, 10.43, 10.69, 10.68, 10.69, 11.34, 3.55, 3.60, 3.67, 3.85, 3.97, 4.34]
cray_mpich2 = [10.32, 10.35, 10.66, 10.59, 10.61, 11.24, 3.55, 3.58, 3.67, 3.82, 3.96, 4.34]
cray_mpich3 = [10.44, 10.43, 10.70, 10.68, 10.70, 11.32, 3.56, 3.61, 3.68, 3.85, 3.97, 4.35]
cray_mpich4 = [10.38, 10.42, 10.66, 10.65, 10.66, 11.30, 3.57, 3.61, 3.69, 3.85, 3.98, 4.36]
cray_mpich5 = [10.36, 10.38, 10.64, 10.62, 10.65, 11.25, 3.55, 3.59, 3.67, 3.83, 3.95, 4.33]
cray_mpich_averages = []
for i in range(num_elements):
    avg = (cray_mpich1[i] + cray_mpich2[i] + cray_mpich3[i] + cray_mpich4[i] + cray_mpich5[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages.append(avg)

argonne_mpich1 = [11.23, 11.22, 11.50, 11.51, 11.53, 12.14, 5.22, 5.27, 5.35, 5.51, 5.58, 11.88]
argonne_mpich2 = [11.33, 11.35, 11.58, 11.62, 11.63, 12.22, 5.27, 5.32, 5.39, 5.54, 5.60, 11.90]
argonne_mpich3 = [11.31, 11.29, 11.58, 11.57, 11.58, 12.15, 5.26, 5.30, 5.37, 5.52, 5.59, 11.89]
argonne_mpich4 = [11.25, 11.23, 11.50, 11.52, 11.52, 12.10, 5.20, 5.25, 5.32, 5.47, 5.54, 11.85]
argonne_mpich5 = [11.24, 11.24, 11.51, 11.51, 11.54, 12.21, 5.22, 5.27, 5.35, 5.51, 5.58, 11.87]
argonne_mpich_averages = []
for i in range(num_elements):
    avg = (argonne_mpich1[i] + argonne_mpich2[i] + argonne_mpich3[i] + argonne_mpich4[i] + argonne_mpich5[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages.append(avg)

openmpi1 = [11.23, 11.22, 11.49, 11.49, 11.48, 12.07, 5.18, 5.22, 5.28, 5.44, 5.50, 11.66]
openmpi2 = [11.24, 11.24, 11.49, 11.53, 11.51, 12.11, 5.19, 5.23, 5.30, 5.45, 5.52, 11.67]
openmpi3 = [11.29, 11.25, 11.52, 11.52, 11.55, 12.08, 5.16, 5.22, 5.29, 5.44, 5.51, 11.67]
openmpi4 = [11.31, 11.25, 11.55, 11.55, 11.57, 12.21, 5.20, 5.23, 5.29, 5.45, 5.53, 11.67]
openmpi5 = [9.97, 9.97, 10.24, 10.26, 10.27, 10.88, 3.85, 3.91, 3.99, 4.16, 4.23, 7.77]
openmpi_averages = []
for i in range(num_elements):
    avg = (openmpi1[i] + openmpi2[i] + openmpi3[i] + openmpi4[i] + openmpi5[i]) / 5
    avg = round(avg, 2)
    openmpi_averages.append(avg)

sns.set(style="whitegrid")  # Set the plot style
plt.figure(figsize=(10, 6))  # Set the plot size

# Plotting the line plot
plt.plot(sizes, cray_mpich_averages, marker='x', linewidth=4)
plt.plot(sizes, argonne_mpich_averages, marker='o', linewidth=2)
plt.plot(sizes, openmpi_averages, marker="|", linewidth=1)

# Set labels and title
plt.xlabel('Size')
plt.ylabel('Latency (us)')
plt.title('OSU MPI Latency Test v7.1')

plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility

# Add a legend
plt.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left')

plt.tight_layout()  # Adjust the layout to prevent labels from being cut off
plt.show()  # Display the plot

# %%
sizes = ['16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB', '32MB']
num_elements = len(sizes)

cray_mpich1 = [4.89, 8.87, 10.22, 12.91, 18.38, 29.22, 51.00, 96.38, 181.95, 357.26, 710.88, 1427.49]
cray_mpich2 = [4.90, 8.86, 10.22, 12.91, 18.34, 29.28, 51.08, 94.75, 182.07, 357.90, 709.74, 1427.86]
cray_mpich3 = [4.91, 8.87, 10.23, 12.89, 18.42, 29.24, 51.01, 94.84, 182.25, 357.71, 710.20, 1427.90]
cray_mpich4 = [4.91, 8.86, 10.20, 12.91, 18.44, 29.21, 51.27, 95.48, 182.03, 357.97, 709.79, 1424.93]
cray_mpich5 = [4.89, 8.84, 10.21, 12.91, 18.40, 29.29, 51.03, 97.70, 182.02, 357.63, 711.35, 1426.07]
cray_mpich_averages = []
for i in range(num_elements):
    avg = (cray_mpich1[i] + cray_mpich2[i] + cray_mpich3[i] + cray_mpich4[i] + cray_mpich5[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages.append(avg)

argonne_mpich1 = [12.70, 14.22, 15.95, 18.74, 24.28, 35.36, 92.24, 130.49, 208.95, 364.79, 671.18, 1311.69]
argonne_mpich2 = [12.68, 14.24, 16.02, 18.78, 24.34, 35.38, 92.62, 130.74, 208.82, 365.02, 672.61, 1311.73]
argonne_mpich3 = [12.64, 14.22, 15.97, 18.74, 24.34, 35.58, 92.45, 130.58, 208.73, 364.92, 670.98, 1309.27]
argonne_mpich4 = [12.63, 14.18, 15.94, 18.67, 24.28, 35.39, 92.10, 130.17, 208.19, 364.65, 671.40, 1309.87]
argonne_mpich5 = [12.64, 14.22, 15.95, 18.73, 24.51, 35.43, 92.28, 130.56, 208.37, 364.70, 671.90, 1311.95]
argonne_mpich_averages = []
for i in range(num_elements):
    avg = (argonne_mpich1[i] + argonne_mpich2[i] + argonne_mpich3[i] + argonne_mpich4[i] + argonne_mpich5[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages.append(avg)

openmpi1 = [12.41, 14.00, 15.68, 18.44, 23.93, 35.03, 92.04, 130.21, 207.83, 364.00, 669.91, 1310.73]
openmpi2 = [12.45, 14.02, 15.68, 18.42, 23.96, 35.05, 91.80, 129.98, 207.55, 363.66, 671.00, 1310.17]
openmpi3 = [12.43, 14.00, 15.69, 18.41, 24.26, 35.08, 91.76, 130.00, 207.70, 363.73, 670.73, 1308.08]
openmpi4 = [12.44, 14.01, 15.71, 18.41, 24.00, 35.09, 92.15, 130.34, 207.87, 363.29, 669.46, 1309.30]
openmpi5 = [8.44, 9.12, 10.55, 13.26, 18.91, 29.95, 88.67, 126.02, 203.42, 359.19, 664.68, 1301.47]
openmpi_averages = []
for i in range(num_elements):
    avg = (openmpi1[i] + openmpi2[i] + openmpi3[i] + openmpi4[i] + openmpi5[i]) / 5
    avg = round(avg, 2)
    openmpi_averages.append(avg)

sns.set(style="whitegrid")  # Set the plot style
plt.figure(figsize=(10, 6))  # Set the plot size

# Plotting the line plot
plt.plot(sizes, cray_mpich_averages, marker='x', linewidth=4)
plt.plot(sizes, argonne_mpich_averages, marker='o', linewidth=2)
plt.plot(sizes, openmpi_averages, marker="|", linewidth=1)

# Set labels and title
plt.xlabel('Size')
plt.ylabel('Latency (us)')
plt.title('OSU MPI Latency Test v7.1')

plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility

# Add a legend
plt.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left')

plt.tight_layout()  # Adjust the layout to prevent labels from being cut off
plt.show()  # Display the plot

# %% [markdown]
# ### osu_bw - Bandwidth Test
#     * The bandwidth tests are carried out by having the sender sending out a
#     * fixed number (equal to the window size) of back-to-back messages to the
#     * receiver and then waiting for a reply from the receiver. The receiver
#     * sends the reply only after receiving all these messages. This process is
#     * repeated for several iterations and the bandwidth is calculated based on
#     * the elapsed time (from the time sender sends the first message until the
#     * time it receives the reply back from the receiver) and the number of bytes
#     * sent by the sender. The objective of this bandwidth test is to determine
#     * the maximum sustained date rate that can be achieved at the network level.
#     * Thus, non-blocking version of MPI functions (MPI_Isend and MPI_Irecv) are
#     * used in the test. This test is available here.

# %%
sizes = [
    '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
    '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB', '32MB'
]

cray_mpich1 = [
    0.45, 0.91, 1.77, 3.53, 7.05, 14.07, 299.56, 641.22, 1274.52, 2413.53, 5018.31, 9573.30,
    17503.43, 20027.10, 21955.14, 22735.36, 23015.26, 23563.71, 23776.19, 23821.40, 23851.54, 23777.10, 23794.77, 23810.35
]
cray_mpich2 = [
    0.45, 0.91, 1.76, 3.55, 7.07, 13.98, 306.72, 627.15, 1248.77, 2466.28, 4973.70, 9923.08,
    17734.78, 20010.14, 22004.09, 22752.94, 23345.67, 23597.27, 23516.69, 23808.77, 23730.31, 23761.42, 23821.17, 23799.66
]
cray_mpich3 = [
    0.45, 0.91, 1.77, 3.51, 7.04, 13.97, 301.61, 624.69, 1241.32, 2475.43, 4901.91, 9739.71,
    17764.50, 20071.11, 22000.78, 22765.30, 23345.19, 23568.08, 23498.15, 23822.83, 23834.39, 23803.26, 23812.24, 23833.05
]
cray_mpich4 = [
    0.45, 0.91, 1.77, 3.54, 7.05, 14.02, 305.57, 629.88, 1242.09, 2481.20, 4858.98,9576.87,
    17606.51, 20026.51, 21924.86, 22717.42, 23115.33, 23416.32, 23762.58, 23817.26, 23728.92, 23813.95, 23813.15, 23824.44
]
cray_mpich5 = [
    0.45, 0.90, 1.75, 3.49, 7.02, 13.91, 307.31, 614.87, 1231.92, 2460.37, 4898.41, 9699.54,
    17646.02, 20068.09, 21010.68, 22767.63, 23319.48, 23616.42, 23566.09, 23545.05, 23730.41, 23816.55, 23757.76, 23808.80
]
num_elements = len(cray_mpich1)
cray_mpich_averages = []
for i in range(num_elements):
    avg = (cray_mpich1[i] + cray_mpich2[i] + cray_mpich3[i] + cray_mpich4[i] + cray_mpich5[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages.append(avg)

argonne_mpich1 = [
    0.49, 0.98, 1.88, 3.78, 7.55, 15.07, 312.92, 626.96, 1249.12, 2483.44, 4994.57, 8450.22,
    12090.06, 15837.90, 19404.41, 21424.78, 21841.42, 23113.46, 436.57, 863.63, 1677.79, 3149.38, 5507.72, 9117.60
]
argonne_mpich2 = [
    0.49, 0.99, 1.89, 3.79, 7.62, 15.18, 314.95, 625.09, 1253.72, 2494.87, 4989.58, 8551.39,
    11440.85, 15886.87, 19459.11, 21547.01, 22396.94, 22891.35, 436.97, 863.72, 1676.46, 3090.79, 5534.20, 9132.75
]
argonne_mpich3 = [
    0.49, 0.98, 1.89, 3.77, 7.53, 14.88, 312.78, 626.13, 1249.61, 2492.14, 4973.05, 8400.03,
    12074.15, 15695.46, 19204.51, 21262.75, 22354.03, 22736.81, 425.62, 842.67, 1638.73, 3082.08, 5552.69, 9290.90
]
argonne_mpich4 = [
    0.48, 0.98, 1.87, 3.73, 7.48, 14.83, 305.56, 614.41, 1215.88, 2416.05, 4841.29, 8355.51,
    12078.14, 15701.71, 19321.31, 21350.92, 22647.33, 22486.54, 425.12, 843.38, 1649.90, 3149.99, 5629.03, 9293.36
]
argonne_mpich5 = [
    0.49, 0.98, 1.89, 3.77, 7.47, 14.91, 308.58, 615.76, 1212.22, 2424.02, 4853.40, 8397.00,
    11763.76, 15717.68, 19189.96, 21276.81, 22141.85, 22799.75, 426.42, 864.20, 1677.68, 3149.35, 5627.56, 9143.66
]
argonne_mpich_averages = []
for i in range(num_elements):
    avg = (argonne_mpich1[i] + argonne_mpich2[i] + argonne_mpich3[i] + argonne_mpich4[i] + argonne_mpich5[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages.append(avg)

openmpi1 = [
    0.49, 0.98, 1.89, 3.78, 7.53, 14.89, 315.71, 631.65, 1261.81, 2459.63, 5001.31, 8541.93,
    12154.77, 15948.52, 19356.86, 21756.14, 22418.16, 22876.44, 437.29, 862.88, 1676.34, 3141.24, 5505.56, 9128.61
]
openmpi2 = [
    0.48, 0.98, 1.87, 3.76, 7.48, 14.73, 306.66, 611.39, 1221.98, 2445.48, 4970.05, 8458.70,
    12079.42, 15793.97, 19345.99, 21643.81, 22416.64, 22558.99, 425.22, 844.09, 1634.03, 3124.92, 5632.94, 9304.35
]
openmpi3 = [
    0.49, 0.97, 1.87, 3.75, 7.53, 14.90, 313.12, 603.94, 1170.96, 2451.89, 4892.52, 8064.59,
    12130.82, 15818.30, 19337.19, 21234.35, 21464.38, 22765.36, 426.89, 863.88, 1677.50, 3150.45, 5509.14, 9164.46
]
openmpi4 = [
    0.49, 0.97, 1.88, 3.75, 7.49, 14.81, 306.90, 603.05, 1221.76, 2447.60, 4882.12, 8447.19,
    12066.40, 15822.73, 19248.46, 21268.93, 22432.61, 22806.41, 428.95, 842.03, 1664.51, 3149.82, 5631.50, 9304.17
]
openmpi5 = [
    0.48, 0.97, 1.87, 3.77, 7.51, 14.74, 326.23, 651.22, 1296.17, 2590.48, 5137.66, 9378.13,
    12606.68, 16771.82, 19221.29, 22000.12, 22857.80, 23305.11, 425.96, 847.95, 1656.18, 3153.43, 5644.57, 9326.69
]
openmpi_averages = []
for i in range(num_elements):
    avg = (openmpi1[i] + openmpi2[i] + openmpi3[i] + openmpi4[i] + openmpi5[i]) / 5
    avg = round(avg, 2)
    openmpi_averages.append(avg)

#---------------------------------------------------------------------------------s

sns.set(style="whitegrid")  # Set the plot style
plt.figure(figsize=(10, 6))  # Set the plot size

# Plotting the line plot
plt.plot(sizes, cray_mpich_averages, marker='x', linewidth=4)
plt.plot(sizes, argonne_mpich_averages, marker='o', linewidth=2)
plt.plot(sizes, openmpi_averages, marker="|", linewidth=1)

# Set labels and title
plt.xlabel('Size')
plt.ylabel('Bandwidth (MB/s)')
plt.title('OSU MPI Bandwidth Test v7.1')

plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility

# Add a legend
plt.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left')

plt.tight_layout()  # Adjust the layout to prevent labels from being cut off
plt.show()  # Display the plot

# %%
sizes = ['4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K']

cray_mpich1 = [0.45, 0.91, 1.77, 3.53, 7.05, 14.07, 299.56, 641.22, 1274.52, 2413.53, 5018.31, 9573.30]
cray_mpich2 = [0.45, 0.91, 1.76, 3.55, 7.07, 13.98, 306.72, 627.15, 1248.77, 2466.28, 4973.70, 9923.08]
cray_mpich3 = [0.45, 0.91, 1.77, 3.51, 7.04, 13.97, 301.61, 624.69, 1241.32, 2475.43, 4901.91, 9739.71]
cray_mpich4 = [0.45, 0.91, 1.77, 3.54, 7.05, 14.02, 305.57, 629.88, 1242.09, 2481.20, 4858.98,9576.87]
cray_mpich5 = [0.45, 0.90, 1.75, 3.49, 7.02, 13.91, 307.31, 614.87, 1231.92, 2460.37, 4898.41, 9699.54]
num_elements = len(cray_mpich1)
cray_mpich_averages = []
for i in range(num_elements):
    avg = (cray_mpich1[i] + cray_mpich2[i] + cray_mpich3[i] + cray_mpich4[i] + cray_mpich5[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages.append(avg)

argonne_mpich1 = [0.49, 0.98, 1.88, 3.78, 7.55, 15.07, 312.92, 626.96, 1249.12, 2483.44, 4994.57, 8450.22]
argonne_mpich2 = [0.49, 0.99, 1.89, 3.79, 7.62, 15.18, 314.95, 625.09, 1253.72, 2494.87, 4989.58, 8551.39]
argonne_mpich3 = [0.49, 0.98, 1.89, 3.77, 7.53, 14.88, 312.78, 626.13, 1249.61, 2492.14, 4973.05, 8400.03]
argonne_mpich4 = [0.48, 0.98, 1.87, 3.73, 7.48, 14.83, 305.56, 614.41, 1215.88, 2416.05, 4841.29, 8355.51]
argonne_mpich5 = [0.49, 0.98, 1.89, 3.77, 7.47, 14.91, 308.58, 615.76, 1212.22, 2424.02, 4853.40, 8397.00]
argonne_mpich_averages = []
for i in range(num_elements):
    avg = (argonne_mpich1[i] + argonne_mpich2[i] + argonne_mpich3[i] + argonne_mpich4[i] + argonne_mpich5[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages.append(avg)

openmpi1 = [0.49, 0.98, 1.89, 3.78, 7.53, 14.89, 315.71, 631.65, 1261.81, 2459.63, 5001.31, 8541.93]
openmpi2 = [0.48, 0.98, 1.87, 3.76, 7.48, 14.73, 306.66, 611.39, 1221.98, 2445.48, 4970.05, 8458.70]
openmpi3 = [0.49, 0.97, 1.87, 3.75, 7.53, 14.90, 313.12, 603.94, 1170.96, 2451.89, 4892.52, 8064.59]
openmpi4 = [0.49, 0.97, 1.88, 3.75, 7.49, 14.81, 306.90, 603.05, 1221.76, 2447.60, 4882.12, 8447.19]
openmpi5 = [0.48, 0.97, 1.87, 3.77, 7.51, 14.74, 326.23, 651.22, 1296.17, 2590.48, 5137.66, 9378.13]
openmpi_averages = []
for i in range(num_elements):
    avg = (openmpi1[i] + openmpi2[i] + openmpi3[i] + openmpi4[i] + openmpi5[i]) / 5
    avg = round(avg, 2)
    openmpi_averages.append(avg)


sns.set(style="whitegrid")  # Set the plot style
plt.figure(figsize=(10, 6))  # Set the plot size

# Plotting the line plot
plt.plot(sizes, cray_mpich_averages, marker='x', linewidth=4)
plt.plot(sizes, argonne_mpich_averages, marker='o', linewidth=2)
plt.plot(sizes, openmpi_averages, marker="|", linewidth=1)

# Set labels and title
plt.xlabel('Size')
plt.ylabel('Bandwidth (MB/s)')
plt.title('OSU MPI Bandwidth Test v7.1')

plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility

# Add a legend
plt.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left')

plt.tight_layout()  # Adjust the layout to prevent labels from being cut off
plt.show()  # Display the plot

# %%
sizes = ['16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB', '32MB']

cray_mpich1 = [17503.43, 20027.10, 21955.14, 22735.36, 23015.26, 23563.71, 23776.19, 23821.40, 23851.54, 23777.10, 23794.77, 23810.35]
cray_mpich2 = [17734.78, 20010.14, 22004.09, 22752.94, 23345.67, 23597.27, 23516.69, 23808.77, 23730.31, 23761.42, 23821.17, 23799.66]
cray_mpich3 = [17764.50, 20071.11, 22000.78, 22765.30, 23345.19, 23568.08, 23498.15, 23822.83, 23834.39, 23803.26, 23812.24, 23833.05]
cray_mpich4 = [17606.51, 20026.51, 21924.86, 22717.42, 23115.33, 23416.32, 23762.58, 23817.26, 23728.92, 23813.95, 23813.15, 23824.44]
cray_mpich5 = [17646.02, 20068.09, 21010.68, 22767.63, 23319.48, 23616.42, 23566.09, 23545.05, 23730.41, 23816.55, 23757.76, 23808.80]
num_elements = len(cray_mpich1)
cray_mpich_averages = []
for i in range(num_elements):
    avg = (cray_mpich1[i] + cray_mpich2[i] + cray_mpich3[i] + cray_mpich4[i] + cray_mpich5[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages.append(avg)

argonne_mpich1 = [12090.06, 15837.90, 19404.41, 21424.78, 21841.42, 23113.46, 436.57, 863.63, 1677.79, 3149.38, 5507.72, 9117.60]
argonne_mpich2 = [11440.85, 15886.87, 19459.11, 21547.01, 22396.94, 22891.35, 436.97, 863.72, 1676.46, 3090.79, 5534.20, 9132.75]
argonne_mpich3 = [12074.15, 15695.46, 19204.51, 21262.75, 22354.03, 22736.81, 425.62, 842.67, 1638.73, 3082.08, 5552.69, 9290.90]
argonne_mpich4 = [12078.14, 15701.71, 19321.31, 21350.92, 22647.33, 22486.54, 425.12, 843.38, 1649.90, 3149.99, 5629.03, 9293.36]
argonne_mpich5 = [11763.76, 15717.68, 19189.96, 21276.81, 22141.85, 22799.75, 426.42, 864.20, 1677.68, 3149.35, 5627.56, 9143.66]
argonne_mpich_averages = []
for i in range(num_elements):
    avg = (argonne_mpich1[i] + argonne_mpich2[i] + argonne_mpich3[i] + argonne_mpich4[i] + argonne_mpich5[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages.append(avg)

openmpi1 = [12154.77, 15948.52, 19356.86, 21756.14, 22418.16, 22876.44, 437.29, 862.88, 1676.34, 3141.24, 5505.56, 9128.61]
openmpi2 = [12079.42, 15793.97, 19345.99, 21643.81, 22416.64, 22558.99, 425.22, 844.09, 1634.03, 3124.92, 5632.94, 9304.35]
openmpi3 = [12130.82, 15818.30, 19337.19, 21234.35, 21464.38, 22765.36, 426.89, 863.88, 1677.50, 3150.45, 5509.14, 9164.46]
openmpi4 = [12066.40, 15822.73, 19248.46, 21268.93, 22432.61, 22806.41, 428.95, 842.03, 1664.51, 3149.82, 5631.50, 9304.17]
openmpi5 = [12606.68, 16771.82, 19221.29, 22000.12, 22857.80, 23305.11, 425.96, 847.95, 1656.18, 3153.43, 5644.57, 9326.69]
openmpi_averages = []
for i in range(num_elements):
    avg = (openmpi1[i] + openmpi2[i] + openmpi3[i] + openmpi4[i] + openmpi5[i]) / 5
    avg = round(avg, 2)
    openmpi_averages.append(avg)


sns.set(style="whitegrid")  # Set the plot style
plt.figure(figsize=(10, 6))  # Set the plot size

# Plotting the line plot
plt.plot(sizes, cray_mpich_averages, marker='x', linewidth=4)
plt.plot(sizes, argonne_mpich_averages, marker='o', linewidth=2)
plt.plot(sizes, openmpi_averages, marker="|", linewidth=1)

# Set labels and title
plt.xlabel('Size')
plt.ylabel('Bandwidth (MB/s)')
plt.title('OSU MPI Bandwidth Test v7.1')

plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility

# Add a legend
plt.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left')

plt.tight_layout()  # Adjust the layout to prevent labels from being cut off
plt.show()  # Display the plot

# %% [markdown]
# ## NVHPC

# %% [markdown]
# ### osu_latency - Latency Test
#     * The latency tests are carried out in a ping-pong fashion. The sender
#     * sends a message with a certain data size to the receiver and waits for a
#     * reply from the receiver. The receiver receives the message from the sender
#     * and sends back a reply with the same data size. Many iterations of this
#     * ping-pong test are carried out and average one-way latency numbers are
#     * obtained. Blocking version of MPI functions (MPI_Send and MPI_Recv) are
#     * used in the tests. This test is available here.

# %%
sizes = [
    '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
    '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB', '32MB'
]
num_elements = len(sizes)

cray_mpich1 = [
    6.38, 6.37, 6.48, 6.50, 6.50, 7.08, 3.27, 3.31, 3.36, 3.49, 3.62, 4.00,
    4.59, 8.18, 9.57, 12.40, 17.82, 28.72, 50.37, 93.88, 181.10, 355.83, 706.91, 1416.00
]
cray_mpich2 = [
    7.70, 7.67, 7.83, 7.83, 7.82, 8.39, 5.36, 5.32, 5.13, 5.02, 5.11, 5.47,
    6.31, 13.12, 14.90, 17.80, 23.44, 34.35, 56.17, 99.98, 187.59, 368.62, 724.93, 1446.53
]
cray_mpich3 = [
    7.66, 7.66, 7.78, 7.81, 7.80, 8.37, 5.38, 5.25, 5.24, 5.05, 5.13, 5.53,
    6.42, 13.06, 14.83, 17.73, 23.36, 34.13, 55.93, 99.73, 187.00, 367.44, 723.40, 1441.51
]
cray_mpich4 = [
    7.72, 7.71, 7.84, 7.84, 7.84, 8.42, 5.45, 5.31, 5.26, 5.02, 5.09, 5.47,
    6.22, 13.07, 14.84, 17.76, 23.46, 34.33, 56.02, 99.89, 187.37, 368.30, 724.18, 1443.90
]
cray_mpich5 = [
    7.63, 7.61, 7.76, 7.76, 7.76, 8.33, 5.22, 5.18, 5.06, 5.01, 5.12, 5.53,
    6.26, 13.03, 14.75, 17.62, 23.20, 34.09, 55.85, 99.50, 186.76, 366.72, 722.04, 1439.61
]
cray_mpich_averages = []
for i in range(num_elements):
    avg = (cray_mpich1[i] + cray_mpich2[i] + cray_mpich3[i] + cray_mpich4[i] + cray_mpich5[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages.append(avg)


openmpi1 = [
    
]
openmpi2 = [

]
openmpi3 = [

]
openmpi4 = [

]
openmpi5 = [

]
openmpi_averages = []
for i in range(num_elements):
    avg = (openmpi1[i] + openmpi2[i] + openmpi3[i] + openmpi4[i] + openmpi5[i]) / 5
    avg = round(avg, 2)
    openmpi_averages.append(avg)

sns.set(style="whitegrid")  # Set the plot style
plt.figure(figsize=(10, 6))  # Set the plot size

# Plotting the line plot
plt.plot(sizes, cray_mpich_averages, marker='x', linewidth=4)
plt.plot(sizes, openmpi_averages, marker="|", linewidth=1)

# Set labels and title
plt.xlabel('Size')
plt.ylabel('Latency (us)')
plt.title('OSU MPI Latency Test v7.1')

plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility

# Add a legend
plt.legend(['Cray MPICH', 'Open MPI'], loc='upper left')

plt.tight_layout()  # Adjust the layout to prevent labels from being cut off
plt.show()  # Display the plot

# %% [markdown]
# ### osu_bw - Bandwidth Test
#     * The bandwidth tests are carried out by having the sender sending out a
#     * fixed number (equal to the window size) of back-to-back messages to the
#     * receiver and then waiting for a reply from the receiver. The receiver
#     * sends the reply only after receiving all these messages. This process is
#     * repeated for several iterations and the bandwidth is calculated based on
#     * the elapsed time (from the time sender sends the first message until the
#     * time it receives the reply back from the receiver) and the number of bytes
#     * sent by the sender. The objective of this bandwidth test is to determine
#     * the maximum sustained date rate that can be achieved at the network level.
#     * Thus, non-blocking version of MPI functions (MPI_Isend and MPI_Irecv) are
#     * used in the test. This test is available here.

# %%
sizes = [
    '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
    '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB', '32MB'
]
num_elements = len(sizes)

cray_mpich1 = [
    3.67, 8.10, 16.13, 32.32, 64.86, 129.11, 299.97, 665.45, 1326.28, 2639.58, 5270.36,
    10470.78, 17818.33, 20265.79, 22095.22, 22859.82, 23485.90, 23753.31, 23864.20,
    23929.13, 23965.58, 23981.77, 23990.41
]
cray_mpich2 = [
    3.68, 7.49, 15.09, 31.08, 60.73, 121.11, 313.68, 623.40, 1240.32, 2471.60, 4909.02,
    9720.75, 16034.95, 19130.46, 21369.25, 22218.27, 22906.56, 23249.54, 23402.31,
    23498.44, 23542.91, 23559.88, 23576.20, 23580.61
]
cray_mpich3 = [
    3.87, 7.75, 15.30, 30.86, 61.89, 123.55, 321.10, 624.80, 1278.17, 2545.29, 5072.68,
    10074.11, 16639.93, 19230.71, 21373.36, 22242.19, 22947.50, 23211.73, 23421.57,
    23525.25, 23578.89, 23595.16, 23604.17, 23611.14
]
cray_mpich4 = [
    3.82, 7.67, 15.23, 30.68, 61.39, 123.06, 313.98, 640.01, 1256.38, 2544.66, 5034.00,
    9390.47, 15972.39, 19144.41, 21431.07, 22204.24, 22919.27, 23254.91, 23372.69,
    23492.52, 23536.31, 23564.03, 23570.86, 23577.80
]
cray_mpich5 = [
    3.76, 7.44, 15.05, 30.14, 60.20, 119.73, 308.58, 617.36, 1234.03, 2469.81, 4906.75,
    9678.93, 16470.39, 19073.42, 21374.71, 22221.50, 22992.08, 23361.07, 23475.60,
    23610.81, 23650.78, 23675.95, 23683.75, 23688.66
]
cray_mpich_averages = []
for i in range(num_elements):
    avg = (cray_mpich1[i] + cray_mpich2[i] + cray_mpich3[i] + cray_mpich4[i] + cray_mpich5[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages.append(avg)


openmpi1 = [

]
openmpi2 = [

]
openmpi3 = [

]
openmpi4 = [

]
openmpi5 = [

]
openmpi_averages = []
for i in range(num_elements):
    avg = (openmpi1[i] + openmpi2[i] + openmpi3[i] + openmpi4[i] + openmpi5[i]) / 5
    avg = round(avg, 2)
    openmpi_averages.append(avg)

sns.set(style="whitegrid")  # Set the plot style
plt.figure(figsize=(10, 6))  # Set the plot size

# Plotting the line plot
plt.plot(sizes, cray_mpich_averages, marker='x', linewidth=4)
plt.plot(sizes, argonne_mpich_averages, marker='o', linewidth=2)
plt.plot(sizes, openmpi_averages, marker="|", linewidth=1)

# Set labels and title
plt.xlabel('Size')
plt.ylabel('Latency (us)')
plt.title('OSU MPI Latency Test v7.1')

plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility

# Add a legend
plt.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left')

plt.tight_layout()  # Adjust the layout to prevent labels from being cut off
plt.show()  # Display the plot
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 34
#      32 cray_mpich_averages = []
#      33 for i in range(num_elements):
# ---> 34     avg = (cray_mpich1[i] + cray_mpich2[i] + cray_mpich3[i] + cray_mpich4[i] + cray_mpich5[i]) / 5
#      35     avg = round(avg, 2)
#      36     cray_mpich_averages.append(avg)
#
# IndexError: list index out of range

# %% [markdown]
# ### osu_bibw - Bidirectional Bandwidth Test
#     * The bidirectional bandwidth test is similar to the bandwidth test, except
#     * that both the nodes involved send out a fixed number of back-to-back
#     * messages and wait for the reply. This test measures the maximum
#     * sustainable aggregate bandwidth by two nodes. This test is available here.

# %% [markdown]
# ### osu_mbw_mr - Multiple Bandwidth / Message Rate Test
#     * The multi-pair bandwidth and message rate test evaluates the aggregate
#     * uni-directional bandwidth and message rate between multiple pairs of
#     * processes. Each of the sending processes sends a fixed number of messages
#     * (the window size) back-to-back to the paired receiving process before
#     * waiting for a reply from the receiver. This process is repeated for
#     * several iterations. The objective of this benchmark is to determine the
#     * achieved bandwidth and message rate from one node to another node with a
#     * configurable number of processes running on each node. The test is
#     * available here.

# %% [markdown]
# ### osu_multi_lat - Multi-pair Latency Test
#     * This test is very similar to the latency test. However, at the same
#     * instant multiple pairs are performing the same test simultaneously.
#     * In order to perform the test across just two nodes the hostnames must
#     * be specified in block fashion.

# %% [markdown]
# ## LLVM
# - nodes=2
# - ntasks-per-node=1
# - cpus-per-task=128
# - gpus-per-task=4

# %% [markdown]
# ### osu_latency - Latency Test
#     * The latency tests are carried out in a ping-pong fashion. The sender
#     * sends a message with a certain data size to the receiver and waits for a
#     * reply from the receiver. The receiver receives the message from the sender
#     * and sends back a reply with the same data size. Many iterations of this
#     * ping-pong test are carried out and average one-way latency numbers are
#     * obtained. Blocking version of MPI functions (MPI_Send and MPI_Recv) are
#     * used in the tests. This test is available here.

# %% [markdown]
# ### osu_bw - Bandwidth Test
#     * The bandwidth tests are carried out by having the sender sending out a
#     * fixed number (equal to the window size) of back-to-back messages to the
#     * receiver and then waiting for a reply from the receiver. The receiver
#     * sends the reply only after receiving all these messages. This process is
#     * repeated for several iterations and the bandwidth is calculated based on
#     * the elapsed time (from the time sender sends the first message until the
#     * time it receives the reply back from the receiver) and the number of bytes
#     * sent by the sender. The objective of this bandwidth test is to determine
#     * the maximum sustained date rate that can be achieved at the network level.
#     * Thus, non-blocking version of MPI functions (MPI_Isend and MPI_Irecv) are
#     * used in the test. This test is available here.

# %% [markdown]
# ### osu_bibw - Bidirectional Bandwidth Test
#     * The bidirectional bandwidth test is similar to the bandwidth test, except
#     * that both the nodes involved send out a fixed number of back-to-back
#     * messages and wait for the reply. This test measures the maximum
#     * sustainable aggregate bandwidth by two nodes. This test is available here.

# %% [markdown]
# ### osu_mbw_mr - Multiple Bandwidth / Message Rate Test
#     * The multi-pair bandwidth and message rate test evaluates the aggregate
#     * uni-directional bandwidth and message rate between multiple pairs of
#     * processes. Each of the sending processes sends a fixed number of messages
#     * (the window size) back-to-back to the paired receiving process before
#     * waiting for a reply from the receiver. This process is repeated for
#     * several iterations. The objective of this benchmark is to determine the
#     * achieved bandwidth and message rate from one node to another node with a
#     * configurable number of processes running on each node. The test is
#     * available here.

# %% [markdown]
# ### osu_multi_lat - Multi-pair Latency Test
#     * This test is very similar to the latency test. However, at the same
#     * instant multiple pairs are performing the same test simultaneously.
#     * In order to perform the test across just two nodes the hostnames must
#     * be specified in block fashion.
