# %% [markdown]
# # OSU Block Collective Microbenchmarks (Device to Device)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## TODO

# %% [markdown]
# ## GNU

# %% [markdown]
# ### osu_gather

# %%
sizes = [
    '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
    '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB', '32MB'
]
num_sizes = len(sizes)

###################################################################
#                       2 NODE RESULTS
###################################################################
cray_mpich1_2n = [
    13.38, 13.51, 13.37, 13.77, 14.13, 14.26, 14.30, 16.02, 17.43, 17.69,
    18.82, 21.46, 24.09, 30.19, 41.73, 64.64, 109.87, 199.93, 365.81,
    665.28, 1263.89, 3141.49, 13318.15, 38798.90
]
cray_mpich2_2n = [
    13.28, 13.35, 13.34, 13.67, 14.04, 14.12, 14.21, 15.82, 17.42, 17.82,
    19.05, 21.40, 24.09, 30.01, 41.65, 64.64, 111.28, 201.35, 367.91,
    669.56, 1250.39, 3064.26, 13447.27, 39423.01
]
cray_mpich3_2n = [
    13.60, 13.49, 13.41, 13.80, 14.49, 14.72, 14.80, 16.51, 17.98, 18.39,
    19.46, 22.82, 25.76, 31.75, 43.51, 66.45, 111.77, 203.69, 371.43,
    689.60, 1279.81, 3099.91, 13052.95, 40015.01
]
cray_mpich4_2n = [
    13.31, 13.42, 13.37, 13.76, 14.18, 14.09, 14.13, 15.83, 17.41, 17.92,
    18.82, 21.59, 24.44, 30.26, 41.89, 65.00, 111.06, 203.15, 369.35,
    687.82, 1278.31, 3064.43, 13133.70, 38604.05
]
cray_mpich5_2n = [
    13.37, 13.33, 13.23, 13.59, 14.27, 14.36, 14.42, 16.10, 17.56, 17.94,
    18.96, 22.47, 25.39, 31.30, 42.94, 66.14, 111.80, 203.10, 368.24,
    686.41, 1266.66, 3086.37, 13131.55, 39789.62
]
cray_mpich_averages_2n = []
for i in range(num_sizes):
    avg = (cray_mpich1_2n[i] + cray_mpich2_2n[i] + cray_mpich3_2n[i] + cray_mpich4_2n[i] + cray_mpich5_2n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_2n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_2n = [

]
argonne_mpich2_2n = [

]
argonne_mpich3_2n = [

]
argonne_mpich4_2n = [

]
argonne_mpich5_2n = [

]
argonne_mpich_averages_2n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_2n[i] + argonne_mpich2_2n[i] + argonne_mpich3_2n[i] + argonne_mpich4_2n[i] + argonne_mpich5_2n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_2n.append(avg)

openmpi1_2n = [

]
openmpi2_2n = [

]
openmpi3_2n = [

]
openmpi4_2n = [

]
openmpi5_2n = [

]
openmpi_averages_2n = []
for i in range(num_sizes):
    avg = (openmpi1_2n[i] + openmpi2_2n[i] + openmpi3_2n[i] + openmpi4_2n[i] + openmpi5_2n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_2n.append(avg)

###################################################################
#                       4 NODE RESULTS
###################################################################
cray_mpich1_4n = [
    12.88, 12.88, 12.83, 13.65, 14.16, 14.33, 14.47, 15.43, 16.47, 16.82,
    19.37, 21.87, 24.81, 31.19, 43.77, 68.50, 118.21, 217.02, 407.58, 761.67,
    1882.81, 4304.93, 15313.57, 43271.52
]
cray_mpich2_4n = [
    13.01, 13.03, 12.89, 13.67, 14.14, 14.38, 14.41, 15.39, 16.40, 16.76,
    19.40, 22.06, 25.19, 31.67, 44.56, 69.70, 119.56, 218.67, 410.23, 776.74,
    1848.44, 4196.22, 15293.40, 43328.61
]
cray_mpich3_4n = [
    13.05, 13.14, 12.92, 13.54, 13.99, 14.20, 14.30, 15.30, 16.34, 16.83,
    18.76, 21.06, 24.03, 30.30, 43.00, 68.51, 119.10, 219.12, 412.36, 774.14,
    1880.20, 4189.36, 15135.65, 42677.92
]
cray_mpich4_4n = [
    13.28, 13.30, 13.20, 14.07, 14.67, 14.83, 14.85, 15.94, 17.01, 17.36,
    19.81, 22.41, 25.60, 32.27, 45.13, 70.04, 120.11, 218.69, 408.52, 765.17,
    1876.26, 4175.55, 15041.75, 43279.91
]
cray_mpich5_4n = [
    13.05, 13.04, 12.92, 13.72, 14.20, 14.36, 14.45, 15.44, 16.51, 16.84,
    19.45, 22.00, 25.25, 31.82, 44.58, 69.29, 119.38, 218.65, 407.73, 763.96,
    1871.66, 4125.82, 15348.88, 43130.18
]
cray_mpich_averages_4n = []
for i in range(num_sizes):
    avg = (cray_mpich1_4n[i] + cray_mpich2_4n[i] + cray_mpich3_4n[i] + cray_mpich4_4n[i] + cray_mpich5_4n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_4n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_4n = [

]
argonne_mpich2_4n = [

]
argonne_mpich3_4n = [

]
argonne_mpich4_4n = [

]
argonne_mpich5_4n = [

]
argonne_mpich_averages_4n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_4n[i] + argonne_mpich2_4n[i] + argonne_mpich3_4n[i] + argonne_mpich4_4n[i] + argonne_mpich5_4n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_4n.append(avg)

openmpi1_4n = [

]
openmpi2_4n = [

]
openmpi3_4n = [

]
openmpi4_4n = [

]
openmpi5_4n = [

]
openmpi_averages_4n = []
for i in range(num_sizes):
    avg = (openmpi1_4n[i] + openmpi2_4n[i] + openmpi3_4n[i] + openmpi4_4n[i] + openmpi5_4n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_4n.append(avg)

###################################################################
#                       6 NODE RESULTS
###################################################################
cray_mpich1_6n = [
    12.91, 12.91, 12.81, 13.70, 14.27, 14.40, 14.48, 15.31, 16.27, 16.70,
    19.84, 22.32, 25.50, 32.21, 46.76, 72.69, 125.51, 231.58, 435.55, 0,
    0, 0, 0, 0
]
cray_mpich2_6n = [
    13.00, 13.02, 12.88, 13.77, 14.24, 14.33, 14.43, 15.25, 16.26, 16.74,
    19.91, 22.30, 25.65, 32.61, 46.53, 73.26, 125.73, 231.58, 435.84, 0,
    0, 0, 0, 0
]
cray_mpich3_6n = [
    13.11, 13.09, 12.94, 13.94, 14.52, 14.62, 14.74, 15.50, 16.41, 16.92,
    19.98, 22.45, 25.86, 32.92, 46.39, 72.95, 125.79, 230.97, 433.73, 0,
    0, 0, 0, 0
]
cray_mpich4_6n = [
    13.06, 13.11, 12.93, 13.84, 14.50, 14.62, 14.75, 15.58, 16.44, 16.93,
    19.91, 22.51, 25.89, 32.98, 46.41, 73.12, 125.92, 230.91, 434.97, 0,
    0, 0, 0, 0
]
cray_mpich5_6n = [
    12.94, 13.07, 12.96, 13.65, 14.13, 14.27, 14.34, 15.11, 16.10, 16.60,
    19.50, 21.83, 25.03, 31.58, 44.97, 71.88, 124.60, 229.75, 432.48, 0,
    0, 0, 0, 0
]
cray_mpich_averages_6n = []
for i in range(num_sizes):
    avg = (cray_mpich1_6n[i] + cray_mpich2_6n[i] + cray_mpich3_6n[i] + cray_mpich4_6n[i] + cray_mpich5_6n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_6n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_6n = [

]
argonne_mpich2_6n = [

]
argonne_mpich3_6n = [

]
argonne_mpich4_6n = [

]
argonne_mpich5_6n = [

]
argonne_mpich_averages_6n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_6n[i] + argonne_mpich2_6n[i] + argonne_mpich3_6n[i] + argonne_mpich4_6n[i] + argonne_mpich5_6n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_6n.append(avg)

openmpi1_6n = [

]
openmpi2_6n = [

]
openmpi3_6n = [

]
openmpi4_6n = [

]
openmpi5_6n = [

]
openmpi_averages_6n = []
for i in range(num_sizes):
    avg = (openmpi1_6n[i] + openmpi2_6n[i] + openmpi3_6n[i] + openmpi4_6n[i] + openmpi5_6n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_6n.append(avg)

###################################################################
#                       8 NODE RESULTS
###################################################################
cray_mpich1_8n = [
    12.95, 12.99, 12.99, 13.74, 14.24, 14.38, 14.49, 15.22, 16.12, 17.30,
    19.31, 21.80, 25.43, 33.68, 47.41, 74.74, 130.28, 240.53, 454.38,
    0, 0, 0, 0, 0
]
cray_mpich2_8n = [
    12.95, 12.98, 13.03, 13.74, 14.27, 14.41, 14.54, 15.25, 16.15, 17.48,
    19.34, 21.77, 25.39, 32.65, 46.48, 74.02, 128.26, 239.32, 450.49,
    0, 0, 0, 0, 0
]
cray_mpich3_8n = [
    12.90, 12.92, 12.97, 13.76, 14.18, 14.34, 14.43, 15.09, 15.95, 17.15,
    19.17, 21.48, 24.96, 32.14, 45.86, 73.10, 127.30, 236.29, 449.76,
    0, 0, 0, 0, 0
]
cray_mpich4_8n = [
    13.04, 13.04, 13.11, 13.95, 14.63, 14.72, 14.81, 15.54, 16.40, 17.61,
    19.53, 22.26, 25.96, 34.51, 48.47, 77.75, 132.72, 243.37, 457.00,
    0, 0, 0, 0, 0
]
cray_mpich5_8n = [
    12.99, 13.02, 13.07, 13.86, 14.34, 14.50, 14.62, 15.30, 16.13, 17.31,
    19.26, 21.87, 25.40, 32.54, 46.44, 75.40, 130.10, 240.23, 451.49,
    0, 0, 0, 0, 0
]
cray_mpich_averages_8n = []
for i in range(num_sizes):
    avg = (cray_mpich1_8n[i] + cray_mpich2_8n[i] + cray_mpich3_8n[i] + cray_mpich4_8n[i] + cray_mpich5_8n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_8n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_8n = [

]
argonne_mpich2_8n = [

]
argonne_mpich3_8n = [

]
argonne_mpich4_8n = [

]
argonne_mpich5_8n = [

]
argonne_mpich_averages_8n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_8n[i] + argonne_mpich2_8n[i] + argonne_mpich3_8n[i] + argonne_mpich4_8n[i] + argonne_mpich5_8n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_8n.append(avg)

openmpi1_8n = [

]
openmpi2_8n = [

]
openmpi3_8n = [

]
openmpi4_8n = [

]
openmpi5_8n = [

]
openmpi_averages_8n = []
for i in range(num_sizes):
    avg = (openmpi1_8n[i] + openmpi2_8n[i] + openmpi3_8n[i] + openmpi4_8n[i] + openmpi5_8n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_8n.append(avg)

###################################################################
#                       10 NODE RESULTS
###################################################################
cray_mpich1_10n = [
    12.75, 12.75, 12.75, 13.70, 14.06, 14.20, 14.28, 14.98, 15.80, 16.91,
    19.77, 22.16, 25.93, 33.53, 48.34, 77.45, 134.96, 250.63,
    0, 0, 0, 0, 0, 0
]
cray_mpich2_10n = [
    12.58, 12.58, 12.58, 13.35, 13.68, 13.81, 13.93, 14.60, 15.36, 16.39,
    19.06, 21.20, 24.65, 32.04, 46.70, 75.17, 132.70, 248.85,
    0, 0, 0, 0, 0, 0
]
cray_mpich3_10n = [

]
cray_mpich4_10n = [

]
cray_mpich5_10n = [

]
cray_mpich_averages_10n = []
for i in range(num_sizes):
    avg = (cray_mpich1_10n[i] + cray_mpich2_10n[i] + cray_mpich3_10n[i] + cray_mpich4_10n[i] + cray_mpich5_10n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_10n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_10n = [

]
argonne_mpich2_10n = [

]
argonne_mpich3_10n = [

]
argonne_mpich4_10n = [

]
argonne_mpich5_10n = [

]
argonne_mpich_averages_10n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_10n[i] + argonne_mpich2_10n[i] + argonne_mpich3_10n[i] + argonne_mpich4_10n[i] + argonne_mpich5_10n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_10n.append(avg)

openmpi1_10n = [

]
openmpi2_10n = [

]
openmpi3_10n = [

]
openmpi4_10n = [

]
openmpi5_10n = [

]
openmpi_averages_10n = []
for i in range(num_sizes):
    avg = (openmpi1_10n[i] + openmpi2_10n[i] + openmpi3_10n[i] + openmpi4_10n[i] + openmpi5_10n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_10n.append(avg)

##########################################################################################################################

# Number of nodes used
nun_nodes = [2, 4, 6, 8, 10]

# Averages latencies for 16MB message size, scaling nodes FIXME: change array indeces if we choose to look at a different message size
cray_mpich_results = [ cray_mpich_averages_2n[-6], cray_mpich_averages_4n[-6], cray_mpich_averages_6n[-6], cray_mpich_averages_8n[-6], cray_mpich_averages_10n[-6] ]
argonne_mpich_results = [ argonne_mpich_averages_2n[-6], argonne_mpich_averages_4n[-6], argonne_mpich_averages_6n[-6], argonne_mpich_averages_8n[-6], argonne_mpich_averages_10n[-6] ]
openmpi_results = [ openmpi_averages_2n[-6], openmpi_averages_4n[-6], openmpi1_6n[-6], openmpi1_8n[-6], openmpi1_10n[-6] ]

# Configure plot
sns.set(style="whitegrid")  # Set the plot style
plt.figure(figsize=(10, 6))  # Set the plot size

# Plotting the line plot
plt.plot(nun_nodes, cray_mpich_results, marker='x', linewidth=4)
plt.plot(nun_nodes, argonne_mpich_results, marker='o', linewidth=2)
plt.plot(nun_nodes, openmpi_results, marker="|", linewidth=1)

# Set labels and title
plt.xlabel('Size')
plt.ylabel('Latency (us)')
plt.title('OSU MPI-CUDA Gather Latency Test v7.1')

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45)

# Add a legend
plt.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left')

# Adjust the layout to prevent labels from being cut off
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ### osu_allgather

# %%
sizes = [
    '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
    '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB', '32MB'
]
num_sizes = len(sizes)

###################################################################
#                       2 NODE RESULTS
###################################################################
cray_mpich1_2n = [
    49.29, 49.36, 49.19, 49.96, 43.35, 43.08, 43.53, 41.68, 36.82, 39.16,
    38.40, 42.33, 42.29, 48.26, 56.19, 71.98, 107.34, 172.90, 313.42,
    584.66, 1129.26, 2420.46, 4781.40, 9522.64
]
cray_mpich2_2n = [
    49.76, 49.37, 49.64, 50.30, 42.98, 42.76, 43.44, 41.73, 36.97, 37.23,
    38.33, 42.55, 42.28, 48.77, 55.97, 71.67, 108.22, 172.31, 314.84,
    590.31, 1138.54, 2429.63, 4797.38, 9528.42
]
cray_mpich3_2n = [
    50.30, 50.73, 51.17, 52.05, 45.76, 45.56, 46.15, 44.08, 39.42, 39.90,
    40.60, 48.09, 49.27, 54.16, 61.43, 77.11, 114.61, 178.26, 323.15,
    593.09, 1135.44, 2511.18, 4902.30, 9714.18
]
cray_mpich4_2n = [
    50.06, 49.63, 49.12, 50.28, 43.51, 43.50, 43.85, 41.72, 36.97, 37.46,
    38.61, 42.54, 42.87, 49.06, 56.59, 72.61, 107.53, 173.79, 314.82,
    587.76, 1136.70, 2434.94, 4803.25, 9533.28
]
cray_mpich5_2n = [
    51.01, 50.70, 50.91, 51.39, 45.29, 45.08, 45.80, 43.47, 38.62, 39.45,
    40.70, 48.33, 48.54, 54.44, 61.85, 77.09, 113.87, 179.47, 320.81,
    590.86, 1139.67, 2503.31, 4923.96, 9703.97
]
cray_mpich_averages_2n = []
for i in range(num_sizes):
    avg = (cray_mpich1_2n[i] + cray_mpich2_2n[i] + cray_mpich3_2n[i] + cray_mpich4_2n[i] + cray_mpich5_2n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_2n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_2n = [

]
argonne_mpich2_2n = [

]
argonne_mpich3_2n = [

]
argonne_mpich4_2n = [

]
argonne_mpich5_2n = [

]
argonne_mpich_averages_2n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_2n[i] + argonne_mpich2_2n[i] + argonne_mpich3_2n[i] + argonne_mpich4_2n[i] + argonne_mpich5_2n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_2n.append(avg)

openmpi1_2n = [

]
openmpi2_2n = [

]
openmpi3_2n = [

]
openmpi4_2n = [

]
openmpi5_2n = [

]
openmpi_averages_2n = []
for i in range(num_sizes):
    avg = (openmpi1_2n[i] + openmpi2_2n[i] + openmpi3_2n[i] + openmpi4_2n[i] + openmpi5_2n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_2n.append(avg)

###################################################################
#                       4 NODE RESULTS
###################################################################
cray_mpich1_4n = [
    64.17, 63.99, 64.36, 59.97, 53.60, 53.52, 54.00, 52.16, 48.03, 49.60,
    57.11, 66.07, 70.16, 81.61, 101.67, 149.48, 241.71, 432.91, 815.46,
    1564.11, 2813.11, 5482.97, 10698.39, 21240.51
]
cray_mpich2_4n = [
    62.62, 62.60, 62.92, 58.48, 53.17, 53.05, 53.63, 51.25, 47.27, 48.67,
    53.83, 62.43, 66.30, 77.44, 98.35, 142.59, 231.16, 410.16, 778.27,
    1491.72, 2791.25, 5406.46, 10639.78, 21130.14
]
cray_mpich3_4n = [
    63.24, 62.38, 62.95, 58.59, 53.05, 52.84, 53.45, 51.52, 47.27, 48.61,
    54.14, 63.58, 66.24, 78.90, 99.35, 145.14, 238.66, 429.92, 814.31,
    1556.60, 2798.94, 5428.01, 10675.06, 21172.54
]
cray_mpich4_4n = [
    64.08, 64.40, 64.92, 60.04, 53.94, 53.80, 54.25, 51.90, 48.13, 49.39,
    57.47, 67.12, 70.86, 83.49, 104.93, 151.44, 245.56, 441.44, 828.33,
    1576.34, 2824.20, 5485.06, 10753.92, 21301.40
]
cray_mpich5_4n = [
    63.88, 63.86, 64.02, 59.87, 53.54, 53.41, 53.77, 52.01, 48.21, 49.16,
    57.19, 65.11, 69.70, 80.49, 101.97, 148.74, 240.35, 433.01, 818.13,
    1557.55, 2819.09, 5467.14, 10724.80, 21270.75
]
cray_mpich_averages_4n = []
for i in range(num_sizes):
    avg = (cray_mpich1_4n[i] + cray_mpich2_4n[i] + cray_mpich3_4n[i] + cray_mpich4_4n[i] + cray_mpich5_4n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_4n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_4n = [

]
argonne_mpich2_4n = [

]
argonne_mpich3_4n = [

]
argonne_mpich4_4n = [

]
argonne_mpich5_4n = [

]
argonne_mpich_averages_4n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_4n[i] + argonne_mpich2_4n[i] + argonne_mpich3_4n[i] + argonne_mpich4_4n[i] + argonne_mpich5_4n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_4n.append(avg)

openmpi1_4n = [

]
openmpi2_4n = [

]
openmpi3_4n = [

]
openmpi4_4n = [

]
openmpi5_4n = [

]
openmpi_averages_4n = []
for i in range(num_sizes):
    avg = (openmpi1_4n[i] + openmpi2_4n[i] + openmpi3_4n[i] + openmpi4_4n[i] + openmpi5_4n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_4n.append(avg)

###################################################################
#                       6 NODE RESULTS
###################################################################
cray_mpich1_6n = [
    42.52, 42.49, 43.01, 47.86, 49.93, 51.38, 54.73, 56.79, 58.57, 63.61,
    85.42, 106.94, 143.54, 210.92, 327.56, 545.31, 662.02, 907.36, 1406.98,
    0, 0, 0, 0, 0
]
cray_mpich2_6n = [
    41.53, 41.43, 42.09, 46.53, 48.04, 49.37, 52.48, 53.89, 56.58, 61.22,
    82.27, 104.20, 140.56, 205.04, 323.36, 514.33, 642.68, 883.33, 1362.61,
    0, 0, 0, 0, 0
]
cray_mpich3_6n = [
    42.69, 42.61, 43.15, 47.53, 49.70, 51.09, 54.19, 55.69, 58.12, 63.87,
    84.17, 106.26, 142.86, 211.62, 326.96, 534.23, 666.00, 913.87, 1411.19,
    0, 0, 0, 0, 0
]
cray_mpich4_6n = [
    41.90, 41.46, 42.07, 46.91, 49.55, 50.98, 54.34, 55.50, 58.03, 63.08,
    84.12, 106.38, 143.07, 209.35, 326.13, 520.25, 648.29, 893.28, 1374.60,
    0, 0, 0, 0, 0
]
cray_mpich5_6n = [
    42.09, 42.05, 42.54, 47.34, 49.35, 50.73, 53.96, 55.42, 57.74, 62.94,
    83.64, 106.30, 142.34, 208.54, 324.35, 526.01, 655.66, 900.97, 1382.84,
    0, 0, 0, 0, 0
]
cray_mpich_averages_6n = []
for i in range(num_sizes):
    avg = (cray_mpich1_6n[i] + cray_mpich2_6n[i] + cray_mpich3_6n[i] + cray_mpich4_6n[i] + cray_mpich5_6n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_6n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_6n = [

]
argonne_mpich2_6n = [

]
argonne_mpich3_6n = [

]
argonne_mpich4_6n = [

]
argonne_mpich5_6n = [

]
argonne_mpich_averages_6n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_6n[i] + argonne_mpich2_6n[i] + argonne_mpich3_6n[i] + argonne_mpich4_6n[i] + argonne_mpich5_6n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_6n.append(avg)

openmpi1_6n = [

]
openmpi2_6n = [

]
openmpi3_6n = [

]
openmpi4_6n = [

]
openmpi5_6n = [

]
openmpi_averages_6n = []
for i in range(num_sizes):
    avg = (openmpi1_6n[i] + openmpi2_6n[i] + openmpi3_6n[i] + openmpi4_6n[i] + openmpi5_6n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_6n.append(avg)

###################################################################
#                       8 NODE RESULTS
###################################################################
cray_mpich1_8n = [
    76.15, 76.25, 71.62, 66.90, 61.64, 61.46, 62.32, 60.64, 57.45, 66.27,
    75.46, 87.80, 97.91, 123.30, 175.10, 279.48, 503.17, 942.63, 1863.73,
    0, 0, 0, 0, 0
]
cray_mpich2_8n = [
    76.78, 77.08, 73.34, 68.75, 62.09, 62.28, 62.71, 61.08, 57.55, 66.36,
    75.45, 88.05, 100.32, 124.67, 176.00, 285.18, 513.91, 966.27, 1929.00,
    0, 0, 0, 0, 0
]
cray_mpich3_8n = [
    76.64, 76.98, 72.40, 67.87, 61.86, 61.65, 62.85, 61.36, 57.62, 66.37,
    76.66, 87.14, 97.03, 122.53, 174.17, 281.76, 504.49, 944.07, 1868.96,
    0, 0, 0, 0, 0
]
cray_mpich4_8n = [
    77.61, 77.81, 73.40, 68.42, 62.43, 62.37, 63.01, 62.54, 58.39, 67.07,
    77.09, 89.54, 99.31, 126.04, 177.50, 286.52, 509.20, 950.60, 1863.23,
    0, 0, 0, 0, 0
]
cray_mpich5_8n = [
    77.36, 77.76, 72.60, 68.41, 62.53, 62.34, 63.02, 61.44, 58.37, 66.89,
    76.86, 89.03, 98.89, 125.04, 176.87, 283.83, 506.02, 946.12, 1884.62,
    0, 0, 0, 0, 0
]
cray_mpich_averages_8n = []
for i in range(num_sizes):
    avg = (cray_mpich1_8n[i] + cray_mpich2_8n[i] + cray_mpich3_8n[i] + cray_mpich4_8n[i] + cray_mpich5_8n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_8n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_8n = [

]
argonne_mpich2_8n = [

]
argonne_mpich3_8n = [

]
argonne_mpich4_8n = [

]
argonne_mpich5_8n = [

]
argonne_mpich_averages_8n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_8n[i] + argonne_mpich2_8n[i] + argonne_mpich3_8n[i] + argonne_mpich4_8n[i] + argonne_mpich5_8n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_8n.append(avg)

openmpi1_8n = [

]
openmpi2_8n = [

]
openmpi3_8n = [

]
openmpi4_8n = [

]
openmpi5_8n = [

]
openmpi_averages_8n = []
for i in range(num_sizes):
    avg = (openmpi1_8n[i] + openmpi2_8n[i] + openmpi3_8n[i] + openmpi4_8n[i] + openmpi5_8n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_8n.append(avg)

###################################################################
#                       10 NODE RESULTS
###################################################################
cray_mpich1_10n = [

]
cray_mpich2_10n = [

]
cray_mpich3_10n = [

]
cray_mpich4_10n = [

]
cray_mpich5_10n = [

]
cray_mpich_averages_10n = []
for i in range(num_sizes):
    avg = (cray_mpich1_10n[i] + cray_mpich2_10n[i] + cray_mpich3_10n[i] + cray_mpich4_10n[i] + cray_mpich5_10n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_10n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_10n = [

]
argonne_mpich2_10n = [

]
argonne_mpich3_10n = [

]
argonne_mpich4_10n = [

]
argonne_mpich5_10n = [

]
argonne_mpich_averages_10n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_10n[i] + argonne_mpich2_10n[i] + argonne_mpich3_10n[i] + argonne_mpich4_10n[i] + argonne_mpich5_10n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_10n.append(avg)

openmpi1_10n = [

]
openmpi2_10n = [

]
openmpi3_10n = [

]
openmpi4_10n = [

]
openmpi5_10n = [

]
openmpi_averages_10n = []
for i in range(num_sizes):
    avg = (openmpi1_10n[i] + openmpi2_10n[i] + openmpi3_10n[i] + openmpi4_10n[i] + openmpi5_10n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_10n.append(avg)

##########################################################################################################################

# Number of nodes used
nun_nodes = [2, 4, 6, 8, 10]

# Averages latencies for 16MB message size, scaling nodes FIXME: change array indeces if we choose to look at a different message size
cray_mpich_results = [ cray_mpich_averages_2n[-6], cray_mpich_averages_4n[-6], cray_mpich_averages_6n[-6], cray_mpich_averages_8n[-6], cray_mpich_averages_10n[-6] ]
argonne_mpich_results = [ argonne_mpich_averages_2n[-6], argonne_mpich_averages_4n[-6], argonne_mpich_averages_6n[-6], argonne_mpich_averages_8n[-6], argonne_mpich_averages_10n[-6] ]
openmpi_results = [ openmpi_averages_2n[-6], openmpi_averages_4n[-6], openmpi1_6n[-6], openmpi1_8n[-6], openmpi1_10n[-6] ]

# Configure plot
sns.set(style="whitegrid")  # Set the plot style
plt.figure(figsize=(10, 6))  # Set the plot size

# Plotting the line plot
plt.plot(nun_nodes, cray_mpich_results, marker='x', linewidth=4)
plt.plot(nun_nodes, argonne_mpich_results, marker='o', linewidth=2)
plt.plot(nun_nodes, openmpi_results, marker="|", linewidth=1)

# Set labels and title
plt.xlabel('Size')
plt.ylabel('Latency (us)')
plt.title('OSU MPI-CUDA AllGather Latency Test v7.1')

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45)

# Add a legend
plt.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left')

# Adjust the layout to prevent labels from being cut off
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ### osu_reduce

# %%
sizes = [
    '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
    '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB', '32MB'
]
num_sizes = len(sizes)

###################################################################
#                       2 NODE RESULTS
###################################################################
cray_mpich1_2n = [
    14.78, 14.70, 14.94, 15.11, 15.13, 15.39, 15.88, 16.04, 22.88, 23.99,
    195.99, 236.89, 239.01, 268.52, 277.93, 299.53, 373.46, 541.02, 858.53,
    5454.92, 9222.04, 17568.52, 34934.22, 64017.46
]
cray_mpich2_2n = [
    14.77, 14.59, 14.81, 14.91, 14.89, 15.17, 15.63, 15.87, 22.38, 23.61,
    195.87, 231.78, 244.83, 274.25, 265.87, 293.78, 349.23, 605.04, 890.44,
    5472.56, 9351.30, 18021.84, 35274.13, 63673.95
]

cray_mpich3_2n = [
    14.73, 14.75, 14.99, 15.06, 15.06, 15.35, 16.09, 16.33, 23.81, 24.88,
    190.31, 236.76, 238.01, 261.34, 272.10, 293.09, 376.57, 534.06, 893.12,
    5432.42, 9352.60, 17645.87, 34854.72, 64645.49
]
cray_mpich4_2n = [
    14.35, 14.31, 14.53, 14.58, 14.60, 14.84, 15.32, 15.48, 22.40, 23.58,
    183.40, 229.48, 243.35, 248.87, 272.50, 294.31, 347.69, 533.25, 878.38,
    5505.18, 9123.61, 17209.90, 34702.09, 64541.75
]
cray_mpich5_2n = [
    14.91, 15.05, 15.32, 15.14, 15.15, 15.49, 16.36, 16.40, 23.67, 24.87,
    198.52, 246.34, 247.81, 280.80, 304.04, 303.77, 387.24, 533.86, 885.53,
    5666.74, 9406.59, 17703.12, 34703.79, 63808.60
]
cray_mpich_averages_2n = []
for i in range(num_sizes):
    avg = (cray_mpich1_2n[i] + cray_mpich2_2n[i] + cray_mpich3_2n[i] + cray_mpich4_2n[i] + cray_mpich5_2n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_2n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_2n = [

]
argonne_mpich2_2n = [

]
argonne_mpich3_2n = [

]
argonne_mpich4_2n = [

]
argonne_mpich5_2n = [

]
argonne_mpich_averages_2n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_2n[i] + argonne_mpich2_2n[i] + argonne_mpich3_2n[i] + argonne_mpich4_2n[i] + argonne_mpich5_2n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_2n.append(avg)

openmpi1_2n = [

]
openmpi2_2n = [

]
openmpi3_2n = [

]
openmpi4_2n = [

]
openmpi5_2n = [

]
openmpi_averages_2n = []
for i in range(num_sizes):
    avg = (openmpi1_2n[i] + openmpi2_2n[i] + openmpi3_2n[i] + openmpi4_2n[i] + openmpi5_2n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_2n.append(avg)

###################################################################
#                       4 NODE RESULTS
###################################################################
cray_mpich1_4n = [
    13.53, 13.51, 13.76, 13.76, 13.75, 14.07, 15.01, 15.28, 19.96, 21.04,
    112.27, 136.85, 138.37, 145.06, 164.28, 197.20, 241.61, 377.57, 656.08,
    4422.10, 7437.16, 14493.11, 28422.10, 52672.29
]
cray_mpich2_4n = [
    13.65, 13.56, 13.74, 13.73, 13.75, 14.11, 14.97, 15.24, 19.75, 20.74,
    127.39, 152.60, 153.85, 166.26, 190.18, 216.86, 270.05, 423.04, 712.88,
    4470.51, 7520.65, 14374.27, 28451.60, 52058.65
]
cray_mpich3_4n = [
    13.88, 13.61, 13.83, 13.94, 13.88, 14.18, 15.02, 15.30, 19.87, 21.04,
    121.53, 149.44, 158.51, 159.96, 185.35, 205.20, 274.15, 420.61, 699.77,
    4474.88, 7528.75, 14342.73, 28399.81, 51442.07
]
cray_mpich4_4n = [
    13.94, 13.98, 14.19, 14.20, 14.18, 14.44, 15.46, 15.66, 20.63, 21.85,
    123.50, 152.70, 150.59, 158.61, 189.16, 221.94, 262.05, 412.91, 688.37,
    4504.22, 7580.22, 14409.22, 28602.35, 52055.25
]
cray_mpich5_4n = [
    13.88, 13.68, 13.97, 13.90, 13.98, 14.30, 15.17, 15.35, 20.10, 21.16,
    125.30, 154.26, 170.33, 161.32, 185.80, 213.27, 277.22, 427.02, 697.99,
    4501.19, 7628.05, 14321.94, 28331.16, 51944.58
]
cray_mpich_averages_4n = []
for i in range(num_sizes):
    avg = (cray_mpich1_4n[i] + cray_mpich2_4n[i] + cray_mpich3_4n[i] + cray_mpich4_4n[i] + cray_mpich5_4n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_4n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_4n = [

]
argonne_mpich2_4n = [

]
argonne_mpich3_4n = [

]
argonne_mpich4_4n = [

]
argonne_mpich5_4n = [

]
argonne_mpich_averages_4n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_4n[i] + argonne_mpich2_4n[i] + argonne_mpich3_4n[i] + argonne_mpich4_4n[i] + argonne_mpich5_4n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_4n.append(avg)

openmpi1_4n = [

]
openmpi2_4n = [

]
openmpi3_4n = [

]
openmpi4_4n = [

]
openmpi5_4n = [

]
openmpi_averages_4n = []
for i in range(num_sizes):
    avg = (openmpi1_4n[i] + openmpi2_4n[i] + openmpi3_4n[i] + openmpi4_4n[i] + openmpi5_4n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_4n.append(avg)

###################################################################
#                       6 NODE RESULTS
###################################################################
cray_mpich1_6n = [
    13.09, 13.05, 13.26, 13.36, 13.35, 13.51, 14.69, 14.92, 18.09, 19.06,
    91.54, 110.57, 120.83, 126.36, 144.69, 176.87, 239.30, 382.18, 658.98,
    4130.39, 6999.97, 13528.45, 26497.19, 49422.77
]
cray_mpich2_6n = [
    13.20, 13.20, 13.41, 13.45, 13.51, 13.69, 14.64, 14.86, 18.29, 19.07,
    92.84, 114.56, 114.35, 128.61, 154.86, 177.76, 249.96, 387.94, 663.08,
    4185.13, 7144.51, 13691.50, 26483.05, 49133.46
]
cray_mpich3_6n = [
    13.35, 13.25, 13.51, 13.56, 13.57, 13.76, 14.88, 15.07, 18.44, 19.47,
    91.96, 110.83, 126.21, 135.15, 147.64, 176.67, 232.63, 372.18, 670.29,
    4221.90, 7212.21, 13757.58, 26844.75, 49108.97
]
cray_mpich4_6n = [
    13.41, 13.38, 13.61, 13.67, 13.67, 13.88, 15.13, 15.23, 18.76, 19.83,
    91.39, 110.58, 117.05, 131.38, 145.01, 212.23, 240.15, 386.98, 667.96,
    4236.91, 7240.23, 13806.91, 27016.70, 49305.72
]
cray_mpich5_6n = [
    13.05, 13.03, 13.27, 13.34, 13.36, 13.55, 14.60, 14.77, 18.11, 19.15,
    89.55, 111.49, 118.00, 126.51, 152.14, 190.87, 234.58, 373.77, 654.94,
    4171.92, 7165.39, 13775.33, 26960.05, 48844.74
]
cray_mpich_averages_6n = []
for i in range(num_sizes):
    avg = (cray_mpich1_6n[i] + cray_mpich2_6n[i] + cray_mpich3_6n[i] + cray_mpich4_6n[i] + cray_mpich5_6n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_6n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_6n = [

]
argonne_mpich2_6n = [

]
argonne_mpich3_6n = [

]
argonne_mpich4_6n = [

]
argonne_mpich5_6n = [

]
argonne_mpich_averages_6n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_6n[i] + argonne_mpich2_6n[i] + argonne_mpich3_6n[i] + argonne_mpich4_6n[i] + argonne_mpich5_6n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_6n.append(avg)

openmpi1_6n = [

]
openmpi2_6n = [

]
openmpi3_6n = [

]
openmpi4_6n = [

]
openmpi5_6n = [

]
openmpi_averages_6n = []
for i in range(num_sizes):
    avg = (openmpi1_6n[i] + openmpi2_6n[i] + openmpi3_6n[i] + openmpi4_6n[i] + openmpi5_6n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_6n.append(avg)

###################################################################
#                       8 NODE RESULTS
###################################################################
cray_mpich1_8n = [
    13.25, 13.22, 13.44, 13.49, 13.53, 13.76, 14.85, 15.04, 18.26, 19.26,
    89.91, 108.46, 113.08, 119.85, 131.59, 164.66, 207.56, 334.06, 589.87,
    3929.16, 6701.57, 12836.01, 25437.23, 45617.73
]
cray_mpich2_8n = [
    13.20, 13.21, 13.47, 13.48, 13.53, 13.74, 14.84, 14.95, 18.16, 19.16,
    89.98, 108.46, 113.18, 120.03, 137.82, 157.50, 208.60, 331.43, 590.85,
    3892.09, 6665.53, 12849.13, 25409.22, 45979.64
]
cray_mpich3_8n = [
    13.33, 13.33, 13.53, 13.59, 13.64, 13.87, 14.94, 15.13, 18.37, 19.34,
    87.12, 106.21, 107.41, 113.78, 135.12, 168.02, 209.35, 341.98, 604.30,
    3959.88, 6785.00, 12968.33, 25357.10, 45409.37
]
cray_mpich4_8n = [
    13.40, 13.47, 13.60, 13.69, 13.74, 13.95, 15.25, 15.47, 18.67, 19.73,
    85.99, 104.73, 108.87, 110.94, 130.11, 165.15, 212.72, 334.22, 588.72,
    3924.43, 6731.47, 12803.75, 25064.66, 45636.11
]
cray_mpich5_8n = [
    13.48, 13.44, 13.66, 13.70, 13.76, 13.96, 15.14, 15.30, 18.65, 19.73,
    87.08, 109.23, 107.15, 121.80, 130.90, 166.36, 216.14, 341.18, 611.00,
    3976.28, 6744.70, 12860.84, 25129.89, 45567.95
]
cray_mpich_averages_8n = []
for i in range(num_sizes):
    avg = (cray_mpich1_8n[i] + cray_mpich2_8n[i] + cray_mpich3_8n[i] + cray_mpich4_8n[i] + cray_mpich5_8n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_8n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_8n = [

]
argonne_mpich2_8n = [

]
argonne_mpich3_8n = [

]
argonne_mpich4_8n = [

]
argonne_mpich5_8n = [

]
argonne_mpich_averages_8n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_8n[i] + argonne_mpich2_8n[i] + argonne_mpich3_8n[i] + argonne_mpich4_8n[i] + argonne_mpich5_8n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_8n.append(avg)

openmpi1_8n = [

]
openmpi2_8n = [

]
openmpi3_8n = [

]
openmpi4_8n = [

]
openmpi5_8n = [

]
openmpi_averages_8n = []
for i in range(num_sizes):
    avg = (openmpi1_8n[i] + openmpi2_8n[i] + openmpi3_8n[i] + openmpi4_8n[i] + openmpi5_8n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_8n.append(avg)

###################################################################
#                       10 NODE RESULTS
###################################################################
cray_mpich1_10n = [

]
cray_mpich2_10n = [

]
cray_mpich3_10n = [

]
cray_mpich4_10n = [

]
cray_mpich5_10n = [

]
cray_mpich_averages_10n = []
for i in range(num_sizes):
    avg = (cray_mpich1_10n[i] + cray_mpich2_10n[i] + cray_mpich3_10n[i] + cray_mpich4_10n[i] + cray_mpich5_10n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_10n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_10n = [

]
argonne_mpich2_10n = [

]
argonne_mpich3_10n = [

]
argonne_mpich4_10n = [

]
argonne_mpich5_10n = [

]
argonne_mpich_averages_10n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_10n[i] + argonne_mpich2_10n[i] + argonne_mpich3_10n[i] + argonne_mpich4_10n[i] + argonne_mpich5_10n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_10n.append(avg)

openmpi1_10n = [

]
openmpi2_10n = [

]
openmpi3_10n = [

]
openmpi4_10n = [

]
openmpi5_10n = [

]
openmpi_averages_10n = []
for i in range(num_sizes):
    avg = (openmpi1_10n[i] + openmpi2_10n[i] + openmpi3_10n[i] + openmpi4_10n[i] + openmpi5_10n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_10n.append(avg)

##########################################################################################################################

# Number of nodes used
nun_nodes = [2, 4, 6, 8, 10]

# Averages latencies for 16MB message size, scaling nodes FIXME: change array indeces if we choose to look at a different message size
cray_mpich_results = [ cray_mpich_averages_2n[-6], cray_mpich_averages_4n[-6], cray_mpich_averages_6n[-6], cray_mpich_averages_8n[-6], cray_mpich_averages_10n[-6] ]
argonne_mpich_results = [ argonne_mpich_averages_2n[-6], argonne_mpich_averages_4n[-6], argonne_mpich_averages_6n[-6], argonne_mpich_averages_8n[-6], argonne_mpich_averages_10n[-6] ]
openmpi_results = [ openmpi_averages_2n[-6], openmpi_averages_4n[-6], openmpi1_6n[-6], openmpi1_8n[-6], openmpi1_10n[-6] ]

# Configure plot
sns.set(style="whitegrid")  # Set the plot style
plt.figure(figsize=(10, 6))  # Set the plot size

# Plotting the line plot
plt.plot(nun_nodes, cray_mpich_results, marker='x', linewidth=4)
plt.plot(nun_nodes, argonne_mpich_results, marker='o', linewidth=2)
plt.plot(nun_nodes, openmpi_results, marker="|", linewidth=1)

# Set labels and title
plt.xlabel('Size')
plt.ylabel('Latency (us)')
plt.title('OSU MPI-CUDA Reduce Latency Test v7.1')

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45)

# Add a legend
plt.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left')

# Adjust the layout to prevent labels from being cut off
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ### osu_allreduce

# %%
sizes = [
    '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
    '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB', '32MB'
]
num_sizes = len(sizes)

###################################################################
#                       2 NODE RESULTS
###################################################################
cray_mpich1_2n = [
    32.99, 32.58, 32.73, 32.95, 32.83, 33.70, 28.75, 29.04, 28.47, 28.20,
    39.84, 42.24, 47.02, 56.10, 75.71, 100.68, 113.46, 122.21, 141.75,
    180.12, 246.52, 391.08, 790.53, 1598.14
]
cray_mpich2_2n = [
    32.45, 32.36, 32.53, 32.49, 32.58, 33.27, 28.69, 29.37, 28.68, 28.96,
    40.52, 42.93, 47.51, 56.30, 78.08, 101.93, 114.68, 122.48, 140.16,
    179.23, 248.80, 394.48, 795.87, 1621.00
]
cray_mpich3_2n = [
    33.95, 34.05, 34.30, 34.37, 34.37, 35.18, 31.90, 32.61, 31.63, 31.56,
    45.39, 48.35, 53.00, 64.11, 83.97, 109.66, 128.28, 137.87, 153.48,
    189.42, 259.36, 406.38, 815.65, 1633.13
]
cray_mpich4_2n = [
    33.00, 32.48, 32.74, 32.63, 32.47, 33.50, 28.80, 29.69, 29.04, 29.06,
    40.77, 43.30, 47.59, 60.48, 81.47, 105.13, 114.66, 123.07, 142.47,
    180.04, 250.81, 396.38, 796.65, 1601.53
]
cray_mpich5_2n = [
    34.00, 33.71, 33.87, 33.91, 33.95, 34.83, 31.52, 32.16, 31.20, 31.28,
    45.53, 47.78, 52.93, 61.97, 82.80, 108.19, 127.71, 137.53, 151.32,
    189.75, 259.22, 407.19, 820.69, 1656.89
]
cray_mpich_averages_2n = []
for i in range(num_sizes):
    avg = (cray_mpich1_2n[i] + cray_mpich2_2n[i] + cray_mpich3_2n[i] + cray_mpich4_2n[i] + cray_mpich5_2n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_2n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_2n = [

]
argonne_mpich2_2n = [

]
argonne_mpich3_2n = [

]
argonne_mpich4_2n = [

]
argonne_mpich5_2n = [

]
argonne_mpich_averages_2n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_2n[i] + argonne_mpich2_2n[i] + argonne_mpich3_2n[i] + argonne_mpich4_2n[i] + argonne_mpich5_2n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_2n.append(avg)

openmpi1_2n = [

]
openmpi2_2n = [

]
openmpi3_2n = [

]
openmpi4_2n = [

]
openmpi5_2n = [

]
openmpi_averages_2n = []
for i in range(num_sizes):
    avg = (openmpi1_2n[i] + openmpi2_2n[i] + openmpi3_2n[i] + openmpi4_2n[i] + openmpi5_2n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_2n.append(avg)

###################################################################
#                       4 NODE RESULTS
###################################################################
cray_mpich1_4n = [
    38.55, 38.42, 38.48, 38.53, 38.62, 39.69, 37.57, 38.35, 37.88, 38.80,
    57.49, 60.24, 65.76, 74.84, 96.19, 139.79, 157.00, 176.70, 199.08, 240.39,
    328.95, 509.87, 1031.70, 2092.46
]
cray_mpich2_4n = [
    38.22, 37.95, 38.14, 38.17, 38.25, 39.23, 36.66, 37.38, 36.47, 37.57,
    55.92, 59.61, 64.21, 73.86, 95.42, 148.15, 155.99, 174.80, 197.20, 239.18,
    325.11, 509.18, 1032.13, 2085.74
]
cray_mpich3_4n = [
    37.70, 37.61, 37.92, 38.03, 38.59, 39.65, 37.33, 37.95, 37.37, 38.33,
    56.32, 59.48, 64.22, 73.96, 95.29, 141.24, 155.51, 175.93, 197.56, 242.52,
    327.09, 504.20, 1031.25, 2082.20
]
cray_mpich4_4n = [
    39.38, 39.13, 39.32, 39.25, 39.26, 40.30, 39.18, 39.74, 39.50, 40.14,
    60.27, 62.53, 67.66, 76.83, 97.72, 138.42, 159.31, 181.28, 204.43, 248.56,
    333.97, 513.30, 1046.27, 2160.65
]
cray_mpich5_4n = [
    38.69, 38.61, 38.78, 38.85, 38.97, 39.96, 38.09, 38.61, 38.06, 38.99,
    57.82, 60.45, 66.06, 75.89, 111.80, 154.71, 157.09, 178.45, 202.95, 244.15,
    330.67, 513.08, 1038.24, 2108.15
]
cray_mpich_averages_4n = []
for i in range(num_sizes):
    avg = (cray_mpich1_4n[i] + cray_mpich2_4n[i] + cray_mpich3_4n[i] + cray_mpich4_4n[i] + cray_mpich5_4n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_4n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_4n = [

]
argonne_mpich2_4n = [

]
argonne_mpich3_4n = [

]
argonne_mpich4_4n = [

]
argonne_mpich5_4n = [

]
argonne_mpich_averages_4n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_4n[i] + argonne_mpich2_4n[i] + argonne_mpich3_4n[i] + argonne_mpich4_4n[i] + argonne_mpich5_4n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_4n.append(avg)

openmpi1_4n = [

]
openmpi2_4n = [

]
openmpi3_4n = [

]
openmpi4_4n = [

]
openmpi5_4n = [

]
openmpi_averages_4n = []
for i in range(num_sizes):
    avg = (openmpi1_4n[i] + openmpi2_4n[i] + openmpi3_4n[i] + openmpi4_4n[i] + openmpi5_4n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_4n.append(avg)

###################################################################
#                       6 NODE RESULTS
###################################################################
cray_mpich1_6n = [
    43.33, 43.03, 43.24, 43.32, 43.37, 44.31, 46.24, 46.91, 46.59, 48.56,
    69.61, 74.25, 81.97, 97.78, 129.41, 178.95, 201.60, 231.35, 280.31,
    367.07, 526.18, 873.57, 1833.47, 3758.78
]
cray_mpich2_6n = [
    42.58, 42.54, 42.57, 42.49, 42.61, 44.10, 44.10, 44.99, 44.80, 46.67,
    67.62, 72.01, 80.34, 98.10, 128.30, 178.80, 196.08, 226.24, 272.87,
    354.74, 517.55, 862.41, 1809.84, 3713.06
]
cray_mpich3_6n = [
    43.89, 43.56, 43.93, 43.67, 43.86, 45.13, 46.38, 47.38, 47.09, 48.09,
    71.43, 74.04, 83.10, 97.26, 129.29, 179.38, 201.10, 231.23, 282.25,
    371.07, 525.69, 879.70, 1867.24, 3774.24
]
cray_mpich4_6n = [
    43.82, 43.60, 43.77, 43.98, 43.81, 45.08, 47.24, 48.06, 48.98, 49.19,
    71.81, 76.03, 83.39, 98.53, 137.81, 180.83, 204.21, 236.42, 282.97,
    368.72, 530.80, 886.52, 1850.34, 3799.90
]
cray_mpich5_6n = [
    42.51, 42.50, 42.67, 42.63, 42.55, 43.56, 45.30, 46.18, 45.87, 46.82,
    69.63, 72.53, 80.30, 122.97, 125.89, 176.43, 197.39, 230.84, 275.21,
    353.12, 519.67, 862.84, 1802.19, 3711.81, 0.0
]
cray_mpich_averages_6n = []
for i in range(num_sizes):
    avg = (cray_mpich1_6n[i] + cray_mpich2_6n[i] + cray_mpich3_6n[i] + cray_mpich4_6n[i] + cray_mpich5_6n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_6n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_6n = [

]
argonne_mpich2_6n = [

]
argonne_mpich3_6n = [

]
argonne_mpich4_6n = [

]
argonne_mpich5_6n = [

]
argonne_mpich_averages_6n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_6n[i] + argonne_mpich2_6n[i] + argonne_mpich3_6n[i] + argonne_mpich4_6n[i] + argonne_mpich5_6n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_6n.append(avg)

openmpi1_6n = [

]
openmpi2_6n = [

]
openmpi3_6n = [

]
openmpi4_6n = [

]
openmpi5_6n = [

]
openmpi_averages_6n = []
for i in range(num_sizes):
    avg = (openmpi1_6n[i] + openmpi2_6n[i] + openmpi3_6n[i] + openmpi4_6n[i] + openmpi5_6n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_6n.append(avg)

###################################################################
#                       8 NODE RESULTS
###################################################################
cray_mpich1_8n = [
    43.48, 43.60, 43.72, 43.68, 43.72, 44.83, 45.12, 46.00, 45.81, 47.22,
    68.53, 74.65, 79.79, 104.22, 110.87, 184.48, 187.57, 213.15, 248.08,
    316.70, 391.04, 586.94, 1203.82, 2457.54
]
cray_mpich2_8n = [
    43.45, 43.51, 43.67, 43.59, 43.61, 44.55, 45.33, 46.11, 45.86, 47.21,
    67.18, 73.82, 78.84, 88.71, 145.49, 178.33, 196.13, 218.44, 251.28,
    315.35, 393.80, 597.46, 1212.11, 2532.35
]
cray_mpich3_8n = [
    43.86, 43.82, 43.92, 43.94, 44.07, 44.99, 45.15, 45.90, 45.46, 47.13,
    67.75, 75.48, 79.56, 89.65, 111.67, 189.39, 184.03, 212.57, 245.62,
    309.24, 389.10, 587.01, 1206.14, 2460.21
]
cray_mpich4_8n = [
    44.86, 44.48, 44.72, 44.81, 44.97, 45.76, 46.66, 47.53, 47.23, 48.84,
    71.61, 77.62, 83.03, 92.95, 114.60, 194.28, 195.25, 222.24, 259.35,
    311.29, 397.83, 602.98, 1209.26, 2499.20
]
cray_mpich5_8n = [
    44.28, 44.22, 44.37, 44.34, 44.37, 45.47, 45.76, 46.66, 46.76, 47.76,
    69.26, 76.16, 81.01, 91.16, 128.80, 198.81, 188.65, 214.94, 255.21,
    312.93, 396.96, 601.35, 1219.42, 2486.63
]
cray_mpich_averages_8n = []
for i in range(num_sizes):
    avg = (cray_mpich1_8n[i] + cray_mpich2_8n[i] + cray_mpich3_8n[i] + cray_mpich4_8n[i] + cray_mpich5_8n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_8n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_8n = [

]
argonne_mpich2_8n = [

]
argonne_mpich3_8n = [

]
argonne_mpich4_8n = [

]
argonne_mpich5_8n = [

]
argonne_mpich_averages_8n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_8n[i] + argonne_mpich2_8n[i] + argonne_mpich3_8n[i] + argonne_mpich4_8n[i] + argonne_mpich5_8n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_8n.append(avg)

openmpi1_8n = [

]
openmpi2_8n = [

]
openmpi3_8n = [

]
openmpi4_8n = [

]
openmpi5_8n = [

]
openmpi_averages_8n = []
for i in range(num_sizes):
    avg = (openmpi1_8n[i] + openmpi2_8n[i] + openmpi3_8n[i] + openmpi4_8n[i] + openmpi5_8n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_8n.append(avg)

###################################################################
#                       10 NODE RESULTS
###################################################################
cray_mpich1_10n = [

]
cray_mpich2_10n = [

]
cray_mpich3_10n = [

]
cray_mpich4_10n = [

]
cray_mpich5_10n = [

]
cray_mpich_averages_10n = []
for i in range(num_sizes):
    avg = (cray_mpich1_10n[i] + cray_mpich2_10n[i] + cray_mpich3_10n[i] + cray_mpich4_10n[i] + cray_mpich5_10n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_10n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_10n = [

]
argonne_mpich2_10n = [

]
argonne_mpich3_10n = [

]
argonne_mpich4_10n = [

]
argonne_mpich5_10n = [

]
argonne_mpich_averages_10n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_10n[i] + argonne_mpich2_10n[i] + argonne_mpich3_10n[i] + argonne_mpich4_10n[i] + argonne_mpich5_10n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_10n.append(avg)

openmpi1_10n = [

]
openmpi2_10n = [

]
openmpi3_10n = [

]
openmpi4_10n = [

]
openmpi5_10n = [

]
openmpi_averages_10n = []
for i in range(num_sizes):
    avg = (openmpi1_10n[i] + openmpi2_10n[i] + openmpi3_10n[i] + openmpi4_10n[i] + openmpi5_10n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_10n.append(avg)

##########################################################################################################################

# Number of nodes used
nun_nodes = [2, 4, 6, 8, 10]

# Averages latencies for 16MB message size, scaling nodes FIXME: change array indeces if we choose to look at a different message size
cray_mpich_results = [ cray_mpich_averages_2n[-6], cray_mpich_averages_4n[-6], cray_mpich_averages_6n[-6], cray_mpich_averages_8n[-6], cray_mpich_averages_10n[-6] ]
argonne_mpich_results = [ argonne_mpich_averages_2n[-6], argonne_mpich_averages_4n[-6], argonne_mpich_averages_6n[-6], argonne_mpich_averages_8n[-6], argonne_mpich_averages_10n[-6] ]
openmpi_results = [ openmpi_averages_2n[-6], openmpi_averages_4n[-6], openmpi1_6n[-6], openmpi1_8n[-6], openmpi1_10n[-6] ]

# Configure plot
sns.set(style="whitegrid")  # Set the plot style
plt.figure(figsize=(10, 6))  # Set the plot size

# Plotting the line plot
plt.plot(nun_nodes, cray_mpich_results, marker='x', linewidth=4)
plt.plot(nun_nodes, argonne_mpich_results, marker='o', linewidth=2)
plt.plot(nun_nodes, openmpi_results, marker="|", linewidth=1)

# Set labels and title
plt.xlabel('Size')
plt.ylabel('Latency (us)')
plt.title('OSU MPI-CUDA AllReduce Latency Test v7.1')

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45)

# Add a legend
plt.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left')

# Adjust the layout to prevent labels from being cut off
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ### osu_bcast

# %%
sizes = [
    '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
    '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB', '32MB'
]
num_sizes = len(sizes)

###################################################################
#                       2 NODE RESULTS
###################################################################
cray_mpich1_2n = [
    21.98, 21.88, 22.11, 22.18, 22.13, 22.69, 16.14, 24.98, 17.80, 17.88,
    18.05, 14.24, 14.80, 18.86, 20.92, 24.35, 31.55, 44.62, 74.36, 127.99,
    236.34, 456.52, 898.09, 1779.62
]
cray_mpich2_2n = [
    22.10, 21.85, 22.08, 22.03, 22.03, 22.54, 16.06, 24.80, 17.43, 17.58,
    17.91, 14.16, 14.66, 18.67, 20.81, 24.12, 30.97, 45.45, 72.19, 127.14,
    238.00, 456.33, 897.65, 1782.08
]
cray_mpich3_2n = [
    23.32, 23.43, 23.52, 23.48, 23.42, 24.10, 17.38, 26.67, 18.62, 18.78,
    19.05, 15.36, 16.09, 23.53, 26.56, 29.69, 36.94, 49.95, 79.08, 132.84,
    243.30, 470.80, 918.40, 1803.55
]
cray_mpich4_2n = [
    21.66, 21.67, 21.84, 21.89, 21.84, 22.36, 15.84, 24.51, 17.20, 17.39,
    17.60, 13.92, 14.58, 18.55, 20.65, 23.99, 31.31, 45.07, 72.13, 127.33,
    238.08, 458.14, 897.20, 1780.05
]
cray_mpich5_2n = [
    23.49, 23.44, 23.64, 23.70, 23.69, 24.26, 17.57, 26.61, 18.87, 19.12,
    19.47, 15.51, 16.19, 23.72, 26.70, 29.59, 36.84, 49.96, 78.93, 133.04,
    241.87, 468.23, 918.92, 1809.98
]
cray_mpich_averages_2n = []
for i in range(num_sizes):
    avg = (cray_mpich1_2n[i] + cray_mpich2_2n[i] + cray_mpich3_2n[i] + cray_mpich4_2n[i] + cray_mpich5_2n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_2n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_2n = [

]
argonne_mpich2_2n = [

]
argonne_mpich3_2n = [

]
argonne_mpich4_2n = [

]
argonne_mpich5_2n = [

]
argonne_mpich_averages_2n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_2n[i] + argonne_mpich2_2n[i] + argonne_mpich3_2n[i] + argonne_mpich4_2n[i] + argonne_mpich5_2n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_2n.append(avg)

openmpi1_2n = [

]
openmpi2_2n = [

]
openmpi3_2n = [

]
openmpi4_2n = [

]
openmpi5_2n = [

]
openmpi_averages_2n = []
for i in range(num_sizes):
    avg = (openmpi1_2n[i] + openmpi2_2n[i] + openmpi3_2n[i] + openmpi4_2n[i] + openmpi5_2n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_2n.append(avg)

###################################################################
#                       4 NODE RESULTS
###################################################################
cray_mpich1_4n = [
    34.10, 34.07, 34.58, 34.57, 34.69, 34.95, 17.27, 26.66, 18.56, 18.48,
    18.67, 15.00, 15.71, 21.79, 34.22, 40.54, 55.58, 85.87, 146.60, 270.73,
    517.51, 1016.84, 2052.05, 3985.88
]
cray_mpich2_4n = [
    34.66, 34.64, 35.14, 34.75, 34.78, 35.17, 16.94, 26.09, 18.04, 18.30,
    18.63, 14.76, 15.61, 23.32, 32.96, 39.95, 54.76, 85.32, 147.29, 275.40,
    528.89, 1039.33, 2104.58, 4080.66
]
cray_mpich3_4n = [
    33.29, 33.59, 34.37, 34.33, 34.35, 34.67, 16.86, 25.99, 18.00, 18.16,
    18.35, 14.74, 15.45, 21.02, 29.93, 37.45, 52.18, 83.07, 143.79, 268.96,
    516.43, 1016.02, 2045.98, 3996.07
]
cray_mpich4_4n = [
    33.78, 33.77, 34.25, 34.34, 34.19, 34.27, 16.97, 26.11, 18.14, 18.26,
    18.53, 14.70, 15.58, 23.12, 35.60, 43.24, 57.98, 88.15, 149.80, 278.41,
    528.73, 1040.84, 2112.76, 4085.39
]
cray_mpich5_4n = [
    34.09, 34.04, 34.14, 34.04, 34.03, 34.78, 17.26, 26.30, 18.34, 18.48,
    18.82, 15.11, 16.06, 23.26, 33.92, 40.64, 55.24, 86.55, 146.22, 278.86,
    527.15, 1034.60, 2100.81, 4111.26
]
cray_mpich_averages_4n = []
for i in range(num_sizes):
    avg = (cray_mpich1_4n[i] + cray_mpich2_4n[i] + cray_mpich3_4n[i] + cray_mpich4_4n[i] + cray_mpich5_4n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_4n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_4n = [

]
argonne_mpich2_4n = [

]
argonne_mpich3_4n = [

]
argonne_mpich4_4n = [

]
argonne_mpich5_4n = [

]
argonne_mpich_averages_4n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_4n[i] + argonne_mpich2_4n[i] + argonne_mpich3_4n[i] + argonne_mpich4_4n[i] + argonne_mpich5_4n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_4n.append(avg)

openmpi1_4n = [

]
openmpi2_4n = [

]
openmpi3_4n = [

]
openmpi4_4n = [

]
openmpi5_4n = [

]
openmpi_averages_4n = []
for i in range(num_sizes):
    avg = (openmpi1_4n[i] + openmpi2_4n[i] + openmpi3_4n[i] + openmpi4_4n[i] + openmpi5_4n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_4n.append(avg)

###################################################################
#                       6 NODE RESULTS
###################################################################
cray_mpich1_6n = [
    39.40, 39.41, 40.09, 40.05, 40.17, 40.92, 19.74, 29.45, 21.41, 21.63,
    21.98, 17.54, 18.65, 26.18, 41.29, 50.11, 67.97, 103.10, 176.43,
    329.57, 621.18, 1227.02, 2468.67, 4810.12
]
cray_mpich2_6n = [
    39.95, 39.91, 40.62, 40.59, 40.61, 41.01, 20.86, 29.97, 21.81, 22.24,
    22.51, 17.78, 18.91, 26.96, 41.26, 49.93, 68.10, 103.47, 175.37,
    327.91, 620.37, 1214.70, 2466.37, 4784.03
]
cray_mpich3_6n = [
    39.31, 39.35, 39.97, 39.94, 39.98, 40.46, 20.56, 29.76, 21.79, 22.18,
    22.57, 17.58, 18.47, 27.05, 42.94, 51.49, 69.12, 104.59, 176.71,
    329.76, 626.76, 1223.15, 2462.54, 4808.47
]
cray_mpich4_6n = [
    40.25, 39.96, 40.62, 40.68, 40.70, 41.05, 20.43, 29.61, 21.68, 21.87,
    22.22, 17.32, 18.31, 26.93, 44.59, 52.78, 70.86, 106.72, 178.71,
    333.54, 623.99, 1226.59, 2466.03, 4806.47
]
cray_mpich5_6n = [
    39.24, 39.10, 39.88, 39.80, 39.89, 40.23, 18.80, 28.10, 20.00, 20.12,
    20.34, 17.11, 17.86, 23.40, 38.19, 45.76, 64.14, 99.22, 170.48,
    318.33, 606.47, 1192.99, 2403.23, 4689.98
]
cray_mpich_averages_6n = []
for i in range(num_sizes):
    avg = (cray_mpich1_6n[i] + cray_mpich2_6n[i] + cray_mpich3_6n[i] + cray_mpich4_6n[i] + cray_mpich5_6n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_6n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_6n = [

]
argonne_mpich2_6n = [

]
argonne_mpich3_6n = [

]
argonne_mpich4_6n = [

]
argonne_mpich5_6n = [

]
argonne_mpich_averages_6n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_6n[i] + argonne_mpich2_6n[i] + argonne_mpich3_6n[i] + argonne_mpich4_6n[i] + argonne_mpich5_6n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_6n.append(avg)

openmpi1_6n = [

]
openmpi2_6n = [

]
openmpi3_6n = [

]
openmpi4_6n = [

]
openmpi5_6n = [

]
openmpi_averages_6n = []
for i in range(num_sizes):
    avg = (openmpi1_6n[i] + openmpi2_6n[i] + openmpi3_6n[i] + openmpi4_6n[i] + openmpi5_6n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_6n.append(avg)

###################################################################
#                       8 NODE RESULTS
###################################################################
cray_mpich1_8n = [
    42.46, 42.44, 43.19, 43.12, 43.20, 43.63, 20.20, 29.18, 21.39, 21.74,
    22.04, 15.29, 16.05, 24.56, 43.42, 54.44, 76.20, 122.48, 210.12, 397.79,
    760.89, 1498.70, 2970.01, 5919.61
]
cray_mpich2_8n = [
    45.91, 45.86, 46.99, 46.71, 46.89, 47.23, 19.47, 28.86, 20.70, 20.96,
    21.34, 15.42, 16.11, 24.72, 43.96, 54.82, 77.10, 121.14, 215.38, 395.54,
    764.10, 1507.83, 2979.31, 5923.95
]
cray_mpich3_8n = [
    43.03, 42.78, 43.52, 43.65, 43.64, 44.21, 20.47, 29.36, 21.65, 21.91,
    22.25, 14.99, 15.88, 24.53, 43.98, 53.77, 75.46, 123.72, 210.26, 395.77,
    758.26, 1494.41, 2963.95, 5880.09
]
cray_mpich4_8n = [
    43.32, 43.27, 44.02, 43.87, 44.00, 44.75, 19.84, 29.01, 20.99, 21.25,
    21.58, 15.41, 16.32, 24.87, 47.26, 57.87, 79.50, 125.51, 216.46, 403.68,
    764.91, 1509.65, 2991.40, 5940.68
]
cray_mpich5_8n = [
    42.75, 42.88, 43.62, 43.55, 43.55, 44.04, 20.05, 29.05, 21.27, 21.58,
    21.99, 15.36, 16.26, 24.27, 45.29, 54.93, 77.53, 122.70, 218.79, 396.02,
    758.44, 1496.89, 2971.01, 5888.61
]
cray_mpich_averages_8n = []
for i in range(num_sizes):
    avg = (cray_mpich1_8n[i] + cray_mpich2_8n[i] + cray_mpich3_8n[i] + cray_mpich4_8n[i] + cray_mpich5_8n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_8n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_8n = [

]
argonne_mpich2_8n = [

]
argonne_mpich3_8n = [

]
argonne_mpich4_8n = [

]
argonne_mpich5_8n = [

]
argonne_mpich_averages_8n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_8n[i] + argonne_mpich2_8n[i] + argonne_mpich3_8n[i] + argonne_mpich4_8n[i] + argonne_mpich5_8n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_8n.append(avg)

openmpi1_8n = [

]
openmpi2_8n = [

]
openmpi3_8n = [

]
openmpi4_8n = [

]
openmpi5_8n = [

]
openmpi_averages_8n = []
for i in range(num_sizes):
    avg = (openmpi1_8n[i] + openmpi2_8n[i] + openmpi3_8n[i] + openmpi4_8n[i] + openmpi5_8n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_8n.append(avg)

###################################################################
#                       10 NODE RESULTS
###################################################################
cray_mpich1_10n = [

]
cray_mpich2_10n = [

]
cray_mpich3_10n = [

]
cray_mpich4_10n = [

]
cray_mpich5_10n = [

]
cray_mpich_averages_10n = []
for i in range(num_sizes):
    avg = (cray_mpich1_10n[i] + cray_mpich2_10n[i] + cray_mpich3_10n[i] + cray_mpich4_10n[i] + cray_mpich5_10n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_10n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_10n = [

]
argonne_mpich2_10n = [

]
argonne_mpich3_10n = [

]
argonne_mpich4_10n = [

]
argonne_mpich5_10n = [

]
argonne_mpich_averages_10n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_10n[i] + argonne_mpich2_10n[i] + argonne_mpich3_10n[i] + argonne_mpich4_10n[i] + argonne_mpich5_10n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_10n.append(avg)

openmpi1_10n = [

]
openmpi2_10n = [

]
openmpi3_10n = [

]
openmpi4_10n = [

]
openmpi5_10n = [

]
openmpi_averages_10n = []
for i in range(num_sizes):
    avg = (openmpi1_10n[i] + openmpi2_10n[i] + openmpi3_10n[i] + openmpi4_10n[i] + openmpi5_10n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_10n.append(avg)

##########################################################################################################################

# Number of nodes used
nun_nodes = [2, 4, 6, 8, 10]

# Averages latencies for 16MB message size, scaling nodes FIXME: change array indeces if we choose to look at a different message size
cray_mpich_results = [ cray_mpich_averages_2n[-6], cray_mpich_averages_4n[-6], cray_mpich_averages_6n[-6], cray_mpich_averages_8n[-6], cray_mpich_averages_10n[-6] ]
argonne_mpich_results = [ argonne_mpich_averages_2n[-6], argonne_mpich_averages_4n[-6], argonne_mpich_averages_6n[-6], argonne_mpich_averages_8n[-6], argonne_mpich_averages_10n[-6] ]
openmpi_results = [ openmpi_averages_2n[-6], openmpi_averages_4n[-6], openmpi1_6n[-6], openmpi1_8n[-6], openmpi1_10n[-6] ]

# Configure plot
sns.set(style="whitegrid")  # Set the plot style
plt.figure(figsize=(10, 6))  # Set the plot size

# Plotting the line plot
plt.plot(nun_nodes, cray_mpich_results, marker='x', linewidth=4)
plt.plot(nun_nodes, argonne_mpich_results, marker='o', linewidth=2)
plt.plot(nun_nodes, openmpi_results, marker="|", linewidth=1)

# Set labels and title
plt.xlabel('Size')
plt.ylabel('Latency (us)')
plt.title('OSU MPI-CUDA Broadcast Latency Test v7.1')

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45)

# Add a legend
plt.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left')

# Adjust the layout to prevent labels from being cut off
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ### osu_alltoall

# %%
sizes = [
    '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
    '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB', '32MB'
]
num_sizes = len(sizes)

###################################################################
#                       2 NODE RESULTS
###################################################################
cray_mpich1_2n = [
    39.34, 39.01, 38.65, 39.64, 40.79, 41.02, 41.84, 43.40, 52.55, 50.80,
    52.54, 55.78, 57.18, 59.98, 62.62, 66.93, 96.86, 229.64, 418.86, 790.84,
    1571.84, 3121.45, 6336.75, 12707.16
]
cray_mpich2_2n = [
    38.90, 38.36, 38.09, 38.56, 40.22, 40.74, 42.37, 44.06, 52.22, 51.47,
    52.18, 54.06, 57.96, 58.15, 64.10, 67.65, 97.26, 228.36, 404.76, 786.30,
    1562.70, 3181.24, 6297.55, 12639.04
]
cray_mpich3_2n = [
    40.08, 40.13, 39.74, 40.78, 45.93, 46.45, 47.36, 48.51, 48.94, 48.23,
    49.19, 50.82, 60.67, 57.79, 61.19, 70.29, 102.27, 247.85, 438.99, 828.74,
    1625.03, 3269.12, 6503.81, 12875.85
]
cray_mpich4_2n = [
    38.46, 38.10, 38.15, 38.55, 39.70, 39.94, 41.37, 42.61, 51.85, 51.11,
    53.72, 53.74, 57.67, 59.97, 65.58, 70.60, 97.65, 228.68, 407.05, 784.18,
    1566.78, 3117.56, 6331.17, 12624.37
]
cray_mpich5_2n = [
    41.64, 41.56, 41.02, 42.08, 47.05, 47.13, 48.29, 50.18, 51.25, 51.37,
    52.90, 53.11, 56.30, 57.54, 63.39, 72.84, 102.58, 251.11, 438.98, 821.09,
    1635.16, 3238.00, 6513.15
]
cray_mpich_averages_2n = []
for i in range(num_sizes):
    avg = (cray_mpich1_2n[i] + cray_mpich2_2n[i] + cray_mpich3_2n[i] + cray_mpich4_2n[i] + cray_mpich5_2n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_2n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_2n = [

]
argonne_mpich2_2n = [

]
argonne_mpich3_2n = [

]
argonne_mpich4_2n = [

]
argonne_mpich5_2n = [

]
argonne_mpich_averages_2n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_2n[i] + argonne_mpich2_2n[i] + argonne_mpich3_2n[i] + argonne_mpich4_2n[i] + argonne_mpich5_2n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_2n.append(avg)

openmpi1_2n = [

]
openmpi2_2n = [

]
openmpi3_2n = [

]
openmpi4_2n = [

]
openmpi5_2n = [

]
openmpi_averages_2n = []
for i in range(num_sizes):
    avg = (openmpi1_2n[i] + openmpi2_2n[i] + openmpi3_2n[i] + openmpi4_2n[i] + openmpi5_2n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_2n.append(avg)

###################################################################
#                       4 NODE RESULTS
###################################################################
cray_mpich1_4n = [
    56.99, 56.02, 56.74, 60.64, 61.09, 63.58, 64.99, 66.93, 73.35, 72.11,
    70.47, 73.47, 79.09, 83.42, 89.47, 134.21, 254.29, 592.94, 1094.89,
    2146.36, 4264.84, 8345.29, 16660.07, 36249.16
]
cray_mpich2_4n = [
    55.64, 54.72, 55.61, 59.42, 59.48, 61.38, 62.53, 64.16, 75.83, 73.63,
    75.35, 77.98, 80.64, 79.43, 88.31, 131.77, 254.57, 592.65, 1093.91,
    2155.58, 4285.72, 8879.69, 17632.24, 43364.10
]
cray_mpich3_4n = [
    55.33, 54.76, 55.85, 59.06, 59.28, 60.93, 62.27, 64.09, 71.67, 70.27,
    72.61, 73.79, 75.71, 81.16, 91.63, 131.17, 255.16, 588.84, 1103.37,
    2207.31, 4350.43, 8634.85, 17257.19, 38560.88
]
cray_mpich4_4n = [
    56.48, 56.55, 57.31, 61.29, 61.89, 63.80, 64.87, 65.67, 72.50, 71.99,
    74.37, 75.18, 76.65, 81.24, 91.00, 133.09, 258.79, 600.38, 1109.39,
    2187.73, 4314.67, 8606.87, 17101.71, 37629.81
]
cray_mpich5_4n = [
    55.96, 56.19, 56.68, 60.76, 61.37, 63.09, 64.04, 66.46, 72.46, 69.34,
    70.94, 72.46, 75.67, 79.94, 88.60, 133.00, 259.14, 604.02, 1105.19,
    2181.80, 4284.83, 8486.72, 16828.86, 35704.89
]
cray_mpich_averages_4n = []
for i in range(num_sizes):
    avg = (cray_mpich1_4n[i] + cray_mpich2_4n[i] + cray_mpich3_4n[i] + cray_mpich4_4n[i] + cray_mpich5_4n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_4n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_4n = [

]
argonne_mpich2_4n = [

]
argonne_mpich3_4n = [

]
argonne_mpich4_4n = [

]
argonne_mpich5_4n = [

]
argonne_mpich_averages_4n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_4n[i] + argonne_mpich2_4n[i] + argonne_mpich3_4n[i] + argonne_mpich4_4n[i] + argonne_mpich5_4n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_4n.append(avg)

openmpi1_4n = [

]
openmpi2_4n = [

]
openmpi3_4n = [

]
openmpi4_4n = [

]
openmpi5_4n = [

]
openmpi_averages_4n = []
for i in range(num_sizes):
    avg = (openmpi1_4n[i] + openmpi2_4n[i] + openmpi3_4n[i] + openmpi4_4n[i] + openmpi5_4n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_4n.append(avg)

###################################################################
#                       6 NODE RESULTS
###################################################################
cray_mpich1_6n = [
    73.07, 72.78, 73.68, 78.85, 79.30, 80.21, 82.57, 85.26, 101.35, 101.32,
    102.88, 105.13, 111.17, 108.54, 130.21, 205.29, 422.06, 956.10, 1810.56,
    0, 0, 0, 0, 0
]
cray_mpich2_6n = [
    71.69, 72.14, 72.84, 77.01, 78.09, 78.95, 81.08, 83.98, 98.34, 97.84,
    99.02, 99.59, 107.13, 104.39, 128.64, 201.19, 418.59, 943.46, 1773.71,
    0, 0, 0, 0, 0
]
cray_mpich3_6n = [
    71.39, 71.63, 72.10, 76.80, 77.21, 78.34, 80.23, 84.47, 103.70, 104.44,
    106.29, 108.37, 114.47, 112.99, 134.54, 206.24, 421.48, 947.10, 1806.27,
    0, 0, 0, 0, 0
]
cray_mpich4_6n = [
    72.14, 71.39, 72.43, 77.44, 77.72, 79.01, 81.19, 83.96, 105.13, 105.03,
    106.24, 108.47, 113.15, 111.96, 130.64, 205.96, 422.83, 952.36, 1805.75,
    0, 0, 0, 0, 0
]
cray_mpich5_6n = [
    71.48, 71.56, 72.16, 76.99, 77.63, 78.70, 80.40, 83.74, 94.62, 92.94,
    94.30, 98.51, 100.36, 107.32, 128.19, 200.45, 415.99, 943.33, 1772.27,
    0, 0, 0, 0, 0
]
cray_mpich_averages_6n = []
for i in range(num_sizes):
    avg = (cray_mpich1_6n[i] + cray_mpich2_6n[i] + cray_mpich3_6n[i] + cray_mpich4_6n[i] + cray_mpich5_6n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_6n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_6n = [

]
argonne_mpich2_6n = [

]
argonne_mpich3_6n = [

]
argonne_mpich4_6n = [

]
argonne_mpich5_6n = [

]
argonne_mpich_averages_6n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_6n[i] + argonne_mpich2_6n[i] + argonne_mpich3_6n[i] + argonne_mpich4_6n[i] + argonne_mpich5_6n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_6n.append(avg)

openmpi1_6n = [

]
openmpi2_6n = [

]
openmpi3_6n = [

]
openmpi4_6n = [

]
openmpi5_6n = [

]
openmpi_averages_6n = []
for i in range(num_sizes):
    avg = (openmpi1_6n[i] + openmpi2_6n[i] + openmpi3_6n[i] + openmpi4_6n[i] + openmpi5_6n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_6n.append(avg)

###################################################################
#                       8 NODE RESULTS
###################################################################
cray_mpich1_8n = [
    88.54, 89.63, 91.81, 92.29, 93.58, 94.90, 96.87, 102.47, 123.98, 123.47,
    125.76, 127.89, 134.61, 132.14, 161.63, 274.48, 580.43, 1283.35, 2469.36,
    0, 0, 0, 0, 0
]
cray_mpich2_8n = [
    89.64, 90.44, 92.85, 93.05, 94.42, 95.92, 98.07, 103.40, 122.69, 121.58,
    122.27, 126.40, 132.87, 135.03, 164.35, 280.90, 584.89, 1301.32, 2498.47,
    0, 0, 0, 0, 0
]
cray_mpich3_8n = [
    89.05, 90.32, 93.60, 93.94, 94.79, 96.77, 98.11, 103.84, 124.58, 124.65,
    124.92, 127.84, 135.67, 133.66, 163.70, 280.95, 580.14, 1284.86, 2451.12,
    0, 0, 0, 0, 0
]
cray_mpich4_8n = [
    90.08, 90.83, 92.95, 93.01, 94.40, 96.14, 98.59, 102.82, 119.10, 119.35,
    119.93, 122.93, 130.40, 129.92, 163.94, 282.58, 588.87, 1301.29, 2470.43,
    0, 0, 0, 0, 0
]
cray_mpich5_8n = [
    90.27, 90.51, 93.36, 93.59, 95.10, 97.60, 98.36, 103.65, 118.84, 117.33,
    117.99, 121.28, 128.35, 128.63, 164.60, 272.52, 583.43, 1316.12, 2456.47,
    0, 0, 0, 0, 0
]
cray_mpich_averages_8n = []
for i in range(num_sizes):
    avg = (cray_mpich1_8n[i] + cray_mpich2_8n[i] + cray_mpich3_8n[i] + cray_mpich4_8n[i] + cray_mpich5_8n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_8n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_8n = [

]
argonne_mpich2_8n = [

]
argonne_mpich3_8n = [

]
argonne_mpich4_8n = [

]
argonne_mpich5_8n = [

]
argonne_mpich_averages_8n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_8n[i] + argonne_mpich2_8n[i] + argonne_mpich3_8n[i] + argonne_mpich4_8n[i] + argonne_mpich5_8n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_8n.append(avg)

openmpi1_8n = [

]
openmpi2_8n = [

]
openmpi3_8n = [

]
openmpi4_8n = [

]
openmpi5_8n = [

]
openmpi_averages_8n = []
for i in range(num_sizes):
    avg = (openmpi1_8n[i] + openmpi2_8n[i] + openmpi3_8n[i] + openmpi4_8n[i] + openmpi5_8n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_8n.append(avg)

###################################################################
#                       10 NODE RESULTS
###################################################################
cray_mpich1_10n = [

]
cray_mpich2_10n = [

]
cray_mpich3_10n = [

]
cray_mpich4_10n = [

]
cray_mpich5_10n = [

]
cray_mpich_averages_10n = []
for i in range(num_sizes):
    avg = (cray_mpich1_10n[i] + cray_mpich2_10n[i] + cray_mpich3_10n[i] + cray_mpich4_10n[i] + cray_mpich5_10n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_10n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_10n = [

]
argonne_mpich2_10n = [

]
argonne_mpich3_10n = [

]
argonne_mpich4_10n = [

]
argonne_mpich5_10n = [

]
argonne_mpich_averages_10n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_10n[i] + argonne_mpich2_10n[i] + argonne_mpich3_10n[i] + argonne_mpich4_10n[i] + argonne_mpich5_10n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_10n.append(avg)

openmpi1_10n = [

]
openmpi2_10n = [

]
openmpi3_10n = [

]
openmpi4_10n = [

]
openmpi5_10n = [

]
openmpi_averages_10n = []
for i in range(num_sizes):
    avg = (openmpi1_10n[i] + openmpi2_10n[i] + openmpi3_10n[i] + openmpi4_10n[i] + openmpi5_10n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_10n.append(avg)

##########################################################################################################################

# Number of nodes used
nun_nodes = [2, 4, 6, 8, 10]

# Averages latencies for 16MB message size, scaling nodes FIXME: change array indeces if we choose to look at a different message size
cray_mpich_results = [ cray_mpich_averages_2n[-6], cray_mpich_averages_4n[-6], cray_mpich_averages_6n[-6], cray_mpich_averages_8n[-6], cray_mpich_averages_10n[-6] ]
argonne_mpich_results = [ argonne_mpich_averages_2n[-6], argonne_mpich_averages_4n[-6], argonne_mpich_averages_6n[-6], argonne_mpich_averages_8n[-6], argonne_mpich_averages_10n[-6] ]
openmpi_results = [ openmpi_averages_2n[-6], openmpi_averages_4n[-6], openmpi1_6n[-6], openmpi1_8n[-6], openmpi1_10n[-6] ]

# Configure plot
sns.set(style="whitegrid")  # Set the plot style
plt.figure(figsize=(10, 6))  # Set the plot size

# Plotting the line plot
plt.plot(nun_nodes, cray_mpich_results, marker='x', linewidth=4)
plt.plot(nun_nodes, argonne_mpich_results, marker='o', linewidth=2)
plt.plot(nun_nodes, openmpi_results, marker="|", linewidth=1)

# Set labels and title
plt.xlabel('Size')
plt.ylabel('Latency (us)')
plt.title('OSU MPI-CUDA All-to-All Personalized Exchange Latency Test v7.1')

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45)

# Add a legend
plt.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left')

# Adjust the layout to prevent labels from being cut off
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ## TEMPLATE:

# %%
sizes = [
    '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
    '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB', '32MB'
]
num_sizes = len(sizes)

###################################################################
#                       2 NODE RESULTS
###################################################################
cray_mpich1_2n = [

]
cray_mpich2_2n = [

]
cray_mpich3_2n = [

]
cray_mpich4_2n = [

]
cray_mpich5_2n = [

]
cray_mpich_averages_2n = []
for i in range(num_sizes):
    avg = (cray_mpich1_2n[i] + cray_mpich2_2n[i] + cray_mpich3_2n[i] + cray_mpich4_2n[i] + cray_mpich5_2n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_2n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_2n = [

]
argonne_mpich2_2n = [

]
argonne_mpich3_2n = [

]
argonne_mpich4_2n = [

]
argonne_mpich5_2n = [

]
argonne_mpich_averages_2n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_2n[i] + argonne_mpich2_2n[i] + argonne_mpich3_2n[i] + argonne_mpich4_2n[i] + argonne_mpich5_2n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_2n.append(avg)

openmpi1_2n = [

]
openmpi2_2n = [

]
openmpi3_2n = [

]
openmpi4_2n = [

]
openmpi5_2n = [

]
openmpi_averages_2n = []
for i in range(num_sizes):
    avg = (openmpi1_2n[i] + openmpi2_2n[i] + openmpi3_2n[i] + openmpi4_2n[i] + openmpi5_2n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_2n.append(avg)

###################################################################
#                       4 NODE RESULTS
###################################################################
cray_mpich1_4n = [

]
cray_mpich2_4n = [

]
cray_mpich3_4n = [

]
cray_mpich4_4n = [

]
cray_mpich5_4n = [

]
cray_mpich_averages_4n = []
for i in range(num_sizes):
    avg = (cray_mpich1_4n[i] + cray_mpich2_4n[i] + cray_mpich3_4n[i] + cray_mpich4_4n[i] + cray_mpich5_4n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_4n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_4n = [

]
argonne_mpich2_4n = [

]
argonne_mpich3_4n = [

]
argonne_mpich4_4n = [

]
argonne_mpich5_4n = [

]
argonne_mpich_averages_4n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_4n[i] + argonne_mpich2_4n[i] + argonne_mpich3_4n[i] + argonne_mpich4_4n[i] + argonne_mpich5_4n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_4n.append(avg)

openmpi1_4n = [

]
openmpi2_4n = [

]
openmpi3_4n = [

]
openmpi4_4n = [

]
openmpi5_4n = [

]
openmpi_averages_4n = []
for i in range(num_sizes):
    avg = (openmpi1_4n[i] + openmpi2_4n[i] + openmpi3_4n[i] + openmpi4_4n[i] + openmpi5_4n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_4n.append(avg)

###################################################################
#                       6 NODE RESULTS
###################################################################
cray_mpich1_6n = [

]
cray_mpich2_6n = [

]
cray_mpich3_6n = [

]
cray_mpich4_6n = [

]
cray_mpich5_6n = [

]
cray_mpich_averages_6n = []
for i in range(num_sizes):
    avg = (cray_mpich1_6n[i] + cray_mpich2_6n[i] + cray_mpich3_6n[i] + cray_mpich4_6n[i] + cray_mpich5_6n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_6n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_6n = [

]
argonne_mpich2_6n = [

]
argonne_mpich3_6n = [

]
argonne_mpich4_6n = [

]
argonne_mpich5_6n = [

]
argonne_mpich_averages_6n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_6n[i] + argonne_mpich2_6n[i] + argonne_mpich3_6n[i] + argonne_mpich4_6n[i] + argonne_mpich5_6n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_6n.append(avg)

openmpi1_6n = [

]
openmpi2_6n = [

]
openmpi3_6n = [

]
openmpi4_6n = [

]
openmpi5_6n = [

]
openmpi_averages_6n = []
for i in range(num_sizes):
    avg = (openmpi1_6n[i] + openmpi2_6n[i] + openmpi3_6n[i] + openmpi4_6n[i] + openmpi5_6n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_6n.append(avg)

###################################################################
#                       8 NODE RESULTS
###################################################################
cray_mpich1_8n = [

]
cray_mpich2_8n = [

]
cray_mpich3_8n = [

]
cray_mpich4_8n = [

]
cray_mpich5_8n = [

]
cray_mpich_averages_8n = []
for i in range(num_sizes):
    avg = (cray_mpich1_8n[i] + cray_mpich2_8n[i] + cray_mpich3_8n[i] + cray_mpich4_8n[i] + cray_mpich5_8n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_8n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_8n = [

]
argonne_mpich2_8n = [

]
argonne_mpich3_8n = [

]
argonne_mpich4_8n = [

]
argonne_mpich5_8n = [

]
argonne_mpich_averages_8n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_8n[i] + argonne_mpich2_8n[i] + argonne_mpich3_8n[i] + argonne_mpich4_8n[i] + argonne_mpich5_8n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_8n.append(avg)

openmpi1_8n = [

]
openmpi2_8n = [

]
openmpi3_8n = [

]
openmpi4_8n = [

]
openmpi5_8n = [

]
openmpi_averages_8n = []
for i in range(num_sizes):
    avg = (openmpi1_8n[i] + openmpi2_8n[i] + openmpi3_8n[i] + openmpi4_8n[i] + openmpi5_8n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_8n.append(avg)

###################################################################
#                       10 NODE RESULTS
###################################################################
cray_mpich1_10n = [

]
cray_mpich2_10n = [

]
cray_mpich3_10n = [

]
cray_mpich4_10n = [

]
cray_mpich5_10n = [

]
cray_mpich_averages_10n = []
for i in range(num_sizes):
    avg = (cray_mpich1_10n[i] + cray_mpich2_10n[i] + cray_mpich3_10n[i] + cray_mpich4_10n[i] + cray_mpich5_10n[i]) / 5
    avg = round(avg, 2)
    cray_mpich_averages_10n.append(avg)

# NOTE: ARGONE MPICH COULD ONLY RUN 16MB BECAUSE THEY RAN OUT OF MEMORY
argonne_mpich1_10n = [

]
argonne_mpich2_10n = [

]
argonne_mpich3_10n = [

]
argonne_mpich4_10n = [

]
argonne_mpich5_10n = [

]
argonne_mpich_averages_10n = []
for i in range(num_sizes):
    avg = (argonne_mpich1_10n[i] + argonne_mpich2_10n[i] + argonne_mpich3_10n[i] + argonne_mpich4_10n[i] + argonne_mpich5_10n[i]) / 5
    avg = round(avg, 2)
    argonne_mpich_averages_10n.append(avg)

openmpi1_10n = [

]
openmpi2_10n = [

]
openmpi3_10n = [

]
openmpi4_10n = [

]
openmpi5_10n = [

]
openmpi_averages_10n = []
for i in range(num_sizes):
    avg = (openmpi1_10n[i] + openmpi2_10n[i] + openmpi3_10n[i] + openmpi4_10n[i] + openmpi5_10n[i]) / 5
    avg = round(avg, 2)
    openmpi_averages_10n.append(avg)

##########################################################################################################################

# Number of nodes used
nun_nodes = [2, 4, 6, 8, 10]

# Averages latencies for 16MB message size, scaling nodes FIXME: change array indeces if we choose to look at a different message size
cray_mpich_results = [ cray_mpich_averages_2n[-6], cray_mpich_averages_4n[-6], cray_mpich_averages_6n[-6], cray_mpich_averages_8n[-6], cray_mpich_averages_10n[-6] ]
argonne_mpich_results = [ argonne_mpich_averages_2n[-6], argonne_mpich_averages_4n[-6], argonne_mpich_averages_6n[-6], argonne_mpich_averages_8n[-6], argonne_mpich_averages_10n[-6] ]
openmpi_results = [ openmpi_averages_2n[-6], openmpi_averages_4n[-6], openmpi1_6n[-6], openmpi1_8n[-6], openmpi1_10n[-6] ]

# Configure plot
sns.set(style="whitegrid")  # Set the plot style
plt.figure(figsize=(10, 6))  # Set the plot size

# Plotting the line plot
plt.plot(nun_nodes, cray_mpich_results, marker='x', linewidth=4)
plt.plot(nun_nodes, argonne_mpich_results, marker='o', linewidth=2)
plt.plot(nun_nodes, openmpi_results, marker="|", linewidth=1)

# Set labels and title
plt.xlabel('Size')
plt.ylabel('Latency (us)')
plt.title('OSU MPI-CUDA Gather Latency Test v7.1')

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45)

# Add a legend
plt.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left')

# Adjust the layout to prevent labels from being cut off
plt.tight_layout()

# Display the plot
plt.show()
