# %% [markdown]
# # OSU Block Collective Microbenchmarks (Device to Device)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ------------------------------

# %% [markdown]
# ## GNU

# %% [markdown]
# ### osu_gather

# %%
##################################
# 2 nodes
##################################
cray_mpich1_2n = [
    13.38, 13.51, 13.37, 13.77, 14.13, 14.26, 14.30, 16.02, 17.43, 17.69,
    18.82, 21.46, 24.09, 30.19, 41.73, 64.64, 109.87, 199.93, 365.81,
    665.28, 1263.89, 3141.49, 13318.15 #, 38798.90
]
argonne_mpich1_2n = [
    15.75, 15.73, 15.78, 15.85, 16.36, 16.47, 16.43, 16.47, 17.31, 18.37,
    18.86, 25.83, 43.87, 43.66, 71.35, 115.56, 215.29, 388.37, 596.26, 1196.24,
    2396.99, 5613.51, 14658.02 #, 0
]
openmpi1_2n = [
    13.71, 13.65, 13.88, 13.86, 14.58, 16.10, 12.15, 12.58, 9.63, 10.87, 11.42, 23.39,
    26.29, 32.60, 41.87, 61.80, 84.76, 136.24, 237.59, 440.79, 843.22, 3100.02, 6559.36
]

##################################
# 4 nodes
##################################
cray_mpich1_4n = [
    12.88, 12.88, 12.83, 13.65, 14.16, 14.33, 14.47, 15.43, 16.47, 16.82,
    19.37, 21.87, 24.81, 31.19, 43.77, 68.50, 118.21, 217.02, 407.58, 761.67,
    1882.81, 4304.93, 15313.57 #, 43271.52
]
argonne_mpich1_4n = [
    15.71, 15.66, 15.64, 15.85, 16.34, 16.42, 16.50, 16.51,
    19.70, 20.78, 21.98, 29.44, 50.79, 47.23, 96.39, 172.09,
    314.94, 465.97, 657.57, 1268.03, 2924.46, 7826.73, 19641.06 #, 0
]
openmpi1_4n = [
    13.47, 13.43, 13.76, 14.01, 14.58, 16.20, 12.56, 12.78, 10.09, 11.54, 11.92, 26.15,
    29.26, 37.40, 45.85, 66.26, 94.17, 154.68, 274.40, 512.30, 988.78, 3720.40, 7437.22
]
    
##################################
# 8 nodes
##################################
cray_mpich1_8n = [
    12.98, 12.90, 12.90, 13.78, 14.40, 14.48, 14.65, 15.31, 16.17, 17.34,
    19.33, 22.05, 25.59, 32.78, 46.58, 74.85, 129.81, 240.91, 453.24,
    1103.68, 2407.65, 5243.80, 17088.56 #, 47497.69
]
argonne_mpich1_8n = [
    184.65, 185.16, 186.42, 190.94, 192.31, 191.82, 192.76, 367.34,
    475.61, 527.51, 527.67, 544.51, 575.98, 571.71, 705.35, 1213.76,
    1898.35, 2053.15, 2274.18, 2860.57, 4612.78, 10537.40, 24069.26 #, 0
]
openmpi1_8n = [
    13.26, 13.23, 13.69, 14.06, 14.75, 16.38, 12.50, 13.26, 11.19, 12.21, 12.92, 25.51,
    31.59, 44.50, 64.84, 105.09, 173.35, 192.45, 749.05, 1717.97, 3637.13, 9314.25, 18685.30
]
    
##################################
# 16 nodes
##################################
cray_mpich1_16n = [
    12.48, 12.65, 12.68, 13.50, 13.99, 14.10, 14.25, 14.77, 16.05, 16.87,
    18.87, 21.93, 25.51, 33.22, 47.89, 77.75, 137.68, 257.24, 634.54,
    1397.51, 2949.17, 6277.91, 19212.84 #, 51606.87
]
argonne_mpich1_16n = [
    235.90, 238.07, 244.19, 241.59, 237.48, 241.57, 469.14, 631.04,
    741.22, 810.64, 811.74, 801.23, 819.99, 926.35, 1525.82, 2259.14,
    3233.22, 3404.72, 3679.86, 4233.94, 6152.53, 12941.89, 28552.10 #, 0
]
openmpi1_16n = [
    132.81, 127.81, 128.60, 130.53, 135.06, 136.93, 257.27, 338.12, 389.36, 426.34, 476.18,
    465.89, 467.56, 490.88, 523.00, 550.02, 611.92, 982.98, 1714.65, 3539.51, 7044.12,
    16045.08, 32135.26
]
    
##################################
# 32 nodes
##################################
cray_mpich1_32n = [
    12.47, 12.65, 12.56, 13.38, 13.89, 14.00, 14.17, 15.03, 15.98, 16.85,
    18.96, 22.03, 26.18, 34.44, 50.59, 82.91, 146.90, 353.05, 778.20,
    1670.41, 3514.22, 7426.73, 21469.74 #, 55827.81
]
argonne_mpich1_32n =  [
    287.81, 288.88, 292.16, 292.63, 291.23, 562.80, 776.28, 945.37,
    1069.96, 1124.36, 1118.83, 1126.59, 1171.23, 1736.67, 2517.23,
    3303.85, 4458.06, 4709.07, 4848.24, 6129.24, 8247.47, 15489.43, 32858.05 #, 0
]
openmpi1_32n = [
    152.06, 157.11, 153.50, 157.32, 156.73, 297.92, 412.66, 485.65, 558.17, 574.94, 581.62,
    603.90, 600.31, 623.94, 642.63, 693.37, 1095.84, 1878.14, 3561.16, 6801.15, 13449.19,
    28902.76, 57911.09
]
    
##########################################################################################################################

# Number of nodes used
num_nodes = [2, 4, 8, 16]

# Message sizes
sizes = [
    '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
    '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB'
]

# Averages latencies for 16MB message size, scaling nodes
cray_mpich_results = [ cray_mpich1_2n[22], cray_mpich1_4n[22], cray_mpich1_8n[22], cray_mpich1_16n[22] ]
argonne_mpich_results = [ argonne_mpich1_2n[22], argonne_mpich1_4n[22], argonne_mpich1_8n[22], argonne_mpich1_16n[22] ]
openmpi_results = [ openmpi1_2n[22], openmpi1_4n[22], openmpi1_8n[22], openmpi1_16n[22] ]

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("husl", 3)

# Set the plot size
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=300)         # controls default text sizes
# plt.rc('axes', titlesize=14)    # fontsize of the axes title
# plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
# plt.rc('xtick', labelsize=15)   # fontsize of the tick labels
# plt.rc('ytick', labelsize=15)   # fontsize of the tick labels
# plt.rc('legend', fontsize=12)   # legend fontsize

# Plotting the line plot with larger linewidth and markersize
ax.plot(num_nodes, cray_mpich_results, marker='x', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(num_nodes, argonne_mpich_results, marker='o', markersize=10, linewidth=2.5, color=color_palette[0])
ax.plot(num_nodes, openmpi_results, marker="|", markersize=10, linewidth=2.5, color=color_palette[2])

# Set labels and title
ax.set_xlabel('Nodes')
ax.set_ylabel('Average Latency (us)')
ax.set_title('OSU MPI-CUDA Gather Latency Test v7.1 (16 MB Message Size)')

# Set y ticks
# ax.set_yticks(range(0, 35001, 5000))
ax.set_yticks(range(0, 35001, 5000))

# Rotate x-axis labels for better visibility
plt.xticks(num_nodes, num_nodes)

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Display the plot
plt.show()

# %%
cray_mpich1_16n = [
    12.48, 12.65, 12.68, 13.50, 13.99, 14.10, 14.25, 14.77, 16.05, 16.87,
    18.87, 21.93, 25.51, 33.22, 47.89, 77.75, 137.68, 257.24, 634.54,
    1397.51, 2949.17, 6277.91, 19212.84 #, 51606.87
]
argonne_mpich1_16n = [
    235.90, 238.07, 244.19, 241.59, 237.48, 241.57, 469.14, 631.04,
    741.22, 810.64, 811.74, 801.23, 819.99, 926.35, 1525.82, 2259.14,
    3233.22, 3404.72, 3679.86, 4233.94, 6152.53, 12941.89, 28552.10 #, 0
]
openmpi1_16n = [
    132.81, 127.81, 128.60, 130.53, 135.06, 136.93, 257.27, 338.12, 389.36, 426.34, 476.18,
    465.89, 467.56, 490.88, 523.00, 550.02, 611.92, 982.98, 1714.65, 3539.51, 7044.12,
    16045.08, 32135.26
]

sizes = [
    '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
    '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB'
]

# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("husl", 3)

# Set the plot size
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes
# plt.rc('axes', titlesize=14)    # fontsize of the axes title
# plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
# plt.rc('xtick', labelsize=15)   # fontsize of the tick labels
# plt.rc('ytick', labelsize=15)   # fontsize of the tick labels
# plt.rc('legend', fontsize=12)   # legend fontsize

# Plotting the line plot with larger linewidth and markersize
ax.plot(sizes, cray_mpich1_16n, marker='x', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(sizes, argonne_mpich1_16n, marker='o', markersize=10, linewidth=2.5, color=color_palette[0])
ax.plot(sizes, openmpi1_16n, marker="|", markersize=10, linewidth=2.5, color=color_palette[2])

# Set labels and title
ax.set_xlabel('Message Size')
ax.set_ylabel('Average Latency (us)')
ax.set_title('OSU MPI-CUDA Gather Latency Test v7.1 (16 Nodes)')

# Rotate x-axis labels for better visibility
plt.xticks(sizes, sizes, rotation=45)

# Set y ticks
ax.set_yticks(range(0, 35001, 5000))
# ax.set_yticks(range(0, 35001, 5000))

#-------------------------------------------------------
# Set y-axis to logarithmic scale and adjust the ticks
# ax.set_yscale("log", base=10)
# ax.get_yaxis().set_major_formatter(plt.ScalarFormatter())
# y_min_power = np.floor(np.log10(np.min([cray_mpich1_16n, argonne_mpich1_16n, openmpi1_16n])))
# y_max_power = np.ceil(np.log10(np.max([cray_mpich1_16n, argonne_mpich1_16n, openmpi1_16n])))
# ax.set_yticks([10**i for i in np.arange(y_min_power, y_max_power + 0.5, 0.5)])
#-------------------------------------------------------

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ### osu_allgather

# %%
##################################
# 2 nodes
##################################
cray_mpich1_2n = [
    49.29, 49.36, 49.19, 49.96, 43.35, 43.08, 43.53, 41.68, 36.82, 39.16,
    38.40, 42.33, 42.29, 48.26, 56.19, 71.98, 107.34, 172.90, 313.42,
    584.66, 1129.26, 2420.46, 4781.40 #, 9522.64
]
argonne_mpich1_2n = [
    57.80, 57.66, 57.57, 58.11, 49.85, 49.88, 50.13, 50.29, 50.79, 54.72,
    56.48, 77.68, 73.11, 53.93, 99.43, 165.77, 216.78, 309.64, 890.23,
    1224.04, 1951.20, 3387.68, 6307.73 #, 13932.99
]
openmpi1_2n = [
    45.41, 45.51, 46.39, 31.40, 34.11, 34.70, 34.28, 34.70, 35.98, 42.58, 46.02, 61.84,
    78.86, 116.00, 182.29, 288.99, 537.94, 961.47, 1846.33, 3590.00, 7094.70, 16975.04, 35000.44
]

##################################
# 4 nodes
##################################
cray_mpich1_4n = [
    64.17, 63.99, 64.36, 59.97, 53.60, 53.52, 54.00, 52.16, 48.03, 49.60,
    57.11, 66.07, 70.16, 81.61, 101.67, 149.48, 241.71, 432.91, 815.46,
    1564.11, 2813.11, 5482.97, 10698.39 #, 21240.51
]
argonne_mpich1_4n = [
    68.50, 68.31, 68.87, 63.74, 55.54, 55.45, 55.71, 55.93, 59.26, 63.87,
    66.19, 88.54, 90.55, 212.79, 228.57, 370.28, 481.46, 685.30, 2000.66, 2768.56,
    4571.38, 7951.88, 14791.11 #, 30402.18
]
openmpi1_4n = [
    69.74, 70.62, 56.85, 50.69, 43.24, 44.23, 43.77, 47.61, 52.34, 61.48, 69.24, 90.96,
    118.55, 179.54, 268.69, 462.15, 853.35, 1596.91, 3071.40, 6035.83, 13325.04, 28636.65, 58540.91
]
    
##################################
# 8 nodes
##################################
cray_mpich1_8n = [
    77.33, 77.81, 73.27, 68.54, 62.44, 62.59, 63.25, 61.96, 59.04, 67.44,
    77.27, 89.43, 99.96, 125.94, 176.56, 285.29, 508.84, 952.79, 1874.91,
    3249.46, 5956.28, 11489.19, 22487.66 #, 44558.11
]
argonne_mpich1_8n =  [
    11763.98, 11911.08, 11759.78, 11895.00, 11809.15, 11819.39, 11790.39,
    12008.82, 11930.39, 11803.14, 11931.35, 11900.32, 81563.10, 81850.19,
    80971.28, 79953.61, 79603.16, 82135.04, 352812.00, 351372.95, 351750.81,
    354979.25, 363131.61 #, 375263.51
]
openmpi1_8n = [
    84.85, 71.21, 65.14, 59.35, 52.00, 52.96, 54.16, 63.84, 69.50, 82.99,
    97.26, 131.32, 186.36, 272.49, 452.92, 812.57, 1560.35, 2978.18,
    5837.94, 12801.94, 26129.03, 53899.84, 109100.78
]
    
##################################
# 16 nodes
##################################
cray_mpich1_16n = [
    38.51, 40.59, 42.47, 45.10, 47.21, 47.05, 49.97, 51.82, 61.32, 73.51,
    92.03, 123.06, 177.61, 1157.70, 1271.70, 1465.66, 1827.44, 2510.34,
    3886.40, 6653.76, 12131.51, 23438.53, 45920.12 #, 90874.56
]
argonne_mpich1_16n =  [
    16437.77, 16430.56, 16320.10, 16322.26, 16477.25, 16271.89, 16417.03, 16283.60,
    16461.70, 16411.75, 16517.31, 164238.32, 169446.88, 167939.88, 169175.39,
    166612.84, 167236.07, 168639.59, 714504.41, 721855.57, 721487.09, 723574.84,
    737900.89 #, 0
]
openmpi1_16n = [
    14941.18, 14736.85, 14896.78, 14926.50, 14817.99, 13953.29, 14964.42, 15201.41, 15432.03,
    15256.30, 15591.84, 15088.85, 17088.41, 17829.26, 17805.83, 18334.59, 22115.46, 24987.92,
    32506.08, 45181.69, 72185.52, 126300.15, 235759.66
]
    
##################################
# 32 nodes
##################################
cray_mpich1_32n = [
    46.33, 48.09, 50.36, 53.16, 55.33, 55.86, 58.98, 68.61, 80.67, 99.07,
    130.44, 189.68, 1436.96, 2332.14, 2575.64, 2959.71, 3705.22, 5101.88,
    7886.41, 13484.41, 24591.46, 47652.88, 93256.31 #, 184483.64
]
argonne_mpich1_32n = [
    
]
openmpi1_32n = [
    
]
    
##########################################################################################################################

# Number of nodes used
num_nodes = [2, 4, 8, 16]

# Message sizes
sizes = [
    '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
    '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB'
]

# Averages latencies for 16MB message size, scaling nodes
cray_mpich_results = [ cray_mpich1_2n[22], cray_mpich1_4n[22], cray_mpich1_8n[22], cray_mpich1_16n[22] ]
argonne_mpich_results = [ argonne_mpich1_2n[22], argonne_mpich1_4n[22], argonne_mpich1_8n[22], argonne_mpich1_16n[22] ]
openmpi_results = [ openmpi1_2n[22], openmpi1_4n[22], openmpi1_8n[22], openmpi1_16n[22] ]

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("husl", 3)

# Set the plot size
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes
# plt.rc('axes', titlesize=14)    # fontsize of the axes title
# plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
# plt.rc('xtick', labelsize=15)   # fontsize of the tick labels
# plt.rc('ytick', labelsize=15)   # fontsize of the tick labels
# plt.rc('legend', fontsize=12)   # legend fontsize

# Plotting the line plot with larger linewidth and markersize
ax.plot(num_nodes, cray_mpich_results, marker='x', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(num_nodes, argonne_mpich_results, marker='o', markersize=10, linewidth=2.5, color=color_palette[0])
ax.plot(num_nodes, openmpi_results, marker="|", markersize=10, linewidth=2.5, color=color_palette[2])

# Set labels and title
ax.set_xlabel('Nodes')
ax.set_ylabel('Average Latency (us)')
ax.set_title('OSU MPI-CUDA AllGather Latency Test v7.1 (16 MB Message Size)')

# Rotate x-axis labels for better visibility
plt.xticks(num_nodes, num_nodes)

# Set y ticks
ax.set_yticks(range(0, 800001, 100000))

#------------------------------------------------------------
# Set y-ticks

#------------------------------------------------------------

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Display the plot
plt.show()

# %%
cray_mpich1_16n = [
    38.51, 40.59, 42.47, 45.10, 47.21, 47.05, 49.97, 51.82, 61.32, 73.51,
    92.03, 123.06, 177.61, 1157.70, 1271.70, 1465.66, 1827.44, 2510.34,
    3886.40, 6653.76, 12131.51, 23438.53, 45920.12 #, 90874.56
]
argonne_mpich1_16n =  [
    16437.77, 16430.56, 16320.10, 16322.26, 16477.25, 16271.89, 16417.03, 16283.60,
    16461.70, 16411.75, 16517.31, 164238.32, 169446.88, 167939.88, 169175.39,
    166612.84, 167236.07, 168639.59, 714504.41, 721855.57, 721487.09, 723574.84,
    737900.89 #, 0
]
openmpi1_16n = [
    14941.18, 14736.85, 14896.78, 14926.50, 14817.99, 13953.29, 14964.42, 15201.41, 15432.03,
    15256.30, 15591.84, 15088.85, 17088.41, 17829.26, 17805.83, 18334.59, 22115.46, 24987.92,
    32506.08, 45181.69, 72185.52, 126300.15, 235759.66
]

sizes = [
    '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
    '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB'
]

# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("husl", 3)

# Set the plot size
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes
# plt.rc('axes', titlesize=14)    # fontsize of the axes title
# plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
# plt.rc('xtick', labelsize=15)   # fontsize of the tick labels
# plt.rc('ytick', labelsize=15)   # fontsize of the tick labels
# plt.rc('legend', fontsize=12)   # legend fontsize

# Plotting the line plot with larger linewidth and markersize
ax.plot(sizes, cray_mpich1_16n, marker='x', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(sizes, argonne_mpich1_16n, marker='o', markersize=10, linewidth=2.5, color=color_palette[0])
ax.plot(sizes, openmpi1_16n, marker="|", markersize=10, linewidth=2.5, color=color_palette[2])

# Set labels and title
ax.set_xlabel('Message Size')
ax.set_ylabel('Average Latency (us)')
ax.set_title('OSU MPI-CUDA AllGather Latency Test v7.1 (16 Nodes)')

# Rotate x-axis labels for better visibility
plt.xticks(sizes, sizes, rotation=45)

# Set y ticks
# ax.set_yticks(range(0, 750001, 50000))
ax.set_yticks(range(0, 800001, 100000))

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ### osu_reduce

# %%
##################################
# 2 nodes
##################################
cray_mpich1_2n = [
    14.78, 14.70, 14.94, 15.11, 15.13, 15.39, 15.88, 16.04, 22.88, 23.99,
    195.99, 236.89, 239.01, 268.52, 277.93, 299.53, 373.46, 541.02, 858.53,
    5454.92, 9222.04, 17568.52, 34934.22 #, 64017.46
]
argonne_mpich1_2n = [
    18.37, 18.33, 18.42, 18.42, 18.41, 18.48, 18.86, 19.01, 19.34, 19.65,
    26.86, 28.12, 52.75, 96.50, 235.19, 534.62, 1159.08, 2377.33, 4822.79,
    9771.57, 19583.16, 39324.81, 79033.49 #, 162804.18
]
openmpi1_2n = [
    12.46, 12.36, 12.62, 12.61, 12.65, 13.42, 16.29, 16.51, 16.71, 17.25, 20.43, 28.44,
    31.70, 38.50, 59.18, 113.13, 306.09, 740.50, 1615.37, 4271.07, 7917.35, 15359.23, 30843.17
]

##################################
# 4 nodes
##################################
cray_mpich1_4n = [
    13.53, 13.51, 13.76, 13.76, 13.75, 14.07, 15.01, 15.28, 19.96, 21.04,
    112.27, 136.85, 138.37, 145.06, 164.28, 197.20, 241.61, 377.57, 656.08,
    4422.10, 7437.16, 14493.11, 28422.10 #, 52672.29
]
argonne_mpich1_4n = [
    16.15, 16.09, 16.12, 16.15, 16.19, 16.34, 16.91, 17.04, 17.29, 17.76,
    29.59, 30.88, 56.38, 101.91, 215.45, 462.50, 974.52, 1988.66, 4006.82, 8136.76,
    16392.73, 32681.25, 65440.18 #, 137580.96
]
openmpi1_4n = [
    12.32, 12.29, 14.80, 14.79, 14.77, 15.34, 17.82, 19.00, 20.49, 21.23, 24.35, 31.85,
    37.87, 47.21, 52.17, 106.90, 262.17, 625.51, 1368.59, 3825.37, 7106.32, 11615.27, 23145.88
]
    
##################################
# 8 nodes
##################################
cray_mpich1_8n = [
    13.53, 13.53, 13.67, 13.80, 13.82, 14.02, 15.23, 15.33, 18.61, 19.70,
    88.07, 105.24, 114.24, 113.06, 130.69, 152.35, 217.96, 336.87, 590.03,
    3982.05, 6757.05, 12799.93, 25151.80 #, 45784.19
]
argonne_mpich1_8n =  [
    14.99, 14.98, 15.03, 15.02, 15.02, 15.11, 16.44, 16.59,
    16.90, 17.30, 32.55, 33.77, 61.09, 108.06, 213.20,
    430.27, 877.32, 1780.49, 3587.47, 7210.00, 14492.84,
    29013.47, 58161.55 #, 124851.46
]
openmpi1_8n = [
    12.38, 12.31, 12.56, 15.51, 15.52, 16.28, 18.57, 19.68, 20.91, 22.62,
    25.77, 33.43, 38.77, 47.65, 56.07, 116.17, 308.07, 755.36, 1690.58,
    4466.30, 8333.45, 14324.45, 29164.10
]
    
##################################
# 16 nodes
##################################
cray_mpich1_16n = [
    12.87, 12.87, 13.10, 13.13, 13.14, 13.37, 14.59, 14.80, 16.97, 17.97,
    64.95, 77.52, 80.32, 85.93, 98.77, 123.15, 169.38, 304.01, 517.59,
    3671.80, 6199.11, 11933.44, 23274.54 #, 42087.02
]
argonne_mpich1_16n = [
    13.81, 13.82, 13.82, 13.83, 13.84, 13.92, 14.85, 14.97, 15.27, 15.68, 32.82, 34.24,
    59.32, 105.84, 203.80, 411.05, 843.11, 1705.20, 3425.34, 6924.28, 13874.87, 27641.24,
    54982.37
]
openmpi1_16n = [
    12.21, 12.20, 12.46, 12.44, 16.48, 17.26, 19.56, 20.40, 21.47, 23.10, 27.56, 35.23,
    40.46, 48.94, 55.09, 116.06, 313.00, 755.24, 1696.34, 4525.89, 7272.47, 14638.19, 32907.50
]
    
##################################
# 32 nodes
##################################
cray_mpich1_32n = [
    12.80, 12.75, 12.89, 13.05, 13.04, 13.34, 14.43, 14.72, 16.28, 17.17,
    61.70, 76.20, 84.20, 84.70, 95.69, 119.86, 162.12, 276.95, 508.39,
    3511.19, 6043.67, 11522.01, 22381.94 #, 40322.93
]
argonne_mpich1_32n = [
    
]
openmpi1_32n = [
    
]
    
##########################################################################################################################

# Number of nodes used
num_nodes = [2, 4, 8, 16]

# Message sizes
sizes = [
    '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
    '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB'
]

# Averages latencies for 16MB message size, scaling nodes
cray_mpich_results = [ cray_mpich1_2n[22], cray_mpich1_4n[22], cray_mpich1_8n[22], cray_mpich1_16n[22] ]
argonne_mpich_results = [ argonne_mpich1_2n[22], argonne_mpich1_4n[22], argonne_mpich1_8n[22], argonne_mpich1_16n[22] ]
openmpi_results = [ openmpi1_2n[22], openmpi1_4n[22], openmpi1_8n[22], openmpi1_16n[22] ]

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("husl", 3)

# Set the plot size
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes
# plt.rc('axes', titlesize=14)    # fontsize of the axes title
# plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
# plt.rc('xtick', labelsize=15)   # fontsize of the tick labels
# plt.rc('ytick', labelsize=15)   # fontsize of the tick labels
# plt.rc('legend', fontsize=12)   # legend fontsize

# Plotting the line plot with larger linewidth and markersize
ax.plot(num_nodes, cray_mpich_results, marker='x', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(num_nodes, argonne_mpich_results, marker='o', markersize=10, linewidth=2.5, color=color_palette[0])
ax.plot(num_nodes, openmpi_results, marker="|", markersize=10, linewidth=2.5, color=color_palette[2])

# Set labels and title
ax.set_xlabel('Nodes')
ax.set_ylabel('Average Latency (us)')
ax.set_title('OSU MPI-CUDA Reduce Latency Test v7.1 (16 MB Message Size)')

# Rotate x-axis labels for better visibility
plt.xticks(num_nodes, num_nodes)#, rotation=45)

# Set y ticks
# ax.set_yticks(range(20000, 80001, 5000))
ax.set_yticks(range(0, 80001, 10000))

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper right') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Display the plot
plt.show()

# %%
cray_mpich1_16n = [
    12.87, 12.87, 13.10, 13.13, 13.14, 13.37, 14.59, 14.80, 16.97, 17.97,
    64.95, 77.52, 80.32, 85.93, 98.77, 123.15, 169.38, 304.01, 517.59,
    3671.80, 6199.11, 11933.44, 23274.54 #, 42087.02
]
argonne_mpich1_16n = [
    13.81, 13.82, 13.82, 13.83, 13.84, 13.92, 14.85, 14.97, 15.27, 15.68, 32.82, 34.24,
    59.32, 105.84, 203.80, 411.05, 843.11, 1705.20, 3425.34, 6924.28, 13874.87, 27641.24,
    54982.37
]
openmpi1_16n = [
    12.21, 12.20, 12.46, 12.44, 16.48, 17.26, 19.56, 20.40, 21.47, 23.10, 27.56, 35.23,
    40.46, 48.94, 55.09, 116.06, 313.00, 755.24, 1696.34, 4525.89, 7272.47, 14638.19, 32907.50
]

sizes = [
    '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
    '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB'
]

# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("husl", 3)

# Set the plot size
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes
# plt.rc('axes', titlesize=14)    # fontsize of the axes title
# plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
# plt.rc('xtick', labelsize=15)   # fontsize of the tick labels
# plt.rc('ytick', labelsize=15)   # fontsize of the tick labels
# plt.rc('legend', fontsize=12)   # legend fontsize

# Plotting the line plot with larger linewidth and markersize
ax.plot(sizes, cray_mpich1_16n, marker='x', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(sizes, argonne_mpich1_16n, marker='o', markersize=10, linewidth=2.5, color=color_palette[0])
ax.plot(sizes, openmpi1_16n, marker="|", markersize=10, linewidth=2.5, color=color_palette[2])

# Set labels and title
ax.set_xlabel('Message Size')
ax.set_ylabel('Average Latency (us)')
ax.set_title('OSU MPI-CUDA Reduce Latency Test v7.1 (16 Nodes)')

# Rotate x-axis labels for better visibility
plt.xticks(sizes, sizes, rotation=45)

# Set y ticks
# ax.set_yticks(range(0, 60001, 5000))
ax.set_yticks(range(0, 60001, 10000))

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ### osu_allreduce

# %%
##################################
# 2 nodes
##################################
cray_mpich1_2n = [
    32.99, 32.58, 32.73, 32.95, 32.83, 33.70, 28.75, 29.04, 28.47, 28.20,
    39.84, 42.24, 47.02, 56.10, 75.71, 100.68, 113.46, 122.21, 141.75,
    180.12, 246.52, 391.08, 790.53 #, 1598.14
]
argonne_mpich1_2n = [
    96.82, 96.61, 109.15, 108.88, 109.06, 108.99, 110.83, 94.92, 96.16, 97.76,
    99.67, 116.70, 188.61, 322.30, 592.49, 1120.10, 2174.70, 4270.62, 8470.15,
    17052.72, 33819.08, 67324.99, 135996.44 #, 270419.17
]
openmpi1_2n = [
    36.38, 36.12, 36.81, 36.64, 36.62, 39.19, 44.85, 45.01, 45.64, 47.47, 52.75, 74.18,
    84.26, 105.62, 186.84, 308.48, 538.12, 1004.89, 1947.15, 4950.30, 8573.77, 17112.79, 33852.83
]

##################################
# 4 nodes
##################################
cray_mpich1_4n = [
    38.55, 38.42, 38.48, 38.53, 38.62, 39.69, 37.57, 38.35, 37.88, 38.80,
    57.49, 60.24, 65.76, 74.84, 96.19, 139.79, 157.00, 176.70, 199.08, 240.39,
    328.95, 509.87, 1031.70 #, 2092.46
]
argonne_mpich1_4n = [
    121.64, 120.81, 144.38, 145.91, 146.30, 145.92, 147.26, 135.70, 121.88, 124.45,
    127.21, 141.82, 212.87, 354.12, 627.45, 1177.20, 2244.85, 4372.14, 8628.98, 17286.29,
    34484.14, 68183.50, 136328.06 #, 274186.33
]
openmpi1_4n = [
    43.23, 43.10, 51.00, 50.73, 50.83, 53.38, 57.95, 62.17, 65.96, 67.74, 73.20, 91.00,
    115.06, 147.40, 178.45, 292.34, 497.90, 917.13, 1744.89, 4343.18, 7623.76, 14425.68, 28486.71
]
    
##################################
# 8 nodes
##################################
cray_mpich1_8n = [
    43.48, 43.60, 43.72, 43.68, 43.72, 44.83, 45.12, 46.00, 45.81, 47.22,
    68.53, 74.65, 79.79, 104.22, 110.87, 184.48, 187.57, 213.15, 248.08,
    316.70, 391.04, 586.94, 1203.82 #, 2457.54
]
argonne_mpich1_8n =  [
    149.94, 150.19, 149.57, 189.70, 191.33, 190.74, 191.57,
    182.95, 173.93, 163.73, 165.74, 182.47, 261.33, 409.36,
    701.67, 1259.46, 2346.98, 4544.50, 8910.55, 17392.90,
    34606.77, 69164.34, 137774.62 #, 276071.94
]
openmpi1_8n = [
    47.93, 47.68, 48.26, 64.28, 64.47, 67.11, 72.79, 75.60, 76.89, 82.33,
    88.29, 112.42, 137.51, 172.46, 228.90, 339.27, 612.89, 999.83, 1897.28,
    5264.62, 9327.95, 17596.51, 34775.48
]
    
##################################
# 16 nodes
##################################
cray_mpich1_16n = [
    49.43, 49.36, 49.28, 49.18, 49.15, 50.11, 52.86, 53.98, 54.34, 56.52,
    80.33, 88.42, 95.43, 105.76, 129.76, 212.25, 223.31, 247.20, 292.63,
    356.28, 444.86, 656.45, 1336.43 #, 2751.48
]
argonne_mpich1_16n = [
    174.63, 174.08, 175.07, 175.30, 226.83, 227.45, 229.05, 219.39, 210.68, 203.24, 192.90,
    209.24, 285.67, 427.98, 715.94, 1280.44, 2373.70, 4543.41, 8902.39, 17682.19, 35016.47,
    69501.16, 139373.95 #, 0
]
openmpi1_16n = [
    52.54, 52.52, 52.78, 52.94, 71.81, 74.60, 81.75, 82.91, 85.79, 89.13, 98.37, 122.92,
    146.21, 181.80, 237.98, 352.95, 632.62, 1057.21, 1987.09, 5463.18, 9758.79, 18283.91, 40681.64
]
    
##################################
# 32 nodes
##################################
cray_mpich1_32n = [
    54.74, 54.24, 54.42, 54.39, 54.59, 56.22, 60.71, 61.79, 61.75, 65.05,
    90.32, 101.18, 126.84, 121.64, 144.09, 235.18, 251.62, 277.25, 318.13,
    401.96, 499.23, 746.76, 1472.72 #, 2970.71
]
argonne_mpich1_32n = [
    
]
openmpi1_32n = [
    
]
    
##########################################################################################################################

# Number of nodes used
num_nodes = [2, 4, 8, 16]

# Message sizes
sizes = [
    '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
    '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB'
]

# Averages latencies for 16MB message size, scaling nodes
cray_mpich_results = [ cray_mpich1_2n[22], cray_mpich1_4n[22], cray_mpich1_8n[22], cray_mpich1_16n[22] ]
argonne_mpich_results = [ argonne_mpich1_2n[22], argonne_mpich1_4n[22], argonne_mpich1_8n[22], argonne_mpich1_16n[22] ]
openmpi_results = [ openmpi1_2n[22], openmpi1_4n[22], openmpi1_8n[22], openmpi1_16n[22] ]

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("husl", 3)

# Set the plot size
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes
# plt.rc('axes', titlesize=14)    # fontsize of the axes title
# plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
# plt.rc('xtick', labelsize=15)   # fontsize of the tick labels
# plt.rc('ytick', labelsize=15)   # fontsize of the tick labels
# plt.rc('legend', fontsize=12)   # legend fontsize

# Plotting the line plot with larger linewidth and markersize
ax.plot(num_nodes, cray_mpich_results, marker='x', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(num_nodes, argonne_mpich_results, marker='o', markersize=10, linewidth=2.5, color=color_palette[0])
ax.plot(num_nodes, openmpi_results, marker="|", markersize=10, linewidth=2.5, color=color_palette[2])

# Set labels and title
ax.set_xlabel('Nodes')
ax.set_ylabel('Average Latency (us)')
ax.set_title('OSU MPI-CUDA AllReduce Latency Test v7.1 (16 MB Message Size)')

# Rotate x-axis labels for better visibility
plt.xticks(num_nodes, num_nodes)

# Set y ticks
# ax.set_yticks(range(0, 140001, 10000))
ax.set_yticks(range(0, 140001, 20000))

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='center left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Display the plot
plt.show()

# %%
cray_mpich1_16n = [
    49.43, 49.36, 49.28, 49.18, 49.15, 50.11, 52.86, 53.98, 54.34, 56.52,
    80.33, 88.42, 95.43, 105.76, 129.76, 212.25, 223.31, 247.20, 292.63,
    356.28, 444.86, 656.45, 1336.43 #, 2751.48
]
argonne_mpich1_16n = [
    174.63, 174.08, 175.07, 175.30, 226.83, 227.45, 229.05, 219.39, 210.68, 203.24, 192.90,
    209.24, 285.67, 427.98, 715.94, 1280.44, 2373.70, 4543.41, 8902.39, 17682.19, 35016.47,
    69501.16, 139373.95 #, 0
]
openmpi1_16n = [
    52.54, 52.52, 52.78, 52.94, 71.81, 74.60, 81.75, 82.91, 85.79, 89.13, 98.37, 122.92,
    146.21, 181.80, 237.98, 352.95, 632.62, 1057.21, 1987.09, 5463.18, 9758.79, 18283.91, 40681.64
]

sizes = [
    '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
    '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB'
]

# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("husl", 3)

# Set the plot size
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes
# plt.rc('axes', titlesize=14)    # fontsize of the axes title
# plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
# plt.rc('xtick', labelsize=15)   # fontsize of the tick labels
# plt.rc('ytick', labelsize=15)   # fontsize of the tick labels
# plt.rc('legend', fontsize=12)   # legend fontsize

# Plotting the line plot with larger linewidth and markersize
ax.plot(sizes, cray_mpich1_16n, marker='x', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(sizes, argonne_mpich1_16n, marker='o', markersize=10, linewidth=2.5, color=color_palette[0])
ax.plot(sizes, openmpi1_16n, marker="|", markersize=10, linewidth=2.5, color=color_palette[2])

# Set labels and title
ax.set_xlabel('Message Size')
ax.set_ylabel('Average Latency (us)')
ax.set_title('OSU MPI-CUDA AllReduce Latency Test v7.1 (16 Nodes)')

# Rotate x-axis labels for better visibility
plt.xticks(sizes, sizes, rotation=45)

# Set y ticks
ax.set_yticks(range(0, 140001, 20000))

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ### osu_bcast

# %%
##################################
# 2 nodes
##################################
cray_mpich1_2n = [
    21.98, 21.88, 22.11, 22.18, 22.13, 22.69, 16.14, 24.98, 17.80, 17.88,
    18.05, 14.24, 14.80, 18.86, 20.92, 24.35, 31.55, 44.62, 74.36, 127.99,
    236.34, 456.52, 898.09 #, 1779.62
]
argonne_mpich1_2n = [
    29.47, 29.18, 29.38, 29.43, 29.43, 29.92, 22.91, 23.06, 23.38, 23.87,
    24.63, 41.03, 54.57, 81.58, 134.46, 239.84, 451.21, 97.72, 210.43, 351.97,
    491.19, 1152.77, 1688.10 #, 2801.80
]
openmpi1_2n = [
    30.06, 30.16, 30.77, 30.78, 30.94, 31.84, 10.91, 10.98, 11.18, 11.54, 11.72, 19.03,
    20.81, 23.62, 29.35, 51.90, 98.69, 188.56, 370.27, 730.41, 1450.77, 2921.04, 5828.83
]

##################################
# 4 nodes
##################################
cray_mpich1_4n = [
    34.10, 34.07, 34.58, 34.57, 34.69, 34.95, 17.27, 26.66, 18.56, 18.48,
    18.67, 15.00, 15.71, 21.79, 34.22, 40.54, 55.58, 85.87, 146.60, 270.73,
    517.51, 1016.84, 2052.05 #, 3985.88
]
argonne_mpich1_4n = [
    38.69, 38.31, 39.02, 39.12, 39.37, 39.80, 26.53, 26.96, 27.15, 27.79,
    28.91, 48.39, 62.24, 89.98, 145.71, 254.10, 471.62, 129.47, 333.75, 513.69,
    747.29, 1080.45, 2652.24 #, 3941.51
]
openmpi1_4n = [
    38.93, 38.86, 39.80, 39.84, 39.84, 41.30,
    12.69, 13.02, 13.24, 13.74, 13.94, 18.85,
    20.31, 23.68, 31.32, 61.93, 121.30, 244.50,
    488.18, 979.43, 1964.20, 3873.27, 7818.51
]
    
##################################
# 8 nodes
##################################
cray_mpich1_8n = [
    42.46, 42.44, 43.19, 43.12, 43.20, 43.63, 20.20, 29.18, 21.39, 21.74,
    22.04, 15.29, 16.05, 24.56, 43.42, 54.44, 76.20, 122.48, 210.12, 397.79,
    760.89, 1498.70, 2970.01 #, 5919.61
]
argonne_mpich1_8n = [
    48.73, 48.88, 49.61, 49.49, 49.58, 50.12, 37.25, 37.66,
    37.99, 38.70, 39.52, 70.24, 103.69, 144.20, 216.31,
    325.71, 543.52, 230.90, 890.86, 1042.86, 1282.55,
    1711.74, 2451.57 #, 5796.07
]
openmpi1_8n = [
    50.26, 51.10, 52.53, 52.50, 51.60, 53.26, 15.32, 15.48, 15.71, 16.17,
    20.64, 35.54, 36.39, 28.09, 40.25, 90.38, 158.22, 295.90, 574.11,
    1138.03, 2253.10, 4464.96, 8894.70
]
    
##################################
# 16 nodes
##################################
cray_mpich1_16n = [
    53.84, 53.93, 55.06, 55.10, 55.26, 55.92, 23.76, 32.89, 25.02, 25.33,
    25.78, 18.19, 19.62, 31.53, 53.64, 66.85, 96.15, 155.15, 277.74, 520.67,
    1013.76, 2046.75, 3987.82 #, 7955.12
]
argonne_mpich1_16n = [
    56.91, 56.97, 57.87, 57.91, 57.96, 58.66, 38.29, 38.71, 39.08, 40.24, 41.07, 70.44,
    112.60, 146.19, 213.56, 330.90, 550.42, 253.99, 2445.94, 1719.63, 1964.09, 2386.51, 3194.15
]
openmpi1_16n = [
    62.17, 62.16, 64.01, 63.96, 64.17, 66.02, 17.16, 17.30, 17.54, 18.03, 23.26, 39.03,
    41.51, 47.11, 57.78, 95.16, 167.76, 317.71, 633.90, 1240.96, 2481.32, 4968.38, 9896.20
]

    
##################################
# 32 nodes
##################################
cray_mpich1_32n = [
    64.21, 63.86, 65.09, 65.30, 65.41, 66.31, 25.46, 34.71, 26.84, 27.22,
    27.78, 21.79, 23.75, 39.42, 65.08, 82.55, 119.99, 191.92, 338.16, 649.19,
    1270.45, 2515.25, 4997.04 #, 9995.05
]
argonne_mpich1_32n = [
    
]
openmpi1_32n = [
    
]
    
##########################################################################################################################

# Number of nodes used
num_nodes = [2, 4, 8, 16]

# Message sizes
sizes = [
    '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
    '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB'
]

# Averages latencies for 16MB message size, scaling nodes
cray_mpich_results = [ cray_mpich1_2n[22], cray_mpich1_4n[22], cray_mpich1_8n[22], cray_mpich1_16n[22] ]
argonne_mpich_results = [ argonne_mpich1_2n[22], argonne_mpich1_4n[22], argonne_mpich1_8n[22], argonne_mpich1_16n[22] ]
openmpi_results = [ openmpi1_2n[22], openmpi1_4n[22], openmpi1_8n[22], openmpi1_16n[22] ]

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("husl", 3)

# Set the plot size
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes
# plt.rc('axes', titlesize=14)    # fontsize of the axes title
# plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
# plt.rc('xtick', labelsize=15)   # fontsize of the tick labels
# plt.rc('ytick', labelsize=15)   # fontsize of the tick labels
# plt.rc('legend', fontsize=12)   # legend fontsize

# Plotting the line plot with larger linewidth and markersize
ax.plot(num_nodes, cray_mpich_results, marker='x', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(num_nodes, argonne_mpich_results, marker='o', markersize=10, linewidth=2.5, color=color_palette[0])
ax.plot(num_nodes, openmpi_results, marker="|", markersize=10, linewidth=2.5, color=color_palette[2])

# Set labels and title
ax.set_xlabel('Nodes')
ax.set_ylabel('Average Latency (us)')
ax.set_title('OSU MPI-CUDA Broadcast Latency Test v7.1 (16 MB Message Size)')

# Rotate x-axis labels for better visibility
plt.xticks(num_nodes, num_nodes)

# Set y-ticks
ax.set_yticks(range(0, 10001, 2000))

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Display the plot
plt.show()

# %%
cray_mpich1_16n = [
    53.84, 53.93, 55.06, 55.10, 55.26, 55.92, 23.76, 32.89, 25.02, 25.33,
    25.78, 18.19, 19.62, 31.53, 53.64, 66.85, 96.15, 155.15, 277.74, 520.67,
    1013.76, 2046.75, 3987.82 #, 7955.12
]
argonne_mpich1_16n = [
    56.91, 56.97, 57.87, 57.91, 57.96, 58.66, 38.29, 38.71, 39.08, 40.24, 41.07, 70.44,
    112.60, 146.19, 213.56, 330.90, 550.42, 253.99, 2445.94, 1719.63, 1964.09, 2386.51, 3194.15
]
openmpi1_16n = [
    62.17, 62.16, 64.01, 63.96, 64.17, 66.02, 17.16, 17.30, 17.54, 18.03, 23.26, 39.03,
    41.51, 47.11, 57.78, 95.16, 167.76, 317.71, 633.90, 1240.96, 2481.32, 4968.38, 9896.20
]

sizes = [
    '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
    '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB'
]

# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("husl", 3)

# Set the plot size
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes
# plt.rc('axes', titlesize=14)    # fontsize of the axes title
# plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
# plt.rc('xtick', labelsize=15)   # fontsize of the tick labels
# plt.rc('ytick', labelsize=15)   # fontsize of the tick labels
# plt.rc('legend', fontsize=12)   # legend fontsize

# Plotting the line plot with larger linewidth and markersize
ax.plot(sizes, cray_mpich1_16n, marker='x', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(sizes, argonne_mpich1_16n, marker='o', markersize=10, linewidth=2.5, color=color_palette[0])
ax.plot(sizes, openmpi1_16n, marker="|", markersize=10, linewidth=2.5, color=color_palette[2])

# Set labels and title
ax.set_xlabel('Message Size')
ax.set_ylabel('Average Latency (us)')
ax.set_title('OSU MPI-CUDA Broadcast Latency Test v7.1 (16 Nodes)')

# Rotate x-axis labels for better visibility
plt.xticks(sizes, sizes, rotation=45)

# Set y-ticks
ax.set_yticks(range(0, 10001, 2000))

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ### osu_alltoall

# %%
##################################
# 2 nodes
##################################
cray_mpich1_2n = [
    39.34, 39.01, 38.65, 39.64, 40.79, 41.02, 41.84, 43.40, 52.55, 50.80,
    52.54, 55.78, 57.18, 59.98, 62.62, 66.93, 96.86, 229.64, 418.86, 790.84,
    1571.84, 3121.45, 6336.75 #, 12707.16
]
argonne_mpich1_2n = [
    102.88, 102.51, 103.53, 103.44, 103.69, 104.47, 71.73, 71.89, 72.26, 72.89,
    74.23, 77.10, 151.84, 97.45, 104.75, 129.22, 188.43, 298.06, 1036.30, 1701.96,
    3140.63, 5761.33, 11062.30 #, 22946.02
]
openmpi1_2n = [
    73.30, 73.17, 74.96, 74.93, 75.01, 76.26,
    23.13, 23.19, 23.33, 23.51, 23.81, 30.33,
    33.75, 44.36, 63.21, 100.74, 171.68, 331.07,
    716.11, 1675.10, 3610.88, 7230.25, 15291.71
]
##################################
# 4 nodes
##################################
cray_mpich1_4n = [
    56.99, 56.02, 56.74, 60.64, 61.09, 63.58, 64.99, 66.93, 73.35, 72.11,
    70.47, 73.47, 79.09, 83.42, 89.47, 134.21, 254.29, 592.94, 1094.89,
    2146.36, 4264.84, 8345.29, 16660.07 #, 36249.16
]
argonne_mpich1_4n = [
    531.11, 594.18, 600.86, 596.23, 621.08, 607.56, 594.54, 4082.81,
    4237.78, 4548.44, 4664.63, 4588.63, 4335.22, 5071.23, 50184.73, 51781.91,
    50133.63, 51366.36, 86537.96, 89259.99, 82950.73, 92135.53, 97093.37 #, 0
]
openmpi1_4n = [
    3740.49, 3357.97, 3710.71, 3727.75, 3749.61, 3752.73,
    3914.08, 35.03, 35.14, 35.52, 36.01, 44.74,
    54.81, 76.03, 113.85, 193.83, 371.12, 744.11,
    1601.20, 3664.37, 7843.71, 16656.70, 39672.46
]
    
##################################
# 8 nodes
##################################
cray_mpich1_8n = [
    90.40, 91.03, 94.26, 94.91, 95.69, 97.69, 98.76, 104.75, 117.03, 115.85,
    120.04, 122.83, 130.86, 131.33, 164.23, 278.65, 592.15, 1302.83, 2477.64,
    4753.43, 9367.57, 18575.60, 40629.29 #, 82502.12
]
argonne_mpich1_8n = [
    1036.64, 1153.63, 1184.88, 1154.76, 1164.89, 1178.00, 1186.93, 4974.20, 5024.73, 5023.96,
    4887.42, 4924.73, 5106.12, 5256.01, 136768.71, 134091.84, 134171.06, 133212.99, 221336.58,
    230474.82, 228276.63, 236582.95, 247036.08
]
openmpi1_8n = [
    6351.36, 6152.08, 5711.00, 5656.76, 5523.40, 5376.17, 5664.87, 4045.50, 4172.87, 4183.27,
    4167.77, 4198.17, 4077.33, 3792.28, 3972.50, 4046.98, 4180.23, 5425.68, 7313.07, 13226.80,
    27985.83, 57008.12, 117727.81
]
    
##################################
# 16 nodes
##################################
cray_mpich1_16n = [
    159.14, 163.26, 163.90, 159.35, 163.78, 163.33, 172.22, 182.38, 217.48, 225.75,
    230.60, 230.02, 248.64, 235.25, 300.98, 571.66, 1240.30, 2793.38, 5203.43,
    9921.90, 19376.41, 42869.16, 86634.40 #, 174095.44
]
argonne_mpich1_16n = [
    531.11, 594.18, 600.86, 596.23, 621.08, 607.56, 594.54, 4082.81, 4237.78,
    4548.44, 4664.63, 4588.63, 4335.22, 5071.23, 50184.73, 51781.91, 50133.63,
    51366.36, 86537.96, 89259.99, 82950.73, 92135.53, 97093.37 #, 0
]
openmpi1_16n = [
    14591.89, 15269.67, 14751.73, 14432.85, 15370.97, 14529.07, 15104.61, 15008.44,
    90120.38, 90689.61, 90561.47, 90997.58, 89733.82, 90218.21, 92863.95, 90859.82,
    561337.52, 562192.68, 567729.18, 566770.86, 571664.17, 583491.84, 592369.29
]
    
##################################
# 32 nodes
##################################
cray_mpich1_32n = [
    320.10, 321.72, 306.39, 312.19, 320.24, 324.78, 334.91, 385.19, 540.63, 543.16,
    549.86, 555.83, 578.24, 463.99, 601.93, 1141.27, 2622.07, 5814.03, 10817.12, 20756.62,
    47469.00, 105345.54, 221658.02 #, 408628.31
]
argonne_mpich1_32n = [
    
]
openmpi1_32n = [
    
]
    
##########################################################################################################################

# Number of nodes used
num_nodes = [2, 4, 8, 16]

# Message sizes
sizes = [
    '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
    '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB'
]

# Averages latencies for 16MB message size, scaling nodes
cray_mpich_results = [ cray_mpich1_2n[22], cray_mpich1_4n[22], cray_mpich1_8n[22], cray_mpich1_16n[22] ]
argonne_mpich_results = [ argonne_mpich1_2n[22], argonne_mpich1_4n[22], argonne_mpich1_8n[22], argonne_mpich1_16n[22] ]
openmpi_results = [ openmpi1_2n[22], openmpi1_4n[22], openmpi1_8n[22], openmpi1_16n[22] ]

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("husl", 3)

# Set the plot size
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes
# plt.rc('axes', titlesize=14)    # fontsize of the axes title
# plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
# plt.rc('xtick', labelsize=15)   # fontsize of the tick labels
# plt.rc('ytick', labelsize=15)   # fontsize of the tick labels
# plt.rc('legend', fontsize=12)   # legend fontsize

# Plotting the line plot with larger linewidth and markersize
ax.plot(num_nodes, cray_mpich_results, marker='x', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(num_nodes, argonne_mpich_results, marker='o', markersize=10, linewidth=2.5, color=color_palette[0])
ax.plot(num_nodes, openmpi_results, marker="|", markersize=10, linewidth=2.5, color=color_palette[2])

# Set labels and title
ax.set_xlabel('Nodes')
ax.set_ylabel('Average Latency (us)')
ax.set_title('OSU MPI-CUDA All-to-All Personalized Exchange Latency Test v7.1 (16 MB Message Size)')

# Rotate x-axis labels for better visibility
plt.xticks(num_nodes, num_nodes)

# Set y-ticks
ax.set_yticks(range(0, 600001, 100000))

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Display the plot
plt.show()

# %%
cray_mpich1_16n = [
    159.14, 163.26, 163.90, 159.35, 163.78, 163.33, 172.22, 182.38, 217.48, 225.75,
    230.60, 230.02, 248.64, 235.25, 300.98, 571.66, 1240.30, 2793.38, 5203.43,
    9921.90, 19376.41, 42869.16, 86634.40 #, 174095.44
]
argonne_mpich1_16n = [
    531.11, 594.18, 600.86, 596.23, 621.08, 607.56, 594.54, 4082.81, 4237.78,
    4548.44, 4664.63, 4588.63, 4335.22, 5071.23, 50184.73, 51781.91, 50133.63,
    51366.36, 86537.96, 89259.99, 82950.73, 92135.53, 97093.37 #, 0
]
openmpi1_16n = [
    14591.89, 15269.67, 14751.73, 14432.85, 15370.97, 14529.07, 15104.61, 15008.44,
    90120.38, 90689.61, 90561.47, 90997.58, 89733.82, 90218.21, 92863.95, 90859.82,
    561337.52, 562192.68, 567729.18, 566770.86, 571664.17, 583491.84, 592369.29
]

sizes = [
    '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
    '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB'
]

# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("husl", 3)

# Set the plot size
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes
# plt.rc('axes', titlesize=14)    # fontsize of the axes title
# plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
# plt.rc('xtick', labelsize=15)   # fontsize of the tick labels
# plt.rc('ytick', labelsize=15)   # fontsize of the tick labels
# plt.rc('legend', fontsize=12)   # legend fontsize

# Plotting the line plot with larger linewidth and markersize
ax.plot(sizes, cray_mpich1_16n, marker='x', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(sizes, argonne_mpich1_16n, marker='o', markersize=10, linewidth=2.5, color=color_palette[0])
ax.plot(sizes, openmpi1_16n, marker="|", markersize=10, linewidth=2.5, color=color_palette[2])

# Set labels and title
ax.set_xlabel('Message Size')
ax.set_ylabel('Average Latency (us)')
ax.set_title('OSU MPI-CUDA All-to-All Personalized Exchange Latency Test v7.1 (16 Nodes)')

# Rotate x-axis labels for better visibility
plt.xticks(sizes, sizes, rotation=45)

# Set y-ticks
ax.set_yticks(range(0, 600001, 100000))

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ## TEMPLATE:

# %%
##################################
# 2 nodes
##################################
cray_mpich1_2n = [
    
]
argonne_mpich1_2n = [
    
]
openmpi1_2n = [
    
]

##################################
# 4 nodes
##################################
cray_mpich1_4n = [
    
]
argonne_mpich1_4n = [
    
]
openmpi1_4n = [
    
]
    
##################################
# 8 nodes
##################################
cray_mpich1_8n = [
    
]
argonne_mpich1_8n = [
    
]
openmpi1_8n = [
    
]
    
##################################
# 16 nodes
##################################
cray_mpich1_16n = [
    
]
argonne_mpich1_16n = [
    
]
openmpi1_16n = [
    
]
    
##################################
# 32 nodes
##################################
cray_mpich1_32n = [
    
]
argonne_mpich1_32n = [
    
]
openmpi1_32n = [
    
]
    
##########################################################################################################################

# Number of nodes used
num_nodes = [2, 4, 8, 16, 32]
message_sizes = [
    '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
    '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB', '32MB'
]

# %% [markdown]
# ## TEST

# %%
##################################
# 2 nodes
##################################
cray_mpich1_2n = [
    13.38, 13.51, 13.37, 13.77, 14.13, 14.26, 14.30, 16.02, 17.43, 17.69,
    18.82, 21.46, 24.09, 30.19, 41.73, 64.64, 109.87, 199.93, 365.81,
    665.28, 1263.89, 3141.49, 13318.15 #, 38798.90
]
argonne_mpich1_2n = [
    15.75, 15.73, 15.78, 15.85, 16.36, 16.47, 16.43, 16.47, 17.31, 18.37,
    18.86, 25.83, 43.87, 43.66, 71.35, 115.56, 215.29, 388.37, 596.26, 1196.24,
    2396.99, 5613.51, 14658.02 #, 0
]
openmpi1_2n = [
    13.71, 13.65, 13.88, 13.86, 14.58, 16.10, 12.15, 12.58, 9.63, 10.87, 11.42, 23.39,
    26.29, 32.60, 41.87, 61.80, 84.76, 136.24, 237.59, 440.79, 843.22, 3100.02, 6559.36
]

##################################
# 4 nodes
##################################
cray_mpich1_4n = [
    12.88, 12.88, 12.83, 13.65, 14.16, 14.33, 14.47, 15.43, 16.47, 16.82,
    19.37, 21.87, 24.81, 31.19, 43.77, 68.50, 118.21, 217.02, 407.58, 761.67,
    1882.81, 4304.93, 15313.57 #, 43271.52
]
argonne_mpich1_4n = [
    15.71, 15.66, 15.64, 15.85, 16.34, 16.42, 16.50, 16.51,
    19.70, 20.78, 21.98, 29.44, 50.79, 47.23, 96.39, 172.09,
    314.94, 465.97, 657.57, 1268.03, 2924.46, 7826.73, 19641.06 #, 0
]
openmpi1_4n = [
    13.47, 13.43, 13.76, 14.01, 14.58, 16.20, 12.56, 12.78, 10.09, 11.54, 11.92, 26.15,
    29.26, 37.40, 45.85, 66.26, 94.17, 154.68, 274.40, 512.30, 988.78, 3720.40, 7437.22
]
    
##################################
# 8 nodes
##################################
cray_mpich1_8n = [
    12.98, 12.90, 12.90, 13.78, 14.40, 14.48, 14.65, 15.31, 16.17, 17.34,
    19.33, 22.05, 25.59, 32.78, 46.58, 74.85, 129.81, 240.91, 453.24,
    1103.68, 2407.65, 5243.80, 17088.56 #, 47497.69
]
argonne_mpich1_8n = [
    184.65, 185.16, 186.42, 190.94, 192.31, 191.82, 192.76, 367.34,
    475.61, 527.51, 527.67, 544.51, 575.98, 571.71, 705.35, 1213.76,
    1898.35, 2053.15, 2274.18, 2860.57, 4612.78, 10537.40, 24069.26 #, 0
]
openmpi1_8n = [
    13.26, 13.23, 13.69, 14.06, 14.75, 16.38, 12.50, 13.26, 11.19, 12.21, 12.92, 25.51,
    31.59, 44.50, 64.84, 105.09, 173.35, 192.45, 749.05, 1717.97, 3637.13, 9314.25, 18685.30
]
    
##################################
# 16 nodes
##################################
cray_mpich1_16n = [
    12.48, 12.65, 12.68, 13.50, 13.99, 14.10, 14.25, 14.77, 16.05, 16.87,
    18.87, 21.93, 25.51, 33.22, 47.89, 77.75, 137.68, 257.24, 634.54,
    1397.51, 2949.17, 6277.91, 19212.84 #, 51606.87
]
argonne_mpich1_16n = [
    235.90, 238.07, 244.19, 241.59, 237.48, 241.57, 469.14, 631.04,
    741.22, 810.64, 811.74, 801.23, 819.99, 926.35, 1525.82, 2259.14,
    3233.22, 3404.72, 3679.86, 4233.94, 6152.53, 12941.89, 28552.10 #, 0
]
openmpi1_16n = [
    132.81, 127.81, 128.60, 130.53, 135.06, 136.93, 257.27, 338.12, 389.36, 426.34, 476.18,
    465.89, 467.56, 490.88, 523.00, 550.02, 611.92, 982.98, 1714.65, 3539.51, 7044.12,
    16045.08, 32135.26
]
    
##################################
# 32 nodes
##################################
cray_mpich1_32n = [
    12.47, 12.65, 12.56, 13.38, 13.89, 14.00, 14.17, 15.03, 15.98, 16.85,
    18.96, 22.03, 26.18, 34.44, 50.59, 82.91, 146.90, 353.05, 778.20,
    1670.41, 3514.22, 7426.73, 21469.74 #, 55827.81
]
argonne_mpich1_32n =  [
    287.81, 288.88, 292.16, 292.63, 291.23, 562.80, 776.28, 945.37,
    1069.96, 1124.36, 1118.83, 1126.59, 1171.23, 1736.67, 2517.23,
    3303.85, 4458.06, 4709.07, 4848.24, 6129.24, 8247.47, 15489.43, 32858.05 #, 0
]
openmpi1_32n = [
    152.06, 157.11, 153.50, 157.32, 156.73, 297.92, 412.66, 485.65, 558.17, 574.94, 581.62,
    603.90, 600.31, 623.94, 642.63, 693.37, 1095.84, 1878.14, 3561.16, 6801.15, 13449.19,
    28902.76, 57911.09
]
    
##########################################################################################################################

# Number of nodes used
num_nodes = [2, 4, 8, 16]

# Message sizes
sizes = [
    '4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', 
    '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB'
]

# Averages latencies for 16MB message size, scaling nodes
cray_mpich_results = [ cray_mpich1_2n[22], cray_mpich1_4n[22], cray_mpich1_8n[22], cray_mpich1_16n[22] ]
argonne_mpich_results = [ argonne_mpich1_2n[22], argonne_mpich1_4n[22], argonne_mpich1_8n[22], argonne_mpich1_16n[22] ]
openmpi_results = [ openmpi1_2n[22], openmpi1_4n[22], openmpi1_8n[22], openmpi1_16n[22] ]

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("husl", 3)

# Set the plot size
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(num_nodes, cray_mpich_results, marker='x', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(num_nodes, argonne_mpich_results, marker='o', markersize=10, linewidth=2.5, color=color_palette[0])
ax.plot(num_nodes, openmpi_results, marker="|", markersize=10, linewidth=2.5, color=color_palette[2])

# Set labels and title
ax.set_xlabel('Nodes')
ax.set_ylabel('Average Latency (us)')
ax.set_title('OSU MPI-CUDA Gather Latency Test v7.1 (16 MB Message Size)')

# Set y ticks
# ax.set_yticks(range(0, 35001, 5000))
ax.set_yticks(range(6000, 35001, 4000))

# Rotate x-axis labels for better visibility
plt.xticks(num_nodes, num_nodes)

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Display the plot
plt.show()
