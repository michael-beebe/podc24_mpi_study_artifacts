# %% [markdown]
# # Point-to-Point OSU Microbenchmarks (Device to Device)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ------------------------------

# %% [markdown]
# ### osu_latency - Latency Test
#     * The latency tests are carried out in a ping-pong fashion. The sender
#     * sends a message with a certain data size to the receiver and waits for a
#     * reply from the receiver. The receiver receives the message from the sender
#     * and sends back a reply with the same data size. Many iterations of this
#     * ping-pong test are carried out and average one-way latency numbers are
#     * obtained. Blocking version of MPI functions (MPI_Send and MPI_Recv) are
#     * used in the tests. This test is available here.

# %%
sizes = ['4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB']
size_values = [4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304, 8388608, 16777216]
num_elements = len(sizes)

# Test 1
cray_mpich1 = [9.76, 9.74, 10.02, 10.01, 10.02, 10.65, 3.51, 3.55, 3.63, 3.80, 3.92, 4.29, 4.89, 8.66, 10.02, 12.71, 18.13, 28.94, 50.80, 94.37, 181.52, 356.69, 707.60]
argonne_mpich1 = [9.47, 9.46, 9.72, 9.75, 9.82, 10.50, 3.94, 4.00, 4.07, 4.24, 4.31, 7.85, 8.51, 9.21, 10.62, 13.43, 18.95, 30.08, 88.09, 126.03, 203.57, 358.03, 665.18]
openmpi1 = [10.74, 10.71, 10.95, 10.94, 10.96, 11.59, 5.08, 5.13, 5.21, 5.36, 5.45, 11.69, 12.48, 14.01, 15.81, 18.54, 24.03, 35.28, 57.53, 103.11, 192.35, 375.72, 739.74]

# Test 2
cray_mpich2 = [9.67, 9.63, 9.88, 9.89, 9.88, 10.50, 3.45, 3.49, 3.57, 3.73, 3.86, 4.23, 4.83, 8.55, 9.93, 12.70, 18.12, 28.93, 50.78, 94.37, 181.64, 357.21, 709.70]
argonne_mpich2 = [9.56, 9.51, 9.74, 9.72, 9.74, 10.36, 3.94, 4.00, 4.07, 4.24, 4.30, 7.90, 8.56, 9.24, 10.66, 13.45, 18.96, 30.14, 88.28, 126.15, 203.22, 358.84, 666.49]
openmpi2 = [10.66, 10.66, 10.93, 10.93, 10.90, 11.48, 5.18, 5.21, 5.25, 5.36, 5.44, 11.68, 12.45, 13.99, 15.80, 18.46, 23.97, 35.25, 57.53, 102.30, 191.51, 377.49, 739.90]
    
# Test 3
cray_mpich3 = [9.66, 9.67, 9.90, 9.83, 9.84, 10.47, 3.47, 3.51, 3.59, 3.75, 3.87, 4.25, 4.86, 8.60, 9.98, 12.66, 18.07, 28.87, 50.56, 94.06, 181.00, 356.14, 706.58]
argonne_mpich3 = [9.45, 9.45, 9.70, 9.70, 9.68, 10.29, 3.90, 3.94, 4.03, 4.18, 4.26, 7.84, 8.47, 9.19, 10.58, 13.43, 19.02, 30.11, 87.94, 125.71, 203.27, 358.69, 668.69]
openmpi3 = [10.65, 10.64, 10.95, 10.95, 10.96, 11.62, 5.03, 5.09, 5.18, 5.33, 5.41, 11.66, 12.45, 14.01, 15.71, 18.47, 23.93, 35.33, 57.24, 102.19, 190.87, 374.37, 738.07]
    
# Test 4
cray_mpich4 = [9.63, 9.59, 9.85, 9.84, 9.87, 10.52, 3.48, 3.52, 3.60, 3.77, 3.89, 4.27, 4.87, 8.68, 10.06, 12.77, 18.26, 29.01, 50.79, 94.65, 182.16, 357.29, 710.08]
argonne_mpich4 = [9.53, 9.52, 9.78, 9.78, 9.75, 10.38, 3.91, 3.97, 4.05, 4.23, 4.30, 7.85, 8.51, 9.20, 10.58, 13.34, 18.95, 29.97, 88.45, 126.41, 203.54, 358.75, 666.43]
openmpi4 = [9.28, 9.27, 9.52, 9.53, 9.55, 10.21, 3.74, 3.79, 3.87, 4.02, 4.06, 7.68, 8.32, 9.03, 10.40, 13.18, 18.70, 29.62, 51.68, 96.02, 184.35, 359.81, 717.47]

# Test 5
cray_mpich5 = [9.76, 9.73, 9.99, 9.99, 10.05, 10.73, 3.51, 3.56, 3.62, 3.82, 3.96, 4.31, 4.91, 8.68, 10.11, 12.76, 18.20, 29.02, 50.89, 94.65, 181.71, 357.88, 709.62]
argonne_mpich5 = [9.34, 9.34, 9.60, 9.66, 9.71, 10.35, 3.91, 3.96, 4.05, 4.20, 4.29, 7.86, 8.52, 9.20, 10.59, 13.33, 18.89, 29.95, 88.96, 126.42, 203.73, 358.86, 667.70]
openmpi5 = [9.37, 9.33, 9.60, 9.60, 9.62, 10.24, 3.73, 3.79, 3.85, 4.01, 4.08, 7.64, 8.29, 9.03, 10.38, 13.19, 18.75, 29.80, 52.05, 96.88, 184.93, 363.60, 722.18]

# Average test results
cray_mpich_averages = []
argonne_mpich_averages = []
openmpi_averages = []
for i in range(num_elements):
    cray_mpich_averages.append(( cray_mpich1[i] + cray_mpich2[i] + cray_mpich3[i] + cray_mpich4[i] + cray_mpich5[i] ) / 5)
    argonne_mpich_averages.append(( argonne_mpich1[i] + argonne_mpich2[2] + argonne_mpich3[i] + argonne_mpich4[i] + argonne_mpich5[i] ) / 5)
    openmpi_averages.append(( openmpi1[i] + openmpi2[i] + openmpi3[i] + openmpi4[i] + openmpi5[i] ) / 5)
 
#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("colorblind", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(size_values, cray_mpich_averages, marker='x', markersize=10, linewidth=2.5, color=color_palette[2])
ax.plot(size_values, argonne_mpich_averages, marker='o', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(size_values, openmpi_averages, marker="|", markersize=10, linewidth=2.5, color=color_palette[0])

# Set labels and title
ax.set_xlabel('Size')
ax.set_ylabel('Latency (us)')
# ax.set_title(' OSU MPI-CUDA Point-to-Point Latency')

plt.xscale('log')
plt.yscale('log')

# Set y ticks
# ax.set_yticks(range(0, 801, 100))

# Rotate x-axis labels for better visibility
ax.set_xticks(size_values)
ax.set_xticklabels(sizes, rotation=45)

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save plot
plt.savefig("figures/loglog_pt2pt/pt2pt_latency_all.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %%
sizes = ['4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K']
size_values = [4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192]
num_elements = len(sizes)

cray_mpich_small = []
argonne_mpich_small = []
openmpi_small = []

for i in range(num_elements):
    cray_mpich_small.append( cray_mpich_averages[i] )
    argonne_mpich_small.append( argonne_mpich_averages[i] )
    openmpi_small.append( openmpi_averages[i] )

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("colorblind", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(size_values, cray_mpich_small, marker='x', markersize=10, linewidth=2.5, color=color_palette[2])
ax.plot(size_values, argonne_mpich_small, marker='o', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(size_values, openmpi_small, marker="|", markersize=10, linewidth=2.5, color=color_palette[0])

# Set labels and title
ax.set_xlabel('Size')
ax.set_ylabel('Latency (us)')
# ax.set_title(' OSU MPI-CUDA Point-to-Point Latency')

# Set y ticks
# ax.set_yticks(range(0, 13, 2))

plt.xscale('log')
plt.yscale('log')

# Rotate x-axis labels for better visibility
ax.set_xticks(size_values)
ax.set_xticklabels(sizes, rotation=45)

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='lower left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save plot
plt.savefig("figures/loglog_pt2pt/pt2pt_latency_small.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %%
sizes = ['16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB']
size_values = [16384, 32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304, 8388608, 16777216]

num_elements = len(sizes)

cray_mpich_large = []
argonne_mpich_large = []
openmpi_large = []

for i in range(num_elements):
    cray_mpich_large.append( cray_mpich_averages[i+12] )
    argonne_mpich_large.append( argonne_mpich_averages[i+12] )
    openmpi_large.append( openmpi_averages[i+12] )

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("colorblind", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(size_values, cray_mpich_large, marker='x', markersize=10, linewidth=2.5, color=color_palette[2])
ax.plot(size_values, argonne_mpich_large, marker='o', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(size_values, openmpi_large, marker="|", markersize=10, linewidth=2.5, color=color_palette[0])

# Set labels and title
ax.set_xlabel('Size')
ax.set_ylabel('Latency (us)')
# ax.set_title(' OSU MPI-CUDA Point-to-Point Latency')

# Set y ticks
# ax.set_yticks(range(0, 801, 100))

plt.xscale('log')
plt.yscale('log')

# Rotate x-axis labels for better visibility
ax.set_xticks(size_values)
ax.set_xticklabels(sizes, rotation=45)

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save plot
plt.savefig("figures/loglog_pt2pt/pt2pt_latency_large.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %% [markdown]
# ### osu_bw - Bandwidth Test
#     * The bandwidth tests are carried out by having the sender sending out a
#     * fixed number (equal to the window size) of back-to-back messages to the
#     * receiver and then waiting for a reply from the receiver. The receiver
#     * sends the reply only after receiving all these messages. This process is
#     * repeated for several iterations and the bandwidth is calculated based on
#     * the elapsed time (from the time sender sends the first message until the
#     * time it receives the reply back from the receiver) and the number of bytes
#     * sent by the sender. The objective of this bandwidth test is to determine
#     * the maximum sustained date rate that can be achieved at the network level.
#     * Thus, non-blocking version of MPI functions (MPI_Isend and MPI_Irecv) are
#     * used in the test. This test is available here.

# %%
sizes = ['4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K', '16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB']
size_values = [4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304, 8388608, 16777216]
num_elements = len(sizes)

# Test 1
cray_mpich1 = [0.49, 0.99, 1.91, 3.83, 7.66, 15.16, 322.20, 664.02, 1320.99, 2621.78, 5229.88, 10395.12, 17907.68, 20240.80, 22111.03, 22795.09, 23423.68, 23508.70, 23641.08, 23883.94, 23914.15, 23892.85, 23909.56]
argonne_mpich1 = [0.54, 1.08, 2.09, 4.18, 8.33, 16.50, 329.49, 661.00, 1314.02, 2643.65, 5284.86, 9465.73, 12054.60, 16085.58, 19861.66, 21714.76, 22704.34, 22866.40, 441.69, 873.86, 1675.08, 3103.84, 5559.73]
openmpi1 = [0.53, 1.07, 2.04, 4.09, 8.13, 15.97, 281.51, 594.28, 1237.34, 2379.71, 2724.22, 1792.46, 3555.52, 13472.73, 17200.41, 20933.07, 21826.29, 22328.91, 22497.87, 22913.18, 22833.45, 22960.65, 23092.08]

# Test 2
cray_mpich2 = [0.49, 0.98, 1.90, 3.81, 7.60, 15.14, 327.04, 613.88, 1215.97, 2543.65, 5129.79, 9392.27, 17886.66, 20243.75, 22084.62, 22707.93, 23346.00, 23504.71, 23812.98, 23907.57, 23690.89, 23846.40, 23802.08]
# Average test results
cray_mpich_averages = []
argonne_mpich_averages = []
openmpi_averages = []
for i in range(num_elements):
    cray_mpich_averages.append(( cray_mpich1[i] + cray_mpich2[i] + cray_mpich3[i] + cray_mpich4[i] + cray_mpich5[i] ) / 5)
    argonne_mpich_averages.append(( argonne_mpich1[i] + argonne_mpich2[2] + argonne_mpich3[i] + argonne_mpich4[i] + argonne_mpich5[i] ) / 5)
    openmpi_averages.append(( openmpi1[i] + openmpi2[i] + openmpi3[i] + openmpi4[i] + openmpi5[i] ) / 5)

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("colorblind", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(size_values, cray_mpich1, marker='x', markersize=10, linewidth=2.5, color=color_palette[2])
ax.plot(size_values, argonne_mpich1, marker='o', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(size_values, openmpi1, marker="|", markersize=10, linewidth=2.5, color=color_palette[0])

# Set labels and title
ax.set_xlabel('Size')
ax.set_ylabel('Bandwidth (MB/s)')
# ax.set_title(' OSU MPI-CUDA Point-to-Point Bandwidth')

# Set y ticks
# ax.set_yticks(range(0, 25001, 5000))

plt.xscale('log')
plt.yscale('log')

# Rotate x-axis labels for better visibility
ax.set_xticks(size_values)
ax.set_xticklabels(sizes, rotation=45)

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='lower right') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save plot
plt.savefig("figures/loglog_pt2pt/pt2pt_bandwidth_all.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %%
sizes = ['4', '8', '16', '32', '64', '128', '256', '512', '1K', '2K', '4K', '8K']
size_values = [4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192]

num_elements = len(sizes)

cray_mpich_small = []
argonne_mpich_small = []
openmpi_small = []

for i in range(num_elements):
    cray_mpich_small.append( cray_mpich_averages[i] )
    argonne_mpich_small.append( argonne_mpich_averages[i] )
    openmpi_small.append( openmpi_averages[i] )

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("colorblind", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(size_values, cray_mpich_small, marker='x', markersize=10, linewidth=2.5, color=color_palette[2])
ax.plot(size_values, argonne_mpich_small, marker='o', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(size_values, openmpi_small, marker="|", markersize=10, linewidth=2.5, color=color_palette[0])

# Set labels and title
ax.set_xlabel('Size')
ax.set_ylabel('Bandwidth (MB/s)')
# ax.set_title(' OSU MPI-CUDA Point-to-Point Bandwidth')

# Set y ticks
# ax.set_yticks(range(0, 10001, 2500))

plt.xscale('log')
plt.yscale('log')

# Rotate x-axis labels for better visibility
ax.set_xticks(size_values)
ax.set_xticklabels(sizes, rotation=45)

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='upper left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save plot
plt.savefig("figures/loglog_pt2pt/pt2pt_bandwidth_small.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()

# %%
sizes = ['16K', '32K', '64K', '128K', '256K', '512K', '1MB', '2MB', '4MB', '8MB', '16MB']
size_values = [16384, 32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304, 8388608, 16777216]

num_elements = len(sizes)

cray_mpich_large = []
argonne_mpich_large = []
openmpi_large = []

for i in range(num_elements):
    cray_mpich_large.append( cray_mpich_averages[i+12] )
    argonne_mpich_large.append( argonne_mpich_averages[i+12] )
    openmpi_large.append( openmpi_averages[i+12] )

#----------------------------------------------------------------------------------------
# Set plot style and create a color palette
sns.set(style="whitegrid")
color_palette = sns.color_palette("colorblind", 3)

# Set the plot size
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(16, 12))

# Increase font sizes
plt.rc('font', size=320)         # controls default text sizes

# Plotting the line plot with larger linewidth and markersize
ax.plot(size_values, cray_mpich_large, marker='x', markersize=10, linewidth=2.5, color=color_palette[2])
ax.plot(size_values, argonne_mpich_large, marker='o', markersize=10, linewidth=2.5, color=color_palette[1])
ax.plot(size_values, openmpi_large, marker="|", markersize=10, linewidth=2.5, color=color_palette[0])

# Set labels and title
ax.set_xlabel('Size')
ax.set_ylabel('Bandwidth (MB/s)')
# ax.set_title(' OSU MPI-CUDA Point-to-Point Bandwidth')

# Set y ticks
# ax.set_yticks(range(0, 25001, 5000))

plt.xscale('log')
plt.yscale('log')

# Rotate x-axis labels for better visibility
ax.set_xticks(size_values)
ax.set_xticklabels(sizes, rotation=45)

# Add a legend and place it outside the plot area
legend = ax.legend(['Cray MPICH', 'Argonne MPICH', 'Open MPI'], loc='lower left') #, fontsize='large')

# Add grid for easier value estimation
ax.grid(True)

# Adjust the layout to prevent labels from being cut off
fig.tight_layout()

# Save plot
plt.savefig("figures/loglog_pt2pt/pt2pt_bandwidth_large.pdf", format="pdf", dpi=300, bbox_inches='tight', pad_inches=0.1)

# Display the plot
plt.show()
